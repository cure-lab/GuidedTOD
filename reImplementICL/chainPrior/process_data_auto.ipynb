# %%
import os
import json

# %%
# load json file and read line by line
def load_json_file(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            data.append(json.loads(line))
    return data

# %%
data_part = "full"
train_path = f"/research/d5/gds/xywen22/project/llm_framework/AST_abcd_part/data/processed/train_AST_abcd_waction_{data_part}.json"

train_data = load_json_file(train_path)

# %%
print(train_data[0]['target'])
print(train_data[1]['target'])
# Out:
# pull-up-account [albert sanders]
# validate-purchase [<username>, <username>, <username>]

# %% [markdown]
# #### process the actions described in the format of natural language to the structured format

# %%
mapping_dict = {
  "pull-up-account": "pull up the costumer account",
  "enter-details": "enter details",
  "verify-identity": "verify costumer identity",
  "make-password": "create new password",
  "search-timing": "search timing",
  "search-policy": "check policy",
  "validate-purchase": "validate purchase",
  "search-faq": "search faq",
  "membership": "check membership level",
  "search-boots": "search for boots",
  "try-again": "ask costumer to try again",
  "ask-the-oracle": "ask oracle",
  "update-order": "update order information",
  "promo-code": "offer promo code",
  "update-account": "update costumer account",
  "search-membership": "get memberships information",
  "make-purchase": "make purchase",
  "offer-refund": "offer refund",
  "notify-team": "notify team",
  "record-reason": "record reason",
  "search-jeans": "search for jeans",
  "shipping-status": "get shipping status",
  "search-shirt": "search for shirt",
  "instructions": "check instructions",
  "search-jacket": "search for jacket",
  "log-out-in": "ask costumer log out log in",
  "select-faq": "select topic in faq",
  "subscription-status": "get subscription status",
  "send-link": "send link to costumer",
  "search-pricing": "check pricing"
}

# conver key to value and value to key
def convert_dict(mapping_dict):
    new_dict = {}
    for key, value in mapping_dict.items():
        new_dict[value] = key
    return new_dict

new_mapping_dict = convert_dict(mapping_dict)
print(new_mapping_dict)
# Out:
# {'pull up the costumer account': 'pull-up-account', 'enter details': 'enter-details', 'verify costumer identity': 'verify-identity', 'create new password': 'make-password', 'search timing': 'search-timing', 'check policy': 'search-policy', 'validate purchase': 'validate-purchase', 'search faq': 'search-faq', 'check membership level': 'membership', 'search for boots': 'search-boots', 'ask costumer to try again': 'try-again', 'ask oracle': 'ask-the-oracle', 'update order information': 'update-order', 'offer promo code': 'promo-code', 'update costumer account': 'update-account', 'get memberships information': 'search-membership', 'make purchase': 'make-purchase', 'offer refund': 'offer-refund', 'notify team': 'notify-team', 'record reason': 'record-reason', 'search for jeans': 'search-jeans', 'get shipping status': 'shipping-status', 'search for shirt': 'search-shirt', 'check instructions': 'instructions', 'search for jacket': 'search-jacket', 'ask costumer log out log in': 'log-out-in', 'select topic in faq': 'select-faq', 'get subscription status': 'subscription-status', 'send link to costumer': 'send-link', 'check pricing': 'search-pricing'}

# %%
all_transitions = []
tmp_all_transitions = {}
# for i in range(len(train_data)):
#     # if i == 10:
#     #     break
#     # print(new_mapping_dict[train_data[i]['target']])
#     target_pieces = train_data[i]['target'].split(';')
#     # pull up the costumer account [alessandro phoenix]
#     # only get the first part before the first '['
#     for j in range(len(target_pieces)):
#         target_pieces[j] = target_pieces[j].split('[')[0].strip()
    
#     for j in range(len(target_pieces)):
#         if target_pieces[j] in new_mapping_dict:
#             target_pieces[j] = new_mapping_dict[target_pieces[j]]
#         else:
#             print("not found")

#     # print(target_pieces)

#     all_transitions.append(target_pieces)

for i in range(len(train_data)):
    action = train_data[i]['target'].split(' ')[0].strip()
    if train_data[i]['convo_id'] not in tmp_all_transitions:
        tmp_all_transitions[train_data[i]['convo_id']] = []
    tmp_all_transitions[train_data[i]['convo_id']].append(action)

for key, value in tmp_all_transitions.items():
    all_transitions.append(value)

print("all_transitions: ", all_transitions)

# count the freequency of the first action in each dialogue
action_count = {}
for i in range(len(all_transitions)):
    if all_transitions[i][0] not in action_count:
        action_count[all_transitions[i][0]] = 1
    else:
        action_count[all_transitions[i][0]] += 1

print("action_count: ", json.dumps(action_count, indent=2))

# convert to rate
action_rate = {}
total_dialogue = len(all_transitions)
for key, value in action_count.items():
    action_rate[key] = value / total_dialogue

print("action_rate: ", json.dumps(action_rate, indent=2))
# Out:
# all_transitions:  [['pull-up-account', 'validate-purchase', 'record-reason', 'offer-refund'], ['pull-up-account', 'shipping-status', 'validate-purchase', 'update-order'], ['search-faq', 'search-jacket'], ['search-faq', 'search-shirt', 'select-faq'], ['search-faq', 'search-boots', 'select-faq'], ['pull-up-account', 'verify-identity', 'record-reason', 'update-account'], ['pull-up-account', 'verify-identity', 'membership', 'record-reason', 'offer-refund'], ['pull-up-account', 'record-reason', 'record-reason', 'verify-identity', 'update-account'], ['pull-up-account', 'validate-purchase', 'update-order'], ['pull-up-account', 'verify-identity', 'subscription-status', 'enter-details', 'send-link'], ['enter-details', 'log-out-in'], ['pull-up-account', 'validate-purchase'], ['offer-refund', 'pull-up-account', 'record-reason', 'ask-the-oracle', 'promo-code'], ['search-faq', 'search-policy', 'select-faq'], ['pull-up-account', 'notify-team'], ['pull-up-account', 'enter-details', 'make-password'], ['pull-up-account', 'verify-identity', 'shipping-status'], ['pull-up-account', 'record-reason', 'ask-the-oracle', 'promo-code'], ['pull-up-account', 'verify-identity', 'membership', 'offer-refund'], ['pull-up-account', 'validate-purchase', 'record-reason', 'offer-refund'], ['pull-up-account', 'enter-details', 'send-link'], ['pull-up-account', 'validate-purchase', 'offer-refund'], ['pull-up-account', 'record-reason', 'ask-the-oracle'], ['search-faq', 'try-again', 'log-out-in'], ['pull-up-account', 'verify-identity', 'subscription-status', 'send-link', 'enter-details'], ['search-faq', 'search-membership', 'search-policy', 'select-faq'], ['pull-up-account', 'verify-identity'], ['verify-identity', 'subscription-status', 'send-link'], ['search-faq', 'search-boots'], ['pull-up-account', 'shipping-status', 'shipping-status', 'membership', 'verify-identity', 'make-purchase'], ['search-faq', 'search-jeans', 'select-faq'], ['pull-up-account', 'verify-identity', 'ask-the-oracle'], ['pull-up-account', 'verify-identity', 'ask-the-oracle', 'offer-refund'], ['pull-up-account', 'verify-identity'], ['search-faq', 'search-boots', 'select-faq'], ['pull-up-account', 'verify-identity'], ['pull-up-account', 'record-reason', 'validate-purchase', 'offer-refund'], ['pull-up-account', 'validate-purchase', 'record-reason'], ['pull-up-account', 'verify-identity'], ['pull-up-account', 'verify-identity', 'ask-the-oracle', 'update-order'], ['pull-up-account', 'enter-details', 'send-link'], ['pull-up-account', 'subscription-status', 'verify-identity', 'search-faq', 'search-membership', 'send-link'], ['pull-up-account', 'verify-identity', 'ask-the-oracle'], ['pull-up-account', 'ask-the-oracle', 'send-link'], ['pull-up-account', 'verify-identity', 'ask-the-oracle', 'update-order'], ['pull-up-account', 'record-reason', 'ask-the-oracle'], ['pull-up-account', 'verify-identity'], ['search-faq', 'search-jacket', 'select-faq'], ['pull-up-account', 'verify-identity', 'subscription-status', 'send-link', 'enter-details'], ['search-faq', 'search-timing', 'select-faq'], ['search-faq', 'search-jeans', 'select-faq'], ['enter-details', 'try-again', 'log-out-in'], ['search-faq', 'search-membership'], ['pull-up-account', 'record-reason', 'ask-the-oracle', 'update-account'], ['pull-up-account', 'verify-identity', 'ask-the-oracle'], ['pull-up-account', 'ask-the-oracle', 'promo-code'], ['pull-up-account', 'verify-identity'], ['pull-up-account', 'validate-purchase', 'record-reason'], ['pull-up-account', 'verify-identity', 'validate-purchase', 'update-order'], ['pull-up-account', 'subscription-status', 'send-link'], ['pull-up-account', 'verify-identity', 'shipping-status', 'update-order'], ['pull-up-account', 'verify-identity', 'subscription-status', 'enter-details', 'update-account'], ['pull-up-account', 'verify-identity'], ['pull-up-account', 'verify-identity'], ['pull-up-account', 'enter-details', 'make-password'], ['pull-up-account', 'validate-purchase', 'verify-identity', 'validate-purchase', 'a ...
# action_count:  {
#   "pull-up-account": 5378,
#   "search-faq": 1643,
#   "enter-details": 53,
#   "offer-refund": 9,
#   "verify-identity": 139,
#   "try-again": 283,
#   "validate-purchase": 35,
#   "notify-team": 93,
#   "log-out-in": 265,
#   "record-reason": 32,
#   "make-purchase": 7,
#   "instructions": 23,
#   "shipping-status": 14,
#   "membership": 29,
#   "ask-the-oracle": 7,
#   "subscription-status": 11,
#   "update-account": 4,
#   "make-password": 2,
#   "update-order": 3,
#   "promo-code": 3,
#   "send-link": 1
# }
# action_rate:  {
#   "pull-up-account": 0.6694050286283296,
#   "search-faq": 0.2045058501369181,
#   "enter-details": 0.006596962907642519,
#   "offer-refund": 0.0011202389843166542,
#   "verify-identity": 0.017301468757779437,
#   "try-again": 0.035225292506845904,
#   "validate-purchase": 0.0043564849390092105,
#   "notify-team": 0.01157580283793876,
#   "log-out-in": 0.032984814538212594,
#   "record-reason": 0.003983071944236993,
#   "make-purchase": 0.0008712969878018422,
#   "instructions": 0.0028628329599203386,
#   "shipping-status": 0.0017425939756036844,
#   "membership": 0.0036096589494647746,
#   "ask-the-oracle": 0.0008712969878018422,
#   "subscription-status": 0.0013691809808314662,
#   "update-account": 0.0004978839930296241,
#   "make-password": 0.00024894199651481205,
#   "update-order": 0.0003734129947722181,
#   "promo-code": 0.0003734129947722181,
#   "send-link": 0.00012447099825740602
# }

# %%
possible_states = mapping_dict.keys()
print(list(possible_states))
possible_states = list(possible_states)
# ['pull-up-account', 'enter-details', 'verify-identity', 'make-password', 'search-timing', 'search-policy', 'validate-purchase', 'search-faq', 'membership', 'search-boots', 'try-again', 'ask-the-oracle', 'update-order', 'promo-code', 'update-account', 'search-membership', 'make-purchase', 'offer-refund', 'notify-team', 'record-reason', 'search-jeans', 'shipping-status', 'search-shirt', 'instructions', 'search-jacket', 'log-out-in', 'select-faq', 'subscription-status', 'send-link', 'search-pricing']
# Out:
# ['pull-up-account', 'enter-details', 'verify-identity', 'make-password', 'search-timing', 'search-policy', 'validate-purchase', 'search-faq', 'membership', 'search-boots', 'try-again', 'ask-the-oracle', 'update-order', 'promo-code', 'update-account', 'search-membership', 'make-purchase', 'offer-refund', 'notify-team', 'record-reason', 'search-jeans', 'shipping-status', 'search-shirt', 'instructions', 'search-jacket', 'log-out-in', 'select-faq', 'subscription-status', 'send-link', 'search-pricing']

# %%
# count the transition frequency between every two actions/state according to all_transitions
transition_count = {}
for i in range(len(all_transitions)):
    for j in range(len(all_transitions[i]) - 1):
        if (all_transitions[i][j], all_transitions[i][j+1]) in transition_count:
            transition_count[(all_transitions[i][j], all_transitions[i][j+1])] += 1
        else:
            transition_count[(all_transitions[i][j], all_transitions[i][j+1])] = 1

print("transition_count: ", transition_count)

# if no transition between two states, set the frequency to 0
for state1 in possible_states:
    for state2 in possible_states:
        if (state1, state2) not in transition_count:
            transition_count[(state1, state2)] = 0

print("transition_count: ", transition_count)
# Out:
# transition_count:  {('pull-up-account', 'validate-purchase'): 1376, ('validate-purchase', 'record-reason'): 406, ('record-reason', 'offer-refund'): 136, ('pull-up-account', 'shipping-status'): 138, ('shipping-status', 'validate-purchase'): 140, ('validate-purchase', 'update-order'): 202, ('search-faq', 'search-jacket'): 224, ('search-faq', 'search-shirt'): 200, ('search-shirt', 'select-faq'): 144, ('search-faq', 'search-boots'): 240, ('search-boots', 'select-faq'): 162, ('pull-up-account', 'verify-identity'): 2175, ('verify-identity', 'record-reason'): 35, ('record-reason', 'update-account'): 14, ('verify-identity', 'membership'): 251, ('membership', 'record-reason'): 7, ('pull-up-account', 'record-reason'): 687, ('record-reason', 'record-reason'): 44, ('record-reason', 'verify-identity'): 327, ('verify-identity', 'update-account'): 184, ('verify-identity', 'subscription-status'): 386, ('subscription-status', 'enter-details'): 147, ('enter-details', 'send-link'): 301, ('enter-details', 'log-out-in'): 41, ('offer-refund', 'pull-up-account'): 8, ('record-reason', 'ask-the-oracle'): 243, ('ask-the-oracle', 'promo-code'): 144, ('search-faq', 'search-policy'): 203, ('search-policy', 'select-faq'): 150, ('pull-up-account', 'notify-team'): 91, ('pull-up-account', 'enter-details'): 439, ('enter-details', 'make-password'): 237, ('verify-identity', 'shipping-status'): 332, ('membership', 'offer-refund'): 96, ('validate-purchase', 'offer-refund'): 33, ('search-faq', 'try-again'): 18, ('try-again', 'log-out-in'): 272, ('subscription-status', 'send-link'): 196, ('send-link', 'enter-details'): 71, ('search-faq', 'search-membership'): 308, ('search-membership', 'search-policy'): 48, ('shipping-status', 'shipping-status'): 27, ('shipping-status', 'membership'): 163, ('membership', 'verify-identity'): 4, ('verify-identity', 'make-purchase'): 13, ('search-faq', 'search-jeans'): 230, ('search-jeans', 'select-faq'): 159, ('verify-identity', 'ask-the-oracle'): 421, ('ask-the-oracle', 'offer-refund'): 65, ('record-reason', 'validate-purchase'): 15, ('ask-the-oracle', 'update-order'): 241, ('pull-up-account', 'subscription-status'): 42, ('subscription-status', 'verify-identity'): 10, ('verify-identity', 'search-faq'): 12, ('search-membership', 'send-link'): 2, ('pull-up-account', 'ask-the-oracle'): 289, ('ask-the-oracle', 'send-link'): 72, ('search-jacket', 'select-faq'): 164, ('search-faq', 'search-timing'): 211, ('search-timing', 'select-faq'): 147, ('enter-details', 'try-again'): 37, ('ask-the-oracle', 'update-account'): 81, ('verify-identity', 'validate-purchase'): 277, ('shipping-status', 'update-order'): 133, ('enter-details', 'update-account'): 160, ('validate-purchase', 'verify-identity'): 32, ('validate-purchase', 'ask-the-oracle'): 320, ('search-faq', 'pull-up-account'): 12, ('pull-up-account', 'search-faq'): 117, ('ask-the-oracle', 'membership'): 207, ('validate-purchase', 'shipping-status'): 157, ('shipping-status', 'offer-refund'): 107, ('verify-identity', 'verify-identity'): 191, ('verify-identity', 'promo-code'): 145, ('membership', 'promo-code'): 70, ('verify-identity', 'pull-up-account'): 46, ('membership', 'update-order'): 120, ('validate-purchase', 'membership'): 350, ('membership', 'enter-details'): 325, ('enter-details', 'update-order'): 370, ('select-faq', 'select-faq'): 95, ('validate-purchase', 'validate-purchase'): 88, ('search-timing', 'search-timing'): 3, ('search-timing', 'search-membership'): 22, ('update-account', 'offer-refund'): 34, ('membership', 'update-account'): 48, ('search-faq', 'search-pricing'): 217, ('search-pricing', 'select-faq'): 162, ('notify-team', 'log-out-in'): 63, ('log-out-in', 'try-again'): 140, ('try-again', 'notify-team'): 19, ('try-again', 'instructions'): 94, ('search-membership', 'select-faq'): 187, ('ask-the-oracle', 'validate-purchase'): 9, ('validate-purchase', 'enter-details'): 116, ('enter-details', 'enter-details'): 65, ('enter-details', 'shipping-status'): 4, ('shipping-status', 'ask-the ...
# transition_count:  {('pull-up-account', 'validate-purchase'): 1376, ('validate-purchase', 'record-reason'): 406, ('record-reason', 'offer-refund'): 136, ('pull-up-account', 'shipping-status'): 138, ('shipping-status', 'validate-purchase'): 140, ('validate-purchase', 'update-order'): 202, ('search-faq', 'search-jacket'): 224, ('search-faq', 'search-shirt'): 200, ('search-shirt', 'select-faq'): 144, ('search-faq', 'search-boots'): 240, ('search-boots', 'select-faq'): 162, ('pull-up-account', 'verify-identity'): 2175, ('verify-identity', 'record-reason'): 35, ('record-reason', 'update-account'): 14, ('verify-identity', 'membership'): 251, ('membership', 'record-reason'): 7, ('pull-up-account', 'record-reason'): 687, ('record-reason', 'record-reason'): 44, ('record-reason', 'verify-identity'): 327, ('verify-identity', 'update-account'): 184, ('verify-identity', 'subscription-status'): 386, ('subscription-status', 'enter-details'): 147, ('enter-details', 'send-link'): 301, ('enter-details', 'log-out-in'): 41, ('offer-refund', 'pull-up-account'): 8, ('record-reason', 'ask-the-oracle'): 243, ('ask-the-oracle', 'promo-code'): 144, ('search-faq', 'search-policy'): 203, ('search-policy', 'select-faq'): 150, ('pull-up-account', 'notify-team'): 91, ('pull-up-account', 'enter-details'): 439, ('enter-details', 'make-password'): 237, ('verify-identity', 'shipping-status'): 332, ('membership', 'offer-refund'): 96, ('validate-purchase', 'offer-refund'): 33, ('search-faq', 'try-again'): 18, ('try-again', 'log-out-in'): 272, ('subscription-status', 'send-link'): 196, ('send-link', 'enter-details'): 71, ('search-faq', 'search-membership'): 308, ('search-membership', 'search-policy'): 48, ('shipping-status', 'shipping-status'): 27, ('shipping-status', 'membership'): 163, ('membership', 'verify-identity'): 4, ('verify-identity', 'make-purchase'): 13, ('search-faq', 'search-jeans'): 230, ('search-jeans', 'select-faq'): 159, ('verify-identity', 'ask-the-oracle'): 421, ('ask-the-oracle', 'offer-refund'): 65, ('record-reason', 'validate-purchase'): 15, ('ask-the-oracle', 'update-order'): 241, ('pull-up-account', 'subscription-status'): 42, ('subscription-status', 'verify-identity'): 10, ('verify-identity', 'search-faq'): 12, ('search-membership', 'send-link'): 2, ('pull-up-account', 'ask-the-oracle'): 289, ('ask-the-oracle', 'send-link'): 72, ('search-jacket', 'select-faq'): 164, ('search-faq', 'search-timing'): 211, ('search-timing', 'select-faq'): 147, ('enter-details', 'try-again'): 37, ('ask-the-oracle', 'update-account'): 81, ('verify-identity', 'validate-purchase'): 277, ('shipping-status', 'update-order'): 133, ('enter-details', 'update-account'): 160, ('validate-purchase', 'verify-identity'): 32, ('validate-purchase', 'ask-the-oracle'): 320, ('search-faq', 'pull-up-account'): 12, ('pull-up-account', 'search-faq'): 117, ('ask-the-oracle', 'membership'): 207, ('validate-purchase', 'shipping-status'): 157, ('shipping-status', 'offer-refund'): 107, ('verify-identity', 'verify-identity'): 191, ('verify-identity', 'promo-code'): 145, ('membership', 'promo-code'): 70, ('verify-identity', 'pull-up-account'): 46, ('membership', 'update-order'): 120, ('validate-purchase', 'membership'): 350, ('membership', 'enter-details'): 325, ('enter-details', 'update-order'): 370, ('select-faq', 'select-faq'): 95, ('validate-purchase', 'validate-purchase'): 88, ('search-timing', 'search-timing'): 3, ('search-timing', 'search-membership'): 22, ('update-account', 'offer-refund'): 34, ('membership', 'update-account'): 48, ('search-faq', 'search-pricing'): 217, ('search-pricing', 'select-faq'): 162, ('notify-team', 'log-out-in'): 63, ('log-out-in', 'try-again'): 140, ('try-again', 'notify-team'): 19, ('try-again', 'instructions'): 94, ('search-membership', 'select-faq'): 187, ('ask-the-oracle', 'validate-purchase'): 9, ('validate-purchase', 'enter-details'): 116, ('enter-details', 'enter-details'): 65, ('enter-details', 'shipping-status'): 4, ('shipping-status', 'ask-the ...

# %%
# print the pairs number
counter = 0
for key, value in transition_count.items():
    counter += 1
    print(key, value)

print("counter: ", counter)
# Out:
# ('pull-up-account', 'validate-purchase') 1376
# ('validate-purchase', 'record-reason') 406
# ('record-reason', 'offer-refund') 136
# ('pull-up-account', 'shipping-status') 138
# ('shipping-status', 'validate-purchase') 140
# ('validate-purchase', 'update-order') 202
# ('search-faq', 'search-jacket') 224
# ('search-faq', 'search-shirt') 200
# ('search-shirt', 'select-faq') 144
# ('search-faq', 'search-boots') 240
# ('search-boots', 'select-faq') 162
# ('pull-up-account', 'verify-identity') 2175
# ('verify-identity', 'record-reason') 35
# ('record-reason', 'update-account') 14
# ('verify-identity', 'membership') 251
# ('membership', 'record-reason') 7
# ('pull-up-account', 'record-reason') 687
# ('record-reason', 'record-reason') 44
# ('record-reason', 'verify-identity') 327
# ('verify-identity', 'update-account') 184
# ('verify-identity', 'subscription-status') 386
# ('subscription-status', 'enter-details') 147
# ('enter-details', 'send-link') 301
# ('enter-details', 'log-out-in') 41
# ('offer-refund', 'pull-up-account') 8
# ('record-reason', 'ask-the-oracle') 243
# ('ask-the-oracle', 'promo-code') 144
# ('search-faq', 'search-policy') 203
# ('search-policy', 'select-faq') 150
# ('pull-up-account', 'notify-team') 91
# ('pull-up-account', 'enter-details') 439
# ('enter-details', 'make-password') 237
# ('verify-identity', 'shipping-status') 332
# ('membership', 'offer-refund') 96
# ('validate-purchase', 'offer-refund') 33
# ('search-faq', 'try-again') 18
# ('try-again', 'log-out-in') 272
# ('subscription-status', 'send-link') 196
# ('send-link', 'enter-details') 71
# ('search-faq', 'search-membership') 308
# ('search-membership', 'search-policy') 48
# ('shipping-status', 'shipping-status') 27
# ('shipping-status', 'membership') 163
# ('membership', 'verify-identity') 4
# ('verify-identity', 'make-purchase') 13
# ('search-faq', 'search-jeans') 230
# ('search-jeans', 'select-faq') 159
# ('verify-identity', 'ask-the-oracle') 421
# ('ask-the-oracle', 'offer-refund') 65
# ('record-reason', 'validate-purchase') 15
# ('ask-the-oracle', 'update-order') 241
# ('pull-up-account', 'subscription-status') 42
# ('subscription-status', 'verify-identity') 10
# ('verify-identity', 'search-faq') 12
# ('search-membership', 'send-link') 2
# ('pull-up-account', 'ask-the-oracle') 289
# ('ask-the-oracle', 'send-link') 72
# ('search-jacket', 'select-faq') 164
# ('search-faq', 'search-timing') 211
# ('search-timing', 'select-faq') 147
# ('enter-details', 'try-again') 37
# ('ask-the-oracle', 'update-account') 81
# ('verify-identity', 'validate-purchase') 277
# ('shipping-status', 'update-order') 133
# ('enter-details', 'update-account') 160
# ('validate-purchase', 'verify-identity') 32
# ('validate-purchase', 'ask-the-oracle') 320
# ('search-faq', 'pull-up-account') 12
# ('pull-up-account', 'search-faq') 117
# ('ask-the-oracle', 'membership') 207
# ('validate-purchase', 'shipping-status') 157
# ('shipping-status', 'offer-refund') 107
# ('verify-identity', 'verify-identity') 191
# ('verify-identity', 'promo-code') 145
# ('membership', 'promo-code') 70
# ('verify-identity', 'pull-up-account') 46
# ('membership', 'update-order') 120
# ('validate-purchase', 'membership') 350
# ('membership', 'enter-details') 325
# ('enter-details', 'update-order') 370
# ('select-faq', 'select-faq') 95
# ('validate-purchase', 'validate-purchase') 88
# ('search-timing', 'search-timing') 3
# ('search-timing', 'search-membership') 22
# ('update-account', 'offer-refund') 34
# ('membership', 'update-account') 48
# ('search-faq', 'search-pricing') 217
# ('search-pricing', 'select-faq') 162
# ('notify-team', 'log-out-in') 63
# ('log-out-in', 'try-again') 140
# ('try-again', 'notify-team') 19
# ('try-again', 'instructions') 94
# ('search-membership', 'select-faq') 187
# ('ask-the-oracle', 'validate-purchase') 9
# ('validate-purchase', 'enter-details') 116
# ('enter-details', 'enter-details') 65
# ('enter-details', 'shipping-status') 4
# ('shipping-status', 'ask-the-oracle') 11
# ('ask-the-oracle', 'shipping-status') 58
# ('offer-refund', 'offer-refund') 19
# ('search-jeans', 'search-pricing') 9
# ('search-pricing', 'search-jeans') 2
# ('search-jeans', 'search-timing') 2
# ('search-timing', 'search-pricing') 12
# ('record-reason', 'enter-details') 92
# ('enter-details', 'offer-refund') 124
# ('notify-team', 'promo-code') 35
# ('record-reason', 'update-order') 118
# ('update-order', 'make-purchase') 112
# ('search-policy', 'search-membership') 18
# ('offer-refund', 'update-order') 2
# ('log-out-in', 'notify-team') 19
# ('notify-team', 'instructions') 19
# ('pull-up-account', 'pull-up-account') 90
# ('membership', 'membership') 39
# ('pull-up-account', 'promo-code') 17
# ('promo-code', 'ask-the-oracle') 6
# ('make-password', 'make-password') 9
# ('record-reason', 'promo-code') 32
# ('search-shirt', 'search-shirt') 4
# ('search-shirt', 'search-jacket') 5
# ('offer-refund', 'send-link') 1
# ('send-link', 'membership') 1
# ('enter-details', 'notify-team') 43
# ('send-link', 'send-link') 14
# ('select-faq', 'search-shirt') 2
# ('update-account', 'send-link') 12
# ('notify-team', 'verify-identity') 2
# ('verify-identity', 'update-order') 35
# ('subscription-status', 'subscription-status') 27
# ('update-order', 'subscription-status') 1
# ('select-faq', 'pull-up-account') 13
# ('record-reason', 'notify-team') 105
# ('notify-team', 'pull-up-account') 9
# ('pull-up-account', 'make-purchase') 9
# ('verify-identity', 'enter-details') 154
# ('make-purchase', 'make-purchase') 31
# ('make-purchase', 'verify-identity') 1
# ('verify-identity', 'offer-refund') 17
# ('send-link', 'subscription-status') 6
# ('subscription-status', 'update-account') 37
# ('update-account', 'enter-details') 2
# ('ask-the-oracle', 'record-reason') 17
# ('pull-up-account', 'try-again') 35
# ('search-pricing', 'search-faq') 5
# ('search-jacket', 'search-jeans') 4
# ('try-again', 'enter-details') 45
# ('search-policy', 'try-again') 7
# ('subscription-status', 'ask-the-oracle') 7
# ('log-out-in', 'enter-details') 101
# ('instructions', 'log-out-in') 21
# ('ask-the-oracle', 'search-faq') 16
# ('search-faq', 'promo-code') 1
# ('log-out-in', 'instructions') 140
# ('pull-up-account', 'log-out-in') 20
# ('select-faq', 'promo-code') 2
# ('update-order', 'offer-refund') 11
# ('promo-code', 'enter-details') 2
# ('pull-up-account', 'update-order') 3
# ('update-order', 'shipping-status') 3
# ('search-pricing', 'search-policy') 18
# ('search-policy', 'search-timing') 13
# ('try-again', 'search-faq') 4
# ('search-timing', 'search-jeans') 2
# ('search-jeans', 'log-out-in') 1
# ('select-faq', 'search-timing') 3
# ('membership', 'search-faq') 62
# ('search-policy', 'subscription-status') 1
# ('ask-the-oracle', 'enter-details') 5
# ('pull-up-account', 'make-password') 15
# ('enter-details', 'make-purchase') 28
# ('membership', 'ask-the-oracle') 49
# ('shipping-status', 'pull-up-account') 9
# ('validate-purchase', 'search-faq') 12
# ('search-policy', 'membership') 4
# ('ask-the-oracle', 'ask-the-oracle') 16
# ('update-order', 'update-account') 10
# ('search-membership', 'membership') 8
# ('membership', 'instructions') 5
# ('instructions', 'search-policy') 3
# ('instructions', 'try-again') 28
# ('search-membership', 'pull-up-account') 9
# ('make-purchase', 'try-again') 1
# ('instructions', 'notify-team') 27
# ('notify-team', 'enter-details') 4
# ('enter-details', 'instructions') 2
# ('make-purchase', 'notify-team') 2
# ('update-order', 'update-order') 47
# ('search-timing', 'search-policy') 17
# ('membership', 'make-purchase') 35
# ('search-boots', 'search-jacket') 2
# ('search-jacket', 'search-boots') 2
# ('notify-team', 'make-purchase') 69
# ('promo-code', 'membership') 3
# ('promo-code', 'send-link') 3
# ('update-order', 'promo-code') 2
# ('ask-the-oracle', 'notify-team') 6
# ('select-faq', 'instructions') 1
# ('notify-team', 'search-faq') 3
# ('search-policy', 'search-pricing') 23
# ('search-pricing', 'search-timing') 21
# ('offer-refund', 'enter-details') 7
# ('search-faq', 'membership') 14
# ('shipping-status', 'verify-identity') 14
# ('try-again', 'make-purchase') 10
# ('try-again', 'pull-up-account') 2
# ('enter-details', 'verify-identity') 3
# ('membership', 'subscription-status') 11
# ('subscription-status', 'update-order') 5
# ('verify-identity', 'send-link') 6
# ('promo-code', 'verify-identity') 1
# ('search-jeans', 'search-shirt') 3
# ('search-shirt', 'search-boots') 3
# ('search-boots', 'search-shirt') 1
# ('membership', 'notify-team') 11
# ('search-membership', 'search-timing') 14
# ('update-order', 'record-reason') 4
# ('notify-team', 'try-again') 18
# ('select-faq', 'search-policy') 7
# ('select-faq', 'search-jeans') 5
# ('search-jeans', 'instructions') 2
# ('instructions', 'send-link') 1
# ('send-link', 'update-account') 5
# ('update-account', 'update-order') 4
# ('update-order', 'enter-details') 21
# ('make-password', 'subscription-status') 1
# ('subscription-status', 'promo-code') 1
# ('membership', 'try-again') 4
# ('try-again', 'ask-the-oracle') 4
# ('select-faq', 'search-faq') 3
# ('search-faq', 'log-out-in') 13
# ('instructions', 'search-faq') 10
# ('ask-the-oracle', 'log-out-in') 5
# ('instructions', 'pull-up-account') 1
# ('validate-purchase', 'update-account') 1
# ('record-reason', 'pull-up-account') 21
# ('search-membership', 'search-pricing') 19
# ('search-boots', 'record-reason') 2
# ('notify-team', 'notify-team') 12
# ('verify-identity', 'notify-team') 3
# ('enter-details', 'record-reason') 7
# ('membership', 'search-membership') 6
# ('search-membership', 'verify-identity') 2
# ('membership', 'shipping-status') 4
# ('shipping-status', 'make-purchase') 13
# ('instructions', 'make-purchase') 6
# ('update-account', 'update-account') 11
# ('update-order', 'search-faq') 4
# ('search-shirt', 'search-pricing') 11
# ('validate-purchase', 'pull-up-account') 6
# ('subscription-status', 'notify-team') 4
# ('validate-purchase', 'subscription-status') 12
# ('search-pricing', 'try-again') 1
# ('search-pricing', 'pull-up-account') 9
# ('verify-identity', 'make-password') 20
# ('log-out-in', 'make-purchase') 10
# ('validate-purchase', 'make-purchase') 6
# ('record-reason', 'log-out-in') 1
# ('pull-up-account', 'offer-refund') 5
# ('offer-refund', 'record-reason') 7
# ('search-membership', 'search-faq') 2
# ('record-reason', 'make-purchase') 7
# ('make-purchase', 'search-faq') 5
# ('search-faq', 'notify-team') 3
# ('record-reason', 'shipping-status') 2
# ('search-faq', 'verify-identity') 3
# ('pull-up-account', 'membership') 31
# ('search-policy', 'instructions') 4
# ('instructions', 'membership') 4
# ('membership', 'search-policy') 1
# ('enter-details', 'membership') 5
# ('select-faq', 'search-pricing') 7
# ('subscription-status', 'pull-up-account') 6
# ('notify-team', 'record-reason') 7
# ('update-account', 'record-reason') 4
# ('search-boots', 'log-out-in') 1
# ('log-out-in', 'search-boots') 1
# ('search-boots', 'try-again') 1
# ('try-again', 'select-faq') 2
# ('select-faq', 'ask-the-oracle') 2
# ('search-pricing', 'membership') 2
# ('membership', 'search-jeans') 1
# ('search-jeans', 'membership') 1
# ('membership', 'pull-up-account') 2
# ('make-purchase', 'membership') 1
# ('search-faq', 'subscription-status') 1
# ('subscription-status', 'log-out-in') 1
# ('log-out-in', 'shipping-status') 1
# ('select-faq', 'send-link') 3
# ('offer-refund', 'search-faq') 3
# ('search-policy', 'search-faq') 2
# ('validate-purchase', 'notify-team') 5
# ('search-membership', 'search-membership') 4
# ('update-account', 'verify-identity') 1
# ('make-purchase', 'enter-details') 4
# ('search-policy', 'log-out-in') 2
# ('search-policy', 'search-policy') 7
# ('search-policy', 'ask-the-oracle') 2
# ('search-pricing', 'search-membership') 17
# ('search-timing', 'subscription-status') 1
# ('search-faq', 'validate-purchase') 1
# ('pull-up-account', 'update-account') 1
# ('record-reason', 'membership') 25
# ('promo-code', 'promo-code') 3
# ('ask-the-oracle', 'subscription-status') 7
# ('search-boots', 'search-boots') 3
# ('search-boots', 'search-faq') 3
# ('instructions', 'instructions') 6
# ('search-timing', 'enter-details') 1
# ('search-membership', 'shipping-status') 1
# ('search-pricing', 'search-pricing') 3
# ('search-pricing', 'search-shirt') 3
# ('search-policy', 'pull-up-account') 7
# ('select-faq', 'search-boots') 1
# ('update-account', 'validate-purchase') 3
# ('search-jeans', 'search-faq') 3
# ('search-faq', 'search-faq') 7
# ('notify-team', 'update-account') 1
# ('search-faq', 'select-faq') 9
# ('validate-purchase', 'send-link') 1
# ('search-faq', 'instructions') 9
# ('send-link', 'pull-up-account') 2
# ('ask-the-oracle', 'verify-identity') 8
# ('validate-purchase', 'promo-code') 3
# ('search-pricing', 'search-jacket') 2
# ('search-membership', 'search-boots') 1
# ('log-out-in', 'search-faq') 3
# ('try-again', 'try-again') 7
# ('search-boots', 'offer-refund') 1
# ('offer-refund', 'validate-purchase') 2
# ('shipping-status', 'update-account') 2
# ('promo-code', 'validate-purchase') 1
# ('subscription-status', 'validate-purchase') 2
# ('pull-up-account', 'instructions') 3
# ('instructions', 'record-reason') 1
# ('search-pricing', 'notify-team') 1
# ('search-pricing', 'enter-details') 1
# ('validate-purchase', 'make-password') 1
# ('search-jeans', 'search-jeans') 8
# ('search-jeans', 'search-boots') 2
# ('subscription-status', 'membership') 8
# ('update-account', 'pull-up-account') 2
# ('log-out-in', 'log-out-in') 4
# ('search-membership', 'enter-details') 2
# ('update-order', 'instructions') 1
# ('select-faq', 'search-membership') 5
# ('search-jeans', 'search-jacket') 5
# ('search-jacket', 'search-jacket') 6
# ('offer-refund', 'notify-team') 1
# ('ask-the-oracle', 'make-purchase') 2
# ('make-purchase', 'offer-refund') 1
# ('ask-the-oracle', 'pull-up-account') 4
# ('instructions', 'verify-identity') 2
# ('search-jeans', 'pull-up-account') 4
# ('promo-code', 'record-reason') 1
# ('update-order', 'verify-identity') 1
# ('update-order', 'membership') 3
# ('enter-details', 'search-faq') 3
# ('instructions', 'search-pricing') 1
# ('offer-refund', 'update-account') 3
# ('shipping-status', 'enter-details') 3
# ('make-password', 'search-faq') 1
# ('search-jacket', 'search-pricing') 9
# ('search-jacket', 'search-faq') 1
# ('select-faq', 'membership') 2
# ('subscription-status', 'record-reason') 1
# ('make-purchase', 'log-out-in') 1
# ('try-again', 'search-timing') 1
# ('make-password', 'send-link') 2
# ('search-boots', 'search-policy') 4
# ('search-pricing', 'verify-identity') 1
# ('search-membership', 'record-reason') 2
# ('search-boots', 'search-pricing') 9
# ('search-pricing', 'ask-the-oracle') 6
# ('make-purchase', 'update-account') 1
# ('enter-details', 'validate-purchase') 3
# ('search-jacket', 'instructions') 2
# ('instructions', 'enter-details') 3
# ('select-faq', 'notify-team') 2
# ('make-password', 'enter-details') 4
# ('search-jacket', 'search-timing') 2
# ('log-out-in', 'offer-refund') 1
# ('ask-the-oracle', 'try-again') 1
# ('search-faq', 'enter-details') 2
# ('subscription-status', 'search-faq') 5
# ('instructions', 'ask-the-oracle') 1
# ('search-jacket', 'search-shirt') 1
# ('search-policy', 'enter-details') 1
# ('enter-details', 'subscription-status') 2
# ('offer-refund', 'membership') 4
# ('try-again', 'shipping-status') 2
# ('search-timing', 'pull-up-account') 3
# ('shipping-status', 'record-reason') 7
# ('record-reason', 'search-faq') 5
# ('search-jacket', 'notify-team') 1
# ('search-boots', 'search-membership') 1
# ('search-membership', 'notify-team') 2
# ('offer-refund', 'shipping-status') 2
# ('update-account', 'search-faq') 2
# ('search-policy', 'search-boots') 1
# ('send-link', 'verify-identity') 2
# ('update-order', 'send-link') 2
# ('search-boots', 'pull-up-account') 3
# ('log-out-in', 'pull-up-account') 3
# ('membership', 'validate-purchase') 2
# ('promo-code', 'make-purchase') 1
# ('search-timing', 'search-shirt') 1
# ('search-shirt', 'pull-up-account') 1
# ('search-timing', 'promo-code') 2
# ('enter-details', 'ask-the-oracle') 3
# ('search-jeans', 'search-policy') 3
# ('search-policy', 'record-reason') 1
# ('search-shirt', 'verify-identity') 1
# ('search-timing', 'make-purchase') 1
# ('search-shirt', 'search-timing') 1
# ('search-jacket', 'try-again') 1
# ('try-again', 'membership') 2
# ('make-purchase', 'validate-purchase') 1
# ('search-boots', 'make-purchase') 1
# ('shipping-status', 'search-faq') 3
# ('offer-refund', 'verify-identity') 3
# ('select-faq', 'update-account') 1
# ('search-jacket', 'search-membership') 1
# ('search-pricing', 'make-purchase') 1
# ('membership', 'send-link') 2
# ('make-purchase', 'promo-code') 1
# ('update-order', 'notify-team') 2
# ('promo-code', 'update-account') 1
# ('select-faq', 'enter-details') 1
# ('update-order', 'log-out-in') 1
# ('search-shirt', 'try-again') 1
# ('update-order', 'pull-up-account') 1
# ('search-timing', 'ask-the-oracle') 2
# ('update-order', 'make-password') 1
# ('make-password', 'make-purchase') 1
# ('promo-code', 'offer-refund') 1
# ('search-timing', 'try-again') 1
# ('search-policy', 'search-shirt') 1
# ('update-account', 'subscription-status') 2
# ('subscription-status', 'offer-refund') 2
# ('search-shirt', 'search-jeans') 1
# ('select-faq', 'try-again') 2
# ('search-membership', 'subscription-status') 1
# ('search-faq', 'ask-the-oracle') 2
# ('verify-identity', 'try-again') 1
# ('search-boots', 'send-link') 1
# ('shipping-status', 'try-again') 1
# ('enter-details', 'pull-up-account') 1
# ('search-pricing', 'search-boots') 3
# ('search-policy', 'verify-identity') 1
# ('update-account', 'make-purchase') 1
# ('search-policy', 'update-account') 1
# ('shipping-status', 'subscription-status') 1
# ('search-policy', 'search-jeans') 1
# ('log-out-in', 'record-reason') 1
# ('search-jacket', 'pull-up-account') 1
# ('promo-code', 'update-order') 2
# ('send-link', 'validate-purchase') 1
# ('subscription-status', 'try-again') 1
# ('pull-up-account', 'send-link') 1
# ('send-link', 'search-faq') 2
# ('search-timing', 'record-reason') 1
# ('search-membership', 'try-again') 2
# ('search-pricing', 'promo-code') 1
# ('make-purchase', 'record-reason') 1
# ('search-pricing', 'update-order') 1
# ('search-timing', 'search-faq') 1
# ('search-membership', 'offer-refund') 1
# ('search-faq', 'record-reason') 1
# ('try-again', 'search-membership') 1
# ('search-membership', 'update-order') 1
# ('make-purchase', 'update-order') 1
# ('shipping-status', 'notify-team') 1
# ('notify-team', 'shipping-status') 1
# ('enter-details', 'promo-code') 1
# ('verify-identity', 'instructions') 1
# ('update-account', 'notify-team') 1
# ('subscription-status', 'make-purchase') 1
# ('try-again', 'search-jeans') 1
# ('search-membership', 'ask-the-oracle') 1
# ('search-membership', 'instructions') 1
# ('try-again', 'promo-code') 1
# ('pull-up-account', 'search-timing') 0
# ('pull-up-account', 'search-policy') 0
# ('pull-up-account', 'search-boots') 0
# ('pull-up-account', 'search-membership') 0
# ('pull-up-account', 'search-jeans') 0
# ('pull-up-account', 'search-shirt') 0
# ('pull-up-account', 'search-jacket') 0
# ('pull-up-account', 'select-faq') 0
# ('pull-up-account', 'search-pricing') 0
# ('enter-details', 'search-timing') 0
# ('enter-details', 'search-policy') 0
# ('enter-details', 'search-boots') 0
# ('enter-details', 'search-membership') 0
# ('enter-details', 'search-jeans') 0
# ('enter-details', 'search-shirt') 0
# ('enter-details', 'search-jacket') 0
# ('enter-details', 'select-faq') 0
# ('enter-details', 'search-pricing') 0
# ('verify-identity', 'search-timing') 0
# ('verify-identity', 'search-policy') 0
# ('verify-identity', 'search-boots') 0
# ('verify-identity', 'search-membership') 0
# ('verify-identity', 'search-jeans') 0
# ('verify-identity', 'search-shirt') 0
# ('verify-identity', 'search-jacket') 0
# ('verify-identity', 'log-out-in') 0
# ('verify-identity', 'select-faq') 0
# ('verify-identity', 'search-pricing') 0
# ('make-password', 'pull-up-account') 0
# ('make-password', 'verify-identity') 0
# ('make-password', 'search-timing') 0
# ('make-password', 'search-policy') 0
# ('make-password', 'validate-purchase') 0
# ('make-password', 'membership') 0
# ('make-password', 'search-boots') 0
# ('make-password', 'try-again') 0
# ('make-password', 'ask-the-oracle') 0
# ('make-password', 'update-order') 0
# ('make-password', 'promo-code') 0
# ('make-password', 'update-account') 0
# ('make-password', 'search-membership') 0
# ('make-password', 'offer-refund') 0
# ('make-password', 'notify-team') 0
# ('make-password', 'record-reason') 0
# ('make-password', 'search-jeans') 0
# ('make-password', 'shipping-status') 0
# ('make-password', 'search-shirt') 0
# ('make-password', 'instructions') 0
# ('make-password', 'search-jacket') 0
# ('make-password', 'log-out-in') 0
# ('make-password', 'select-faq') 0
# ('make-password', 'search-pricing') 0
# ('search-timing', 'verify-identity') 0
# ('search-timing', 'make-password') 0
# ('search-timing', 'validate-purchase') 0
# ('search-timing', 'membership') 0
# ('search-timing', 'search-boots') 0
# ('search-timing', 'update-order') 0
# ('search-timing', 'update-account') 0
# ('search-timing', 'offer-refund') 0
# ('search-timing', 'notify-team') 0
# ('search-timing', 'shipping-status') 0
# ('search-timing', 'instructions') 0
# ('search-timing', 'search-jacket') 0
# ('search-timing', 'log-out-in') 0
# ('search-timing', 'send-link') 0
# ('search-policy', 'make-password') 0
# ('search-policy', 'validate-purchase') 0
# ('search-policy', 'update-order') 0
# ('search-policy', 'promo-code') 0
# ('search-policy', 'make-purchase') 0
# ('search-policy', 'offer-refund') 0
# ('search-policy', 'notify-team') 0
# ('search-policy', 'shipping-status') 0
# ('search-policy', 'search-jacket') 0
# ('search-policy', 'send-link') 0
# ('validate-purchase', 'search-timing') 0
# ('validate-purchase', 'search-policy') 0
# ('validate-purchase', 'search-boots') 0
# ('validate-purchase', 'try-again') 0
# ('validate-purchase', 'search-membership') 0
# ('validate-purchase', 'search-jeans') 0
# ('validate-purchase', 'search-shirt') 0
# ('validate-purchase', 'instructions') 0
# ('validate-purchase', 'search-jacket') 0
# ('validate-purchase', 'log-out-in') 0
# ('validate-purchase', 'select-faq') 0
# ('validate-purchase', 'search-pricing') 0
# ('search-faq', 'make-password') 0
# ('search-faq', 'update-order') 0
# ('search-faq', 'update-account') 0
# ('search-faq', 'make-purchase') 0
# ('search-faq', 'offer-refund') 0
# ('search-faq', 'shipping-status') 0
# ('search-faq', 'send-link') 0
# ('membership', 'make-password') 0
# ('membership', 'search-timing') 0
# ('membership', 'search-boots') 0
# ('membership', 'search-shirt') 0
# ('membership', 'search-jacket') 0
# ('membership', 'log-out-in') 0
# ('membership', 'select-faq') 0
# ('membership', 'search-pricing') 0
# ('search-boots', 'enter-details') 0
# ('search-boots', 'verify-identity') 0
# ('search-boots', 'make-password') 0
# ('search-boots', 'search-timing') 0
# ('search-boots', 'validate-purchase') 0
# ('search-boots', 'membership') 0
# ('search-boots', 'ask-the-oracle') 0
# ('search-boots', 'update-order') 0
# ('search-boots', 'promo-code') 0
# ('search-boots', 'update-account') 0
# ('search-boots', 'notify-team') 0
# ('search-boots', 'search-jeans') 0
# ('search-boots', 'shipping-status') 0
# ('search-boots', 'instructions') 0
# ('search-boots', 'subscription-status') 0
# ('try-again', 'verify-identity') 0
# ('try-again', 'make-password') 0
# ('try-again', 'search-policy') 0
# ('try-again', 'validate-purchase') 0
# ('try-again', 'search-boots') 0
# ('try-again', 'update-order') 0
# ('try-again', 'update-account') 0
# ('try-again', 'offer-refund') 0
# ('try-again', 'record-reason') 0
# ('try-again', 'search-shirt') 0
# ('try-again', 'search-jacket') 0
# ('try-again', 'subscription-status') 0
# ('try-again', 'send-link') 0
# ('try-again', 'search-pricing') 0
# ('ask-the-oracle', 'make-password') 0
# ('ask-the-oracle', 'search-timing') 0
# ('ask-the-oracle', 'search-policy') 0
# ('ask-the-oracle', 'search-boots') 0
# ('ask-the-oracle', 'search-membership') 0
# ('ask-the-oracle', 'search-jeans') 0
# ('ask-the-oracle', 'search-shirt') 0
# ('ask-the-oracle', 'instructions') 0
# ('ask-the-oracle', 'search-jacket') 0
# ('ask-the-oracle', 'select-faq') 0
# ('ask-the-oracle', 'search-pricing') 0
# ('update-order', 'search-timing') 0
# ('update-order', 'search-policy') 0
# ('update-order', 'validate-purchase') 0
# ('update-order', 'search-boots') 0
# ('update-order', 'try-again') 0
# ('update-order', 'ask-the-oracle') 0
# ('update-order', 'search-membership') 0
# ('update-order', 'search-jeans') 0
# ('update-order', 'search-shirt') 0
# ('update-order', 'search-jacket') 0
# ('update-order', 'select-faq') 0
# ('update-order', 'search-pricing') 0
# ('promo-code', 'pull-up-account') 0
# ('promo-code', 'make-password') 0
# ('promo-code', 'search-timing') 0
# ('promo-code', 'search-policy') 0
# ('promo-code', 'search-faq') 0
# ('promo-code', 'search-boots') 0
# ('promo-code', 'try-again') 0
# ('promo-code', 'search-membership') 0
# ('promo-code', 'notify-team') 0
# ('promo-code', 'search-jeans') 0
# ('promo-code', 'shipping-status') 0
# ('promo-code', 'search-shirt') 0
# ('promo-code', 'instructions') 0
# ('promo-code', 'search-jacket') 0
# ('promo-code', 'log-out-in') 0
# ('promo-code', 'select-faq') 0
# ('promo-code', 'subscription-status') 0
# ('promo-code', 'search-pricing') 0
# ('update-account', 'make-password') 0
# ('update-account', 'search-timing') 0
# ('update-account', 'search-policy') 0
# ('update-account', 'membership') 0
# ('update-account', 'search-boots') 0
# ('update-account', 'try-again') 0
# ('update-account', 'ask-the-oracle') 0
# ('update-account', 'promo-code') 0
# ('update-account', 'search-membership') 0
# ('update-account', 'search-jeans') 0
# ('update-account', 'shipping-status') 0
# ('update-account', 'search-shirt') 0
# ('update-account', 'instructions') 0
# ('update-account', 'search-jacket') 0
# ('update-account', 'log-out-in') 0
# ('update-account', 'select-faq') 0
# ('update-account', 'search-pricing') 0
# ('search-membership', 'make-password') 0
# ('search-membership', 'validate-purchase') 0
# ('search-membership', 'promo-code') 0
# ('search-membership', 'update-account') 0
# ('search-membership', 'make-purchase') 0
# ('search-membership', 'search-jeans') 0
# ('search-membership', 'search-shirt') 0
# ('search-membership', 'search-jacket') 0
# ('search-membership', 'log-out-in') 0
# ('make-purchase', 'pull-up-account') 0
# ('make-purchase', 'make-password') 0
# ('make-purchase', 'search-timing') 0
# ('make-purchase', 'search-policy') 0
# ('make-purchase', 'search-boots') 0
# ('make-purchase', 'ask-the-oracle') 0
# ('make-purchase', 'search-membership') 0
# ('make-purchase', 'search-jeans') 0
# ('make-purchase', 'shipping-status') 0
# ('make-purchase', 'search-shirt') 0
# ('make-purchase', 'instructions') 0
# ('make-purchase', 'search-jacket') 0
# ('make-purchase', 'select-faq') 0
# ('make-purchase', 'subscription-status') 0
# ('make-purchase', 'send-link') 0
# ('make-purchase', 'search-pricing') 0
# ('offer-refund', 'make-password') 0
# ('offer-refund', 'search-timing') 0
# ('offer-refund', 'search-policy') 0
# ('offer-refund', 'search-boots') 0
# ('offer-refund', 'try-again') 0
# ('offer-refund', 'ask-the-oracle') 0
# ('offer-refund', 'promo-code') 0
# ('offer-refund', 'search-membership') 0
# ('offer-refund', 'make-purchase') 0
# ('offer-refund', 'search-jeans') 0
# ('offer-refund', 'search-shirt') 0
# ('offer-refund', 'instructions') 0
# ('offer-refund', 'search-jacket') 0
# ('offer-refund', 'log-out-in') 0
# ('offer-refund', 'select-faq') 0
# ('offer-refund', 'subscription-status') 0
# ('offer-refund', 'search-pricing') 0
# ('notify-team', 'make-password') 0
# ('notify-team', 'search-timing') 0
# ('notify-team', 'search-policy') 0
# ('notify-team', 'validate-purchase') 0
# ('notify-team', 'membership') 0
# ('notify-team', 'search-boots') 0
# ('notify-team', 'ask-the-oracle') 0
# ('notify-team', 'update-order') 0
# ('notify-team', 'search-membership') 0
# ('notify-team', 'offer-refund') 0
# ('notify-team', 'search-jeans') 0
# ('notify-team', 'search-shirt') 0
# ('notify-team', 'search-jacket') 0
# ('notify-team', 'select-faq') 0
# ('notify-team', 'subscription-status') 0
# ('notify-team', 'send-link') 0
# ('notify-team', 'search-pricing') 0
# ('record-reason', 'make-password') 0
# ('record-reason', 'search-timing') 0
# ('record-reason', 'search-policy') 0
# ('record-reason', 'search-boots') 0
# ('record-reason', 'try-again') 0
# ('record-reason', 'search-membership') 0
# ('record-reason', 'search-jeans') 0
# ('record-reason', 'search-shirt') 0
# ('record-reason', 'instructions') 0
# ('record-reason', 'search-jacket') 0
# ('record-reason', 'select-faq') 0
# ('record-reason', 'subscription-status') 0
# ('record-reason', 'send-link') 0
# ('record-reason', 'search-pricing') 0
# ('search-jeans', 'enter-details') 0
# ('search-jeans', 'verify-identity') 0
# ('search-jeans', 'make-password') 0
# ('search-jeans', 'validate-purchase') 0
# ('search-jeans', 'try-again') 0
# ('search-jeans', 'ask-the-oracle') 0
# ('search-jeans', 'update-order') 0
# ('search-jeans', 'promo-code') 0
# ('search-jeans', 'update-account') 0
# ('search-jeans', 'search-membership') 0
# ('search-jeans', 'make-purchase') 0
# ('search-jeans', 'offer-refund') 0
# ('search-jeans', 'notify-team') 0
# ('search-jeans', 'record-reason') 0
# ('search-jeans', 'shipping-status') 0
# ('search-jeans', 'subscription-status') 0
# ('search-jeans', 'send-link') 0
# ('shipping-status', 'make-password') 0
# ('shipping-status', 'search-timing') 0
# ('shipping-status', 'search-policy') 0
# ('shipping-status', 'search-boots') 0
# ('shipping-status', 'promo-code') 0
# ('shipping-status', 'search-membership') 0
# ('shipping-status', 'search-jeans') 0
# ('shipping-status', 'search-shirt') 0
# ('shipping-status', 'instructions') 0
# ('shipping-status', 'search-jacket') 0
# ('shipping-status', 'log-out-in') 0
# ('shipping-status', 'select-faq') 0
# ('shipping-status', 'send-link') 0
# ('shipping-status', 'search-pricing') 0
# ('search-shirt', 'enter-details') 0
# ('search-shirt', 'make-password') 0
# ('search-shirt', 'search-policy') 0
# ('search-shirt', 'validate-purchase') 0
# ('search-shirt', 'search-faq') 0
# ('search-shirt', 'membership') 0
# ('search-shirt', 'ask-the-oracle') 0
# ('search-shirt', 'update-order') 0
# ('search-shirt', 'promo-code') 0
# ('search-shirt', 'update-account') 0
# ('search-shirt', 'search-membership') 0
# ('search-shirt', 'make-purchase') 0
# ('search-shirt', 'offer-refund') 0
# ('search-shirt', 'notify-team') 0
# ('search-shirt', 'record-reason') 0
# ('search-shirt', 'shipping-status') 0
# ('search-shirt', 'instructions') 0
# ('search-shirt', 'log-out-in') 0
# ('search-shirt', 'subscription-status') 0
# ('search-shirt', 'send-link') 0
# ('instructions', 'make-password') 0
# ('instructions', 'search-timing') 0
# ('instructions', 'validate-purchase') 0
# ('instructions', 'search-boots') 0
# ('instructions', 'update-order') 0
# ('instructions', 'promo-code') 0
# ('instructions', 'update-account') 0
# ('instructions', 'search-membership') 0
# ('instructions', 'offer-refund') 0
# ('instructions', 'search-jeans') 0
# ('instructions', 'shipping-status') 0
# ('instructions', 'search-shirt') 0
# ('instructions', 'search-jacket') 0
# ('instructions', 'select-faq') 0
# ('instructions', 'subscription-status') 0
# ('search-jacket', 'enter-details') 0
# ('search-jacket', 'verify-identity') 0
# ('search-jacket', 'make-password') 0
# ('search-jacket', 'search-policy') 0
# ('search-jacket', 'validate-purchase') 0
# ('search-jacket', 'membership') 0
# ('search-jacket', 'ask-the-oracle') 0
# ('search-jacket', 'update-order') 0
# ('search-jacket', 'promo-code') 0
# ('search-jacket', 'update-account') 0
# ('search-jacket', 'make-purchase') 0
# ('search-jacket', 'offer-refund') 0
# ('search-jacket', 'record-reason') 0
# ('search-jacket', 'shipping-status') 0
# ('search-jacket', 'log-out-in') 0
# ('search-jacket', 'subscription-status') 0
# ('search-jacket', 'send-link') 0
# ('log-out-in', 'verify-identity') 0
# ('log-out-in', 'make-password') 0
# ('log-out-in', 'search-timing') 0
# ('log-out-in', 'search-policy') 0
# ('log-out-in', 'validate-purchase') 0
# ('log-out-in', 'membership') 0
# ('log-out-in', 'ask-the-oracle') 0
# ('log-out-in', 'update-order') 0
# ('log-out-in', 'promo-code') 0
# ('log-out-in', 'update-account') 0
# ('log-out-in', 'search-membership') 0
# ('log-out-in', 'search-jeans') 0
# ('log-out-in', 'search-shirt') 0
# ('log-out-in', 'search-jacket') 0
# ('log-out-in', 'select-faq') 0
# ('log-out-in', 'subscription-status') 0
# ('log-out-in', 'send-link') 0
# ('log-out-in', 'search-pricing') 0
# ('select-faq', 'verify-identity') 0
# ('select-faq', 'make-password') 0
# ('select-faq', 'validate-purchase') 0
# ('select-faq', 'update-order') 0
# ('select-faq', 'make-purchase') 0
# ('select-faq', 'offer-refund') 0
# ('select-faq', 'record-reason') 0
# ('select-faq', 'shipping-status') 0
# ('select-faq', 'search-jacket') 0
# ('select-faq', 'log-out-in') 0
# ('select-faq', 'subscription-status') 0
# ('subscription-status', 'make-password') 0
# ('subscription-status', 'search-timing') 0
# ('subscription-status', 'search-policy') 0
# ('subscription-status', 'search-boots') 0
# ('subscription-status', 'search-membership') 0
# ('subscription-status', 'search-jeans') 0
# ('subscription-status', 'shipping-status') 0
# ('subscription-status', 'search-shirt') 0
# ('subscription-status', 'instructions') 0
# ('subscription-status', 'search-jacket') 0
# ('subscription-status', 'select-faq') 0
# ('subscription-status', 'search-pricing') 0
# ('send-link', 'make-password') 0
# ('send-link', 'search-timing') 0
# ('send-link', 'search-policy') 0
# ('send-link', 'search-boots') 0
# ('send-link', 'try-again') 0
# ('send-link', 'ask-the-oracle') 0
# ('send-link', 'update-order') 0
# ('send-link', 'promo-code') 0
# ('send-link', 'search-membership') 0
# ('send-link', 'make-purchase') 0
# ('send-link', 'offer-refund') 0
# ('send-link', 'notify-team') 0
# ('send-link', 'record-reason') 0
# ('send-link', 'search-jeans') 0
# ('send-link', 'shipping-status') 0
# ('send-link', 'search-shirt') 0
# ('send-link', 'instructions') 0
# ('send-link', 'search-jacket') 0
# ('send-link', 'log-out-in') 0
# ('send-link', 'select-faq') 0
# ('send-link', 'search-pricing') 0
# ('search-pricing', 'make-password') 0
# ('search-pricing', 'validate-purchase') 0
# ('search-pricing', 'update-account') 0
# ('search-pricing', 'offer-refund') 0
# ('search-pricing', 'record-reason') 0
# ('search-pricing', 'shipping-status') 0
# ('search-pricing', 'instructions') 0
# ('search-pricing', 'log-out-in') 0
# ('search-pricing', 'subscription-status') 0
# ('search-pricing', 'send-link') 0
# counter:  900

# %%
# count the frequency of each state
transition_matrix = {}
for state1 in possible_states:
    transition_matrix[state1] = {}
    for state2 in possible_states:
        transition_matrix[state1][state2] = 0
    
    for key, value in transition_count.items():
        if state1 == key[0]:
            transition_matrix[state1][key[1]] = value

print("transition_matrix: ", transition_matrix)
print(len(transition_matrix['pull-up-account']))

# convert count to probability
for state1 in possible_states:
    sum_count = sum(transition_matrix[state1].values())
    for state2 in possible_states:
        if sum_count != 0:
            transition_matrix[state1][state2] = transition_matrix[state1][state2] / sum_count
        
print("transition_matrix: ", transition_matrix)
print(len(transition_matrix['pull-up-account']))
print("sum of probability: ", sum(transition_matrix['pull-up-account'].values()))
print("sum of probability: ", sum(transition_matrix['enter-details'].values()))
# Out:
# transition_matrix:  {'pull-up-account': {'pull-up-account': 90, 'enter-details': 439, 'verify-identity': 2175, 'make-password': 15, 'search-timing': 0, 'search-policy': 0, 'validate-purchase': 1376, 'search-faq': 117, 'membership': 31, 'search-boots': 0, 'try-again': 35, 'ask-the-oracle': 289, 'update-order': 3, 'promo-code': 17, 'update-account': 1, 'search-membership': 0, 'make-purchase': 9, 'offer-refund': 5, 'notify-team': 91, 'record-reason': 687, 'search-jeans': 0, 'shipping-status': 138, 'search-shirt': 0, 'instructions': 3, 'search-jacket': 0, 'log-out-in': 20, 'select-faq': 0, 'subscription-status': 42, 'send-link': 1, 'search-pricing': 0}, 'enter-details': {'pull-up-account': 1, 'enter-details': 65, 'verify-identity': 3, 'make-password': 237, 'search-timing': 0, 'search-policy': 0, 'validate-purchase': 3, 'search-faq': 3, 'membership': 5, 'search-boots': 0, 'try-again': 37, 'ask-the-oracle': 3, 'update-order': 370, 'promo-code': 1, 'update-account': 160, 'search-membership': 0, 'make-purchase': 28, 'offer-refund': 124, 'notify-team': 43, 'record-reason': 7, 'search-jeans': 0, 'shipping-status': 4, 'search-shirt': 0, 'instructions': 2, 'search-jacket': 0, 'log-out-in': 41, 'select-faq': 0, 'subscription-status': 2, 'send-link': 301, 'search-pricing': 0}, 'verify-identity': {'pull-up-account': 46, 'enter-details': 154, 'verify-identity': 191, 'make-password': 20, 'search-timing': 0, 'search-policy': 0, 'validate-purchase': 277, 'search-faq': 12, 'membership': 251, 'search-boots': 0, 'try-again': 1, 'ask-the-oracle': 421, 'update-order': 35, 'promo-code': 145, 'update-account': 184, 'search-membership': 0, 'make-purchase': 13, 'offer-refund': 17, 'notify-team': 3, 'record-reason': 35, 'search-jeans': 0, 'shipping-status': 332, 'search-shirt': 0, 'instructions': 1, 'search-jacket': 0, 'log-out-in': 0, 'select-faq': 0, 'subscription-status': 386, 'send-link': 6, 'search-pricing': 0}, 'make-password': {'pull-up-account': 0, 'enter-details': 4, 'verify-identity': 0, 'make-password': 9, 'search-timing': 0, 'search-policy': 0, 'validate-purchase': 0, 'search-faq': 1, 'membership': 0, 'search-boots': 0, 'try-again': 0, 'ask-the-oracle': 0, 'update-order': 0, 'promo-code': 0, 'update-account': 0, 'search-membership': 0, 'make-purchase': 1, 'offer-refund': 0, 'notify-team': 0, 'record-reason': 0, 'search-jeans': 0, 'shipping-status': 0, 'search-shirt': 0, 'instructions': 0, 'search-jacket': 0, 'log-out-in': 0, 'select-faq': 0, 'subscription-status': 1, 'send-link': 2, 'search-pricing': 0}, 'search-timing': {'pull-up-account': 3, 'enter-details': 1, 'verify-identity': 0, 'make-password': 0, 'search-timing': 3, 'search-policy': 17, 'validate-purchase': 0, 'search-faq': 1, 'membership': 0, 'search-boots': 0, 'try-again': 1, 'ask-the-oracle': 2, 'update-order': 0, 'promo-code': 2, 'update-account': 0, 'search-membership': 22, 'make-purchase': 1, 'offer-refund': 0, 'notify-team': 0, 'record-reason': 1, 'search-jeans': 2, 'shipping-status': 0, 'search-shirt': 1, 'instructions': 0, 'search-jacket': 0, 'log-out-in': 0, 'select-faq': 147, 'subscription-status': 1, 'send-link': 0, 'search-pricing': 12}, 'search-policy': {'pull-up-account': 7, 'enter-details': 1, 'verify-identity': 1, 'make-password': 0, 'search-timing': 13, 'search-policy': 7, 'validate-purchase': 0, 'search-faq': 2, 'membership': 4, 'search-boots': 1, 'try-again': 7, 'ask-the-oracle': 2, 'update-order': 0, 'promo-code': 0, 'update-account': 1, 'search-membership': 18, 'make-purchase': 0, 'offer-refund': 0, 'notify-team': 0, 'record-reason': 1, 'search-jeans': 1, 'shipping-status': 0, 'search-shirt': 1, 'instructions': 4, 'search-jacket': 0, 'log-out-in': 2, 'select-faq': 150, 'subscription-status': 1, 'send-link': 0, 'search-pricing': 23}, 'validate-purchase': {'pull-up-account': 6, 'enter-details': 116, 'verify-identity': 32, 'make-password': 1, 'search-timing': 0, 'search-policy': 0, 'validate-purchase': 88, 'search-faq': 12, 'membership': 350, 'search-boots': 0, 'try- ...
# 30
# transition_matrix:  {'pull-up-account': {'pull-up-account': 0.016117478510028652, 'enter-details': 0.07861747851002865, 'verify-identity': 0.3895057306590258, 'make-password': 0.0026862464183381087, 'search-timing': 0.0, 'search-policy': 0.0, 'validate-purchase': 0.24641833810888253, 'search-faq': 0.02095272206303725, 'membership': 0.005551575931232092, 'search-boots': 0.0, 'try-again': 0.006267908309455587, 'ask-the-oracle': 0.051755014326647565, 'update-order': 0.0005372492836676218, 'promo-code': 0.0030444126074498567, 'update-account': 0.00017908309455587392, 'search-membership': 0.0, 'make-purchase': 0.0016117478510028654, 'offer-refund': 0.0008954154727793697, 'notify-team': 0.016296561604584526, 'record-reason': 0.12303008595988539, 'search-jeans': 0.0, 'shipping-status': 0.0247134670487106, 'search-shirt': 0.0, 'instructions': 0.0005372492836676218, 'search-jacket': 0.0, 'log-out-in': 0.0035816618911174787, 'select-faq': 0.0, 'subscription-status': 0.007521489971346705, 'send-link': 0.00017908309455587392, 'search-pricing': 0.0}, 'enter-details': {'pull-up-account': 0.0006944444444444445, 'enter-details': 0.04513888888888889, 'verify-identity': 0.0020833333333333333, 'make-password': 0.16458333333333333, 'search-timing': 0.0, 'search-policy': 0.0, 'validate-purchase': 0.0020833333333333333, 'search-faq': 0.0020833333333333333, 'membership': 0.003472222222222222, 'search-boots': 0.0, 'try-again': 0.025694444444444443, 'ask-the-oracle': 0.0020833333333333333, 'update-order': 0.2569444444444444, 'promo-code': 0.0006944444444444445, 'update-account': 0.1111111111111111, 'search-membership': 0.0, 'make-purchase': 0.019444444444444445, 'offer-refund': 0.08611111111111111, 'notify-team': 0.029861111111111113, 'record-reason': 0.004861111111111111, 'search-jeans': 0.0, 'shipping-status': 0.002777777777777778, 'search-shirt': 0.0, 'instructions': 0.001388888888888889, 'search-jacket': 0.0, 'log-out-in': 0.02847222222222222, 'select-faq': 0.0, 'subscription-status': 0.001388888888888889, 'send-link': 0.20902777777777778, 'search-pricing': 0.0}, 'verify-identity': {'pull-up-account': 0.01818181818181818, 'enter-details': 0.06086956521739131, 'verify-identity': 0.07549407114624505, 'make-password': 0.007905138339920948, 'search-timing': 0.0, 'search-policy': 0.0, 'validate-purchase': 0.10948616600790514, 'search-faq': 0.0047430830039525695, 'membership': 0.0992094861660079, 'search-boots': 0.0, 'try-again': 0.0003952569169960474, 'ask-the-oracle': 0.16640316205533598, 'update-order': 0.01383399209486166, 'promo-code': 0.05731225296442688, 'update-account': 0.07272727272727272, 'search-membership': 0.0, 'make-purchase': 0.005138339920948616, 'offer-refund': 0.0067193675889328066, 'notify-team': 0.0011857707509881424, 'record-reason': 0.01383399209486166, 'search-jeans': 0.0, 'shipping-status': 0.13122529644268774, 'search-shirt': 0.0, 'instructions': 0.0003952569169960474, 'search-jacket': 0.0, 'log-out-in': 0.0, 'select-faq': 0.0, 'subscription-status': 0.15256916996047432, 'send-link': 0.0023715415019762848, 'search-pricing': 0.0}, 'make-password': {'pull-up-account': 0.0, 'enter-details': 0.2222222222222222, 'verify-identity': 0.0, 'make-password': 0.5, 'search-timing': 0.0, 'search-policy': 0.0, 'validate-purchase': 0.0, 'search-faq': 0.05555555555555555, 'membership': 0.0, 'search-boots': 0.0, 'try-again': 0.0, 'ask-the-oracle': 0.0, 'update-order': 0.0, 'promo-code': 0.0, 'update-account': 0.0, 'search-membership': 0.0, 'make-purchase': 0.05555555555555555, 'offer-refund': 0.0, 'notify-team': 0.0, 'record-reason': 0.0, 'search-jeans': 0.0, 'shipping-status': 0.0, 'search-shirt': 0.0, 'instructions': 0.0, 'search-jacket': 0.0, 'log-out-in': 0.0, 'select-faq': 0.0, 'subscription-status': 0.05555555555555555, 'send-link': 0.1111111111111111, 'search-pricing': 0.0}, 'search-timing': {'pull-up-account': 0.013824884792626729, 'enter-details': 0.004608294930875576, 'verify-identity': 0.0, 'make-password': 0.0, 'search-timing': 0.013 ...
# 30
# sum of probability:  0.9999999999999997
# sum of probability:  0.9999999999999999

# %%
# convert to mdp:
# here we use the dot format to represent the mdp
'''
digraph learned_mdp {
s0 [label="init"];
s1 [label="pull-up-account"];
s2 [label="end"];
s3 [label="enter-details"];
s0 -> s1  [label="pull-up-account:0.03125"];
s0 -> s3  [label="enter-details:0.03125"];
s0 -> s2  [label="end:0.03125"];
s1 -> s3  [label="pull-up-account:0.2202970297029703"];
s1 -> s1  [label="pull-up-account:0.7797029702970297"];
s1 -> s3  [label="enter-details:0.03125"];
s1 -> s2  [label="end:0.03125"];
s2 -> s1  [label="pull-up-account:0.03125"];
s2 -> s3  [label="enter-details:0.03125"];
s2 -> s2  [label="end:0.03125"];
s3 -> s1  [label="pull-up-account:0.03125"];
s3 -> s3  [label="enter-details:0.03125"];
s3 -> s2  [label="end:0.03125"];
__start0 [label="", shape=none];
__start0 -> s0  [label=""];
}
'''

# ['find_hotel', 'book_hotel', 'find_train', 'book_train', 'find_attraction', 'find_restaurant', 'book_restaurant', 'find_hospital', 'book_taxi', 'find_taxi', 'find_bus', 'find_police']

'''
action_rate:  {
  "pull-up-account": 0.6694050286283296,
  "search-faq": 0.2045058501369181,
  "enter-details": 0.006596962907642519,
  "offer-refund": 0.0011202389843166542,
  "verify-identity": 0.017301468757779437,
  "try-again": 0.035225292506845904,
  "validate-purchase": 0.0043564849390092105,
  "notify-team": 0.01157580283793876,
  "log-out-in": 0.032984814538212594,
  "record-reason": 0.003983071944236993,
  "make-purchase": 0.0008712969878018422,
  "instructions": 0.0028628329599203386,
  "shipping-status": 0.0017425939756036844,
  "membership": 0.0036096589494647746,
  "ask-the-oracle": 0.0008712969878018422,
  "subscription-status": 0.0013691809808314662,
  "update-account": 0.0004978839930296241,
  "make-password": 0.00024894199651481205,
  "update-order": 0.0003734129947722181,
  "promo-code": 0.0003734129947722181,
  "send-link": 0.00012447099825740602
}
'''

# convert transition_matrix to dot format
def convert_to_dot(transition_matrix):
    dot_str = "digraph learned_mdp {\n"
    dot_str += "s0 [label=\"init\"];\n"
    for i in range(len(possible_states)):
        dot_str += "s" + str(i+1) + " [label=\"" + possible_states[i] + "\"];\n"
    dot_str += "s31 [label=\"end\"];\n"    

    dot_str += "s0 -> s0  [label=\"init:1.0\"];\n"
    # dot_str += "s0 -> s1  [label=\"action:0.215\"];\n"
    # dot_str += "s0 -> s2  [label=\"action:0.00125\"];\n"
    # dot_str += "s0 -> s3  [label=\"action:0.22875\"];\n"
    # dot_str += "s0 -> s4  [label=\"action:0.0\"];\n"
    # dot_str += "s0 -> s5  [label=\"action:0.1675\"];\n"
    # dot_str += "s0 -> s6  [label=\"action:0.2875\"];\n"
    # dot_str += "s0 -> s7  [label=\"action:0.00125\"];\n"
    # dot_str += "s0 -> s8  [label=\"action:0.03625\"];\n"
    # dot_str += "s0 -> s9  [label=\"action:0.0\"];\n"
    # dot_str += "s0 -> s10  [label=\"action:0.0325\"];\n"
    # dot_str += "s0 -> s11  [label=\"action:0.0\"];\n"
    # dot_str += "s0 -> s12  [label=\"action:0.03\"];\n"
    for i in range(len(possible_states)):
        if possible_states[i] in action_rate:
            dot_str += "s0 -> s" + str(i+1) + "  [label=\"action:" + str(action_rate[possible_states[i]]) + "\"];\n"
        else:
            dot_str += "s0 -> s" + str(i+1) + "  [label=\"action:0.0\"];\n"
    dot_str += "s0 -> s31  [label=\"end:1\"];\n"

    for j in range(len(possible_states)):
        index = j
        state1 = possible_states[j]
        dot_str += "s" + str(index+1) + " -> s0  [label=\"init:1.0\"];\n"
        for k in range(len(possible_states)):
            index2 = k
            state2 = possible_states[k]
            if transition_matrix[state1][state2] != 0:
                dot_str += "s" + str(index+1) + " -> s" + str(index2+1) + "  [label=\"" + "action" + ":" + str(transition_matrix[state1][state2]) + "\"];\n"
        dot_str += 's' + str(index+1) + ' -> s31' + ' [label="end:1.0"];\n'
    
    dot_str += 's31 -> s31 [label="init:1.0"];\n'
    dot_str += 's31 -> s31  [label="action:1.0"];\n'
    dot_str += 's31 -> s31  [label="end:1.0"];\n'

    dot_str += "__start0 [label=\"\", shape=none];\n"
    dot_str += "__start0 -> s0  [label=\"\"];\n"
    dot_str += "}"

    return dot_str

dot_str = convert_to_dot(transition_matrix)
print(dot_str)

# write the dot string to a file
with open(f"learned_mdp_abcd_{data_part}.dot", "w") as f:
    f.write(dot_str)
# Out:
# digraph learned_mdp {
# s0 [label="init"];
# s1 [label="pull-up-account"];
# s2 [label="enter-details"];
# s3 [label="verify-identity"];
# s4 [label="make-password"];
# s5 [label="search-timing"];
# s6 [label="search-policy"];
# s7 [label="validate-purchase"];
# s8 [label="search-faq"];
# s9 [label="membership"];
# s10 [label="search-boots"];
# s11 [label="try-again"];
# s12 [label="ask-the-oracle"];
# s13 [label="update-order"];
# s14 [label="promo-code"];
# s15 [label="update-account"];
# s16 [label="search-membership"];
# s17 [label="make-purchase"];
# s18 [label="offer-refund"];
# s19 [label="notify-team"];
# s20 [label="record-reason"];
# s21 [label="search-jeans"];
# s22 [label="shipping-status"];
# s23 [label="search-shirt"];
# s24 [label="instructions"];
# s25 [label="search-jacket"];
# s26 [label="log-out-in"];
# s27 [label="select-faq"];
# s28 [label="subscription-status"];
# s29 [label="send-link"];
# s30 [label="search-pricing"];
# s31 [label="end"];
# s0 -> s0  [label="init:1.0"];
# s0 -> s1  [label="action:0.6694050286283296"];
# s0 -> s2  [label="action:0.006596962907642519"];
# s0 -> s3  [label="action:0.017301468757779437"];
# s0 -> s4  [label="action:0.00024894199651481205"];
# s0 -> s5  [label="action:0.0"];
# s0 -> s6  [label="action:0.0"];
# s0 -> s7  [label="action:0.0043564849390092105"];
# s0 -> s8  [label="action:0.2045058501369181"];
# s0 -> s9  [label="action:0.0036096589494647746"];
# s0 -> s10  [label="action:0.0"];
# s0 -> s11  [label="action:0.035225292506845904"];
# s0 -> s12  [label="action:0.0008712969878018422"];
# s0 -> s13  [label="action:0.0003734129947722181"];
# s0 -> s14  [label="action:0.0003734129947722181"];
# s0 -> s15  [label="action:0.0004978839930296241"];
# s0 -> s16  [label="action:0.0"];
# s0 -> s17  [label="action:0.0008712969878018422"];
# s0 -> s18  [label="action:0.0011202389843166542"];
# s0 -> s19  [label="action:0.01157580283793876"];
# s0 -> s20  [label="action:0.003983071944236993"];
# s0 -> s21  [label="action:0.0"];
# s0 -> s22  [label="action:0.0017425939756036844"];
# s0 -> s23  [label="action:0.0"];
# s0 -> s24  [label="action:0.0028628329599203386"];
# s0 -> s25  [label="action:0.0"];
# s0 -> s26  [label="action:0.032984814538212594"];
# s0 -> s27  [label="action:0.0"];
# s0 -> s28  [label="action:0.0013691809808314662"];
# s0 -> s29  [label="action:0.00012447099825740602"];
# s0 -> s30  [label="action:0.0"];
# s0 -> s31  [label="end:1"];
# s1 -> s0  [label="init:1.0"];
# s1 -> s1  [label="action:0.016117478510028652"];
# s1 -> s2  [label="action:0.07861747851002865"];
# s1 -> s3  [label="action:0.3895057306590258"];
# s1 -> s4  [label="action:0.0026862464183381087"];
# s1 -> s7  [label="action:0.24641833810888253"];
# s1 -> s8  [label="action:0.02095272206303725"];
# s1 -> s9  [label="action:0.005551575931232092"];
# s1 -> s11  [label="action:0.006267908309455587"];
# s1 -> s12  [label="action:0.051755014326647565"];
# s1 -> s13  [label="action:0.0005372492836676218"];
# s1 -> s14  [label="action:0.0030444126074498567"];
# s1 -> s15  [label="action:0.00017908309455587392"];
# s1 -> s17  [label="action:0.0016117478510028654"];
# s1 -> s18  [label="action:0.0008954154727793697"];
# s1 -> s19  [label="action:0.016296561604584526"];
# s1 -> s20  [label="action:0.12303008595988539"];
# s1 -> s22  [label="action:0.0247134670487106"];
# s1 -> s24  [label="action:0.0005372492836676218"];
# s1 -> s26  [label="action:0.0035816618911174787"];
# s1 -> s28  [label="action:0.007521489971346705"];
# s1 -> s29  [label="action:0.00017908309455587392"];
# s1 -> s31 [label="end:1.0"];
# s2 -> s0  [label="init:1.0"];
# s2 -> s1  [label="action:0.0006944444444444445"];
# s2 -> s2  [label="action:0.04513888888888889"];
# s2 -> s3  [label="action:0.0020833333333333333"];
# s2 -> s4  [label="action:0.16458333333333333"];
# s2 -> s7  [label="action:0.0020833333333333333"];
# s2 -> s8  [label="action:0.0020833333333333333"];
# s2 -> s9  [label="action:0.003472222222222222"];
# s2 -> s11  [label="action:0.025694444444444443"];
# s2 -> s12  [label="action:0.0020833333333333333"];
# s2 -> s13  [label="action:0.2569444444444444"];
# s2 -> s14  [label="action:0.0006944444444444445"];
# s2 -> s15  [label="action:0.1111111111111111"];
# s2 -> s17  [label="action:0.019444444444444445"];
# s2 -> s18  [label="action:0.08611111111111111"];
# s2 -> s19  [label="action:0.029861111111111113"];
# s2 -> s20  [label="action:0.004861111111111111"];
# s2 -> s22  [label="action:0.002777777777777778"];
# s2 -> s24  [label="action:0.001388888888888889"];
# s2 -> s26  [label="action:0.02847222222222222"];
# s2 -> s28  [label="action:0.001388888888888889"];
# s2 -> s29  [label="action:0.20902777777777778"];
# s2 -> s31 [label="end:1.0"];
# s3 -> s0  [label="init:1.0"];
# s3 -> s1  [label="action:0.01818181818181818"];
# s3 -> s2  [label="action:0.06086956521739131"];
# s3 -> s3  [label="action:0.07549407114624505"];
# s3 -> s4  [label="action:0.007905138339920948"];
# s3 -> s7  [label="action:0.10948616600790514"];
# s3 -> s8  [label="action:0.0047430830039525695"];
# s3 -> s9  [label="action:0.0992094861660079"];
# s3 -> s11  [label="action:0.0003952569169960474"];
# s3 -> s12  [label="action:0.16640316205533598"];
# s3 -> s13  [label="action:0.01383399209486166"];
# s3 -> s14  [label="action:0.05731225296442688"];
# s3 -> s15  [label="action:0.07272727272727272"];
# s3 -> s17  [label="action:0.005138339920948616"];
# s3 -> s18  [label="action:0.0067193675889328066"];
# s3 -> s19  [label="action:0.0011857707509881424"];
# s3 -> s20  [label="action:0.01383399209486166"];
# s3 -> s22  [label="action:0.13122529644268774"];
# s3 -> s24  [label="action:0.0003952569169960474"];
# s3 -> s28  [label="action:0.15256916996047432"];
# s3 -> s29  [label="action:0.0023715415019762848"];
# s3 -> s31 [label="end:1.0"];
# s4 -> s0  [label="init:1.0"];
# s4 -> s2  [label="action:0.2222222222222222"];
# s4 -> s4  [label="action:0.5"];
# s4 -> s8  [label="action:0.05555555555555555"];
# s4 -> s17  [label="action:0.05555555555555555"];
# s4 -> s28  [label="action:0.05555555555555555"];
# s4 -> s29  [label="action:0.1111111111111111"];
# s4 -> s31 [label="end:1.0"];
# s5 -> s0  [label="init:1.0"];
# s5 -> s1  [label="action:0.013824884792626729"];
# s5 -> s2  [label="action:0.004608294930875576"];
# s5 -> s5  [label="action:0.013824884792626729"];
# s5 -> s6  [label="action:0.07834101382488479"];
# s5 -> s8  [label="action:0.004608294930875576"];
# s5 -> s11  [label="action:0.004608294930875576"];
# s5 -> s12  [label="action:0.009216589861751152"];
# s5 -> s14  [label="action:0.009216589861751152"];
# s5 -> s16  [label="action:0.10138248847926268"];
# s5 -> s17  [label="action:0.004608294930875576"];
# s5 -> s20  [label="action:0.004608294930875576"];
# s5 -> s21  [label="action:0.009216589861751152"];
# s5 -> s23  [label="action:0.004608294930875576"];
# s5 -> s27  [label="action:0.6774193548387096"];
# s5 -> s28  [label="action:0.004608294930875576"];
# s5 -> s30  [label="action:0.055299539170506916"];
# s5 -> s31 [label="end:1.0"];
# s6 -> s0  [label="init:1.0"];
# s6 -> s1  [label="action:0.02834008097165992"];
# s6 -> s2  [label="action:0.004048582995951417"];
# s6 -> s3  [label="action:0.004048582995951417"];
# s6 -> s5  [label="action:0.05263157894736842"];
# s6 -> s6  [label="action:0.02834008097165992"];
# s6 -> s8  [label="action:0.008097165991902834"];
# s6 -> s9  [label="action:0.016194331983805668"];
# s6 -> s10  [label="action:0.004048582995951417"];
# s6 -> s11  [label="action:0.02834008097165992"];
# s6 -> s12  [label="action:0.008097165991902834"];
# s6 -> s15  [label="action:0.004048582995951417"];
# s6 -> s16  [label="action:0.0728744939271255"];
# s6 -> s20  [label="action:0.004048582995951417"];
# s6 -> s21  [label="action:0.004048582995951417"];
# s6 -> s23  [label="action:0.004048582995951417"];
# s6 -> s24  [label="action:0.016194331983805668"];
# s6 -> s26  [label="action:0.008097165991902834"];
# s6 -> s27  [label="action:0.6072874493927125"];
# s6 -> s28  [label="action:0.004048582995951417"];
# s6 -> s30  [label="action:0.0931174089068826"];
# s6 -> s31 [label="end:1.0"];
# s7 -> s0  [label="init:1.0"];
# s7 -> s1  [label="action:0.0034266133637921186"];
# s7 -> s2  [label="action:0.06624785836664764"];
# s7 -> s3  [label="action:0.018275271273557967"];
# s7 -> s4  [label="action:0.0005711022272986865"];
# s7 -> s7  [label="action:0.05025699600228441"];
# s7 -> s8  [label="action:0.006853226727584237"];
# s7 -> s9  [label="action:0.19988577955454026"];
# s7 -> s12  [label="action:0.18275271273557966"];
# s7 -> s13  [label="action:0.11536264991433466"];
# s7 -> s14  [label="action:0.0017133066818960593"];
# s7 -> s15  [label="action:0.0005711022272986865"];
# s7 -> s17  [label="action:0.0034266133637921186"];
# s7 -> s18  [label="action:0.018846373500856654"];
# s7 -> s19  [label="action:0.0028555111364934323"];
# s7 -> s20  [label="action:0.23186750428326672"];
# s7 -> s22  [label="action:0.08966304968589378"];
# s7 -> s28  [label="action:0.006853226727584237"];
# s7 -> s29  [label="action:0.0005711022272986865"];
# s7 -> s31 [label="end:1.0"];
# s8 -> s0  [label="init:1.0"];
# s8 -> s1  [label="action:0.006220839813374806"];
# s8 -> s2  [label="action:0.0010368066355624676"];
# s8 -> s3  [label="action:0.0015552099533437014"];
# s8 -> s5  [label="action:0.10938310005184033"];
# s8 -> s6  [label="action:0.10523587350959046"];
# s8 -> s7  [label="action:0.0005184033177812338"];
# s8 -> s8  [label="action:0.0036288232244686366"];
# s8 -> s9  [label="action:0.007257646448937273"];
# s8 -> s10  [label="action:0.12441679626749612"];
# s8 -> s11  [label="action:0.00933125972006221"];
# s8 -> s12  [label="action:0.0010368066355624676"];
# s8 -> s14  [label="action:0.0005184033177812338"];
# s8 -> s16  [label="action:0.15966822187662"];
# s8 -> s19  [label="action:0.0015552099533437014"];
# s8 -> s20  [label="action:0.0005184033177812338"];
# s8 -> s21  [label="action:0.11923276308968378"];
# s8 -> s23  [label="action:0.10368066355624676"];
# s8 -> s24  [label="action:0.004665629860031105"];
# s8 -> s25  [label="action:0.11612234318299637"];
# s8 -> s26  [label="action:0.00673924313115604"];
# s8 -> s27  [label="action:0.004665629860031105"];
# s8 -> s28  [label="action:0.0005184033177812338"];
# s8 -> s30  [label="action:0.11249351995852773"];
# s8 -> s31 [label="end:1.0"];
# s9 -> s0  [label="init:1.0"];
# s9 -> s1  [label="action:0.0022123893805309734"];
# s9 -> s2  [label="action:0.35951327433628316"];
# s9 -> s3  [label="action:0.004424778761061947"];
# s9 -> s6  [label="action:0.0011061946902654867"];
# s9 -> s7  [label="action:0.0022123893805309734"];
# s9 -> s8  [label="action:0.06858407079646017"];
# s9 -> s9  [label="action:0.04314159292035398"];
# s9 -> s11  [label="action:0.004424778761061947"];
# s9 -> s12  [label="action:0.05420353982300885"];
# s9 -> s13  [label="action:0.13274336283185842"];
# s9 -> s14  [label="action:0.07743362831858407"];
# s9 -> s15  [label="action:0.05309734513274336"];
# s9 -> s16  [label="action:0.00663716814159292"];
# s9 -> s17  [label="action:0.03871681415929203"];
# s9 -> s18  [label="action:0.10619469026548672"];
# s9 -> s19  [label="action:0.012168141592920354"];
# s9 -> s20  [label="action:0.007743362831858407"];
# s9 -> s21  [label="action:0.0011061946902654867"];
# s9 -> s22  [label="action:0.004424778761061947"];
# s9 -> s24  [label="action:0.0055309734513274336"];
# s9 -> s28  [label="action:0.012168141592920354"];
# s9 -> s29  [label="action:0.0022123893805309734"];
# s9 -> s31 [label="end:1.0"];
# s10 -> s0  [label="init:1.0"];
# s10 -> s1  [label="action:0.015384615384615385"];
# s10 -> s6  [label="action:0.020512820512820513"];
# s10 -> s8  [label="action:0.015384615384615385"];
# s10 -> s10  [label="action:0.015384615384615385"];
# s10 -> s11  [label="action:0.005128205128205128"];
# s10 -> s16  [label="action:0.005128205128205128"];
# s10 -> s17  [label="action:0.005128205128205128"];
# s10 -> s18  [label="action:0.005128205128205128"];
# s10 -> s20  [label="action:0.010256410256410256"];
# s10 -> s23  [label="action:0.005128205128205128"];
# s10 -> s25  [label="action:0.010256410256410256"];
# s10 -> s26  [label="action:0.005128205128205128"];
# s10 -> s27  [label="action:0.8307692307692308"];
# s10 -> s29  [label="action:0.005128205128205128"];
# s10 -> s30  [label="action:0.046153846153846156"];
# s10 -> s31 [label="end:1.0"];
# s11 -> s0  [label="init:1.0"];
# s11 -> s1  [label="action:0.004282655246252677"];
# s11 -> s2  [label="action:0.09635974304068523"];
# s11 -> s5  [label="action:0.0021413276231263384"];
# s11 -> s8  [label="action:0.008565310492505354"];
# s11 -> s9  [label="action:0.004282655246252677"];
# s11 -> s11  [label="action:0.014989293361884369"];
# s11 -> s12  [label="action:0.008565310492505354"];
# s11 -> s14  [label="action:0.0021413276231263384"];
# s11 -> s16  [label="action:0.0021413276231263384"];
# s11 -> s17  [label="action:0.021413276231263382"];
# s11 -> s19  [label="action:0.04068522483940043"];
# s11 -> s21  [label="action:0.0021413276231263384"];
# s11 -> s22  [label="action:0.004282655246252677"];
# s11 -> s24  [label="action:0.2012847965738758"];
# s11 -> s26  [label="action:0.582441113490364"];
# s11 -> s27  [label="action:0.004282655246252677"];
# s11 -> s31 [label="end:1.0"];
# s12 -> s0  [label="init:1.0"];
# s12 -> s1  [label="action:0.004149377593360996"];
# s12 -> s2  [label="action:0.005186721991701245"];
# s12 -> s3  [label="action:0.008298755186721992"];
# s12 -> s7  [label="action:0.00933609958506224"];
# s12 -> s8  [label="action:0.016597510373443983"];
# s12 -> s9  [label="action:0.21473029045643152"];
# s12 -> s11  [label="action:0.001037344398340249"];
# s12 -> s12  [label="action:0.016597510373443983"];
# s12 -> s13  [label="action:0.25"];
# s12 -> s14  [label="action:0.14937759336099585"];
# s12 -> s15  [label="action:0.08402489626556017"];
# s12 -> s17  [label="action:0.002074688796680498"];
# s12 -> s18  [label="action:0.06742738589211618"];
# s12 -> s19  [label="action:0.006224066390041493"];
# s12 -> s20  [label="action:0.017634854771784232"];
# s12 -> s22  [label="action:0.06016597510373444"];
# s12 -> s26  [label="action:0.005186721991701245"];
# s12 -> s28  [label="action:0.007261410788381743"];
# s12 -> s29  [label="action:0.07468879668049792"];
# s12 -> s31 [label="end:1.0"];
# s13 -> s0  [label="init:1.0"];
# s13 -> s1  [label="action:0.004405286343612335"];
# s13 -> s2  [label="action:0.09251101321585903"];
# s13 -> s3  [label="action:0.004405286343612335"];
# s13 -> s4  [label="action:0.004405286343612335"];
# s13 -> s8  [label="action:0.01762114537444934"];
# s13 -> s9  [label="action:0.013215859030837005"];
# s13 -> s13  [label="action:0.20704845814977973"];
# s13 -> s14  [label="action:0.00881057268722467"];
# s13 -> s15  [label="action:0.04405286343612335"];
# s13 -> s17  [label="action:0.4933920704845815"];
# s13 -> s18  [label="action:0.048458149779735685"];
# s13 -> s19  [label="action:0.00881057268722467"];
# s13 -> s20  [label="action:0.01762114537444934"];
# s13 -> s22  [label="action:0.013215859030837005"];
# s13 -> s24  [label="action:0.004405286343612335"];
# s13 -> s26  [label="action:0.004405286343612335"];
# s13 -> s28  [label="action:0.004405286343612335"];
# s13 -> s29  [label="action:0.00881057268722467"];
# s13 -> s31 [label="end:1.0"];
# s14 -> s0  [label="init:1.0"];
# s14 -> s2  [label="action:0.08"];
# s14 -> s3  [label="action:0.04"];
# s14 -> s7  [label="action:0.04"];
# s14 -> s9  [label="action:0.12"];
# s14 -> s12  [label="action:0.24"];
# s14 -> s13  [label="action:0.08"];
# s14 -> s14  [label="action:0.12"];
# s14 -> s15  [label="action:0.04"];
# s14 -> s17  [label="action:0.04"];
# s14 -> s18  [label="action:0.04"];
# s14 -> s20  [label="action:0.04"];
# s14 -> s29  [label="action:0.12"];
# s14 -> s31 [label="end:1.0"];
# s15 -> s0  [label="init:1.0"];
# s15 -> s1  [label="action:0.02531645569620253"];
# s15 -> s2  [label="action:0.02531645569620253"];
# s15 -> s3  [label="action:0.012658227848101266"];
# s15 -> s7  [label="action:0.0379746835443038"];
# s15 -> s8  [label="action:0.02531645569620253"];
# s15 -> s13  [label="action:0.05063291139240506"];
# s15 -> s15  [label="action:0.13924050632911392"];
# s15 -> s17  [label="action:0.012658227848101266"];
# s15 -> s18  [label="action:0.43037974683544306"];
# s15 -> s19  [label="action:0.012658227848101266"];
# s15 -> s20  [label="action:0.05063291139240506"];
# s15 -> s28  [label="action:0.02531645569620253"];
# s15 -> s29  [label="action:0.1518987341772152"];
# s15 -> s31 [label="end:1.0"];
# s16 -> s0  [label="init:1.0"];
# s16 -> s1  [label="action:0.02903225806451613"];
# s16 -> s2  [label="action:0.0064516129032258064"];
# s16 -> s3  [label="action:0.0064516129032258064"];
# s16 -> s5  [label="action:0.04516129032258064"];
# s16 -> s6  [label="action:0.15483870967741936"];
# s16 -> s8  [label="action:0.0064516129032258064"];
# s16 -> s9  [label="action:0.025806451612903226"];
# s16 -> s10  [label="action:0.0032258064516129032"];
# s16 -> s11  [label="action:0.0064516129032258064"];
# s16 -> s12  [label="action:0.0032258064516129032"];
# s16 -> s13  [label="action:0.0032258064516129032"];
# s16 -> s16  [label="action:0.012903225806451613"];
# s16 -> s18  [label="action:0.0032258064516129032"];
# s16 -> s19  [label="action:0.0064516129032258064"];
# s16 -> s20  [label="action:0.0064516129032258064"];
# s16 -> s22  [label="action:0.0032258064516129032"];
# s16 -> s24  [label="action:0.0032258064516129032"];
# s16 -> s27  [label="action:0.603225806451613"];
# s16 -> s28  [label="action:0.0032258064516129032"];
# s16 -> s29  [label="action:0.0064516129032258064"];
# s16 -> s30  [label="action:0.06129032258064516"];
# s16 -> s31 [label="end:1.0"];
# s17 -> s0  [label="init:1.0"];
# s17 -> s2  [label="action:0.07692307692307693"];
# s17 -> s3  [label="action:0.019230769230769232"];
# s17 -> s7  [label="action:0.019230769230769232"];
# s17 -> s8  [label="action:0.09615384615384616"];
# s17 -> s9  [label="action:0.019230769230769232"];
# s17 -> s11  [label="action:0.019230769230769232"];
# s17 -> s13  [label="action:0.019230769230769232"];
# s17 -> s14  [label="action:0.019230769230769232"];
# s17 -> s15  [label="action:0.019230769230769232"];
# s17 -> s17  [label="action:0.5961538461538461"];
# s17 -> s18  [label="action:0.019230769230769232"];
# s17 -> s19  [label="action:0.038461538461538464"];
# s17 -> s20  [label="action:0.019230769230769232"];
# s17 -> s26  [label="action:0.019230769230769232"];
# s17 -> s31 [label="end:1.0"];
# s18 -> s0  [label="init:1.0"];
# s18 -> s1  [label="action:0.12903225806451613"];
# s18 -> s2  [label="action:0.11290322580645161"];
# s18 -> s3  [label="action:0.04838709677419355"];
# s18 -> s7  [label="action:0.03225806451612903"];
# s18 -> s8  [label="action:0.04838709677419355"];
# s18 -> s9  [label="action:0.06451612903225806"];
# s18 -> s13  [label="action:0.03225806451612903"];
# s18 -> s15  [label="action:0.04838709677419355"];
# s18 -> s18  [label="action:0.3064516129032258"];
# s18 -> s19  [label="action:0.016129032258064516"];
# s18 -> s20  [label="action:0.11290322580645161"];
# s18 -> s22  [label="action:0.03225806451612903"];
# s18 -> s29  [label="action:0.016129032258064516"];
# s18 -> s31 [label="end:1.0"];
# s19 -> s0  [label="init:1.0"];
# s19 -> s1  [label="action:0.037037037037037035"];
# s19 -> s2  [label="action:0.01646090534979424"];
# s19 -> s3  [label="action:0.00823045267489712"];
# s19 -> s8  [label="action:0.012345679012345678"];
# s19 -> s11  [label="action:0.07407407407407407"];
# s19 -> s14  [label="action:0.1440329218106996"];
# s19 -> s15  [label="action:0.00411522633744856"];
# s19 -> s17  [label="action:0.2839506172839506"];
# s19 -> s19  [label="action:0.04938271604938271"];
# s19 -> s20  [label="action:0.02880658436213992"];
# s19 -> s22  [label="action:0.00411522633744856"];
# s19 -> s24  [label="action:0.07818930041152264"];
# s19 -> s26  [label="action:0.25925925925925924"];
# s19 -> s31 [label="end:1.0"];
# s20 -> s0  [label="init:1.0"];
# s20 -> s1  [label="action:0.017691659646166806"];
# s20 -> s2  [label="action:0.07750631844987363"];
# s20 -> s3  [label="action:0.2754844144903117"];
# s20 -> s7  [label="action:0.012636899747262006"];
# s20 -> s8  [label="action:0.004212299915754001"];
# s20 -> s9  [label="action:0.02106149957877001"];
# s20 -> s12  [label="action:0.2047177759056445"];
# s20 -> s13  [label="action:0.09941027801179445"];
# s20 -> s14  [label="action:0.02695871946082561"];
# s20 -> s15  [label="action:0.011794439764111205"];
# s20 -> s17  [label="action:0.005897219882055603"];
# s20 -> s18  [label="action:0.11457455770850884"];
# s20 -> s19  [label="action:0.08845829823083404"];
# s20 -> s20  [label="action:0.03706823925863521"];
# s20 -> s22  [label="action:0.0016849199663016006"];
# s20 -> s26  [label="action:0.0008424599831508003"];
# s20 -> s31 [label="end:1.0"];
# s21 -> s0  [label="init:1.0"];
# s21 -> s1  [label="action:0.019801980198019802"];
# s21 -> s5  [label="action:0.009900990099009901"];
# s21 -> s6  [label="action:0.01485148514851485"];
# s21 -> s8  [label="action:0.01485148514851485"];
# s21 -> s9  [label="action:0.0049504950495049506"];
# s21 -> s10  [label="action:0.009900990099009901"];
# s21 -> s21  [label="action:0.039603960396039604"];
# s21 -> s23  [label="action:0.01485148514851485"];
# s21 -> s24  [label="action:0.009900990099009901"];
# s21 -> s25  [label="action:0.024752475247524754"];
# s21 -> s26  [label="action:0.0049504950495049506"];
# s21 -> s27  [label="action:0.7871287128712872"];
# s21 -> s30  [label="action:0.04455445544554455"];
# s21 -> s31 [label="end:1.0"];
# s22 -> s0  [label="init:1.0"];
# s22 -> s1  [label="action:0.014173228346456693"];
# s22 -> s2  [label="action:0.004724409448818898"];
# s22 -> s3  [label="action:0.02204724409448819"];
# s22 -> s7  [label="action:0.2204724409448819"];
# s22 -> s8  [label="action:0.004724409448818898"];
# s22 -> s9  [label="action:0.2566929133858268"];
# s22 -> s11  [label="action:0.0015748031496062992"];
# s22 -> s12  [label="action:0.01732283464566929"];
# s22 -> s13  [label="action:0.2094488188976378"];
# s22 -> s15  [label="action:0.0031496062992125984"];
# s22 -> s17  [label="action:0.02047244094488189"];
# s22 -> s18  [label="action:0.16850393700787403"];
# s22 -> s19  [label="action:0.0015748031496062992"];
# s22 -> s20  [label="action:0.011023622047244094"];
# s22 -> s22  [label="action:0.04251968503937008"];
# s22 -> s28  [label="action:0.0015748031496062992"];
# s22 -> s31 [label="end:1.0"];
# s23 -> s0  [label="init:1.0"];
# s23 -> s1  [label="action:0.005813953488372093"];
# s23 -> s3  [label="action:0.005813953488372093"];
# s23 -> s5  [label="action:0.005813953488372093"];
# s23 -> s10  [label="action:0.01744186046511628"];
# s23 -> s11  [label="action:0.005813953488372093"];
# s23 -> s21  [label="action:0.005813953488372093"];
# s23 -> s23  [label="action:0.023255813953488372"];
# s23 -> s25  [label="action:0.029069767441860465"];
# s23 -> s27  [label="action:0.8372093023255814"];
# s23 -> s30  [label="action:0.06395348837209303"];
# s23 -> s31 [label="end:1.0"];
# s24 -> s0  [label="init:1.0"];
# s24 -> s1  [label="action:0.008695652173913044"];
# s24 -> s2  [label="action:0.02608695652173913"];
# s24 -> s3  [label="action:0.017391304347826087"];
# s24 -> s6  [label="action:0.02608695652173913"];
# s24 -> s8  [label="action:0.08695652173913043"];
# s24 -> s9  [label="action:0.034782608695652174"];
# s24 -> s11  [label="action:0.24347826086956523"];
# s24 -> s12  [label="action:0.008695652173913044"];
# s24 -> s17  [label="action:0.05217391304347826"];
# s24 -> s19  [label="action:0.23478260869565218"];
# s24 -> s20  [label="action:0.008695652173913044"];
# s24 -> s24  [label="action:0.05217391304347826"];
# s24 -> s26  [label="action:0.1826086956521739"];
# s24 -> s29  [label="action:0.008695652173913044"];
# s24 -> s30  [label="action:0.008695652173913044"];
# s24 -> s31 [label="end:1.0"];
# s25 -> s0  [label="init:1.0"];
# s25 -> s1  [label="action:0.005128205128205128"];
# s25 -> s5  [label="action:0.010256410256410256"];
# s25 -> s8  [label="action:0.005128205128205128"];
# s25 -> s10  [label="action:0.010256410256410256"];
# s25 -> s11  [label="action:0.005128205128205128"];
# s25 -> s16  [label="action:0.005128205128205128"];
# s25 -> s19  [label="action:0.005128205128205128"];
# s25 -> s21  [label="action:0.020512820512820513"];
# s25 -> s23  [label="action:0.005128205128205128"];
# s25 -> s24  [label="action:0.010256410256410256"];
# s25 -> s25  [label="action:0.03076923076923077"];
# s25 -> s27  [label="action:0.841025641025641"];
# s25 -> s30  [label="action:0.046153846153846156"];
# s25 -> s31 [label="end:1.0"];
# s26 -> s0  [label="init:1.0"];
# s26 -> s1  [label="action:0.007075471698113208"];
# s26 -> s2  [label="action:0.23820754716981132"];
# s26 -> s8  [label="action:0.007075471698113208"];
# s26 -> s10  [label="action:0.0023584905660377358"];
# s26 -> s11  [label="action:0.330188679245283"];
# s26 -> s17  [label="action:0.02358490566037736"];
# s26 -> s18  [label="action:0.0023584905660377358"];
# s26 -> s19  [label="action:0.04481132075471698"];
# s26 -> s20  [label="action:0.0023584905660377358"];
# s26 -> s22  [label="action:0.0023584905660377358"];
# s26 -> s24  [label="action:0.330188679245283"];
# s26 -> s26  [label="action:0.009433962264150943"];
# s26 -> s31 [label="end:1.0"];
# s27 -> s0  [label="init:1.0"];
# s27 -> s1  [label="action:0.08280254777070063"];
# s27 -> s2  [label="action:0.006369426751592357"];
# s27 -> s5  [label="action:0.01910828025477707"];
# s27 -> s6  [label="action:0.044585987261146494"];
# s27 -> s8  [label="action:0.01910828025477707"];
# s27 -> s9  [label="action:0.012738853503184714"];
# s27 -> s10  [label="action:0.006369426751592357"];
# s27 -> s11  [label="action:0.012738853503184714"];
# s27 -> s12  [label="action:0.012738853503184714"];
# s27 -> s14  [label="action:0.012738853503184714"];
# s27 -> s15  [label="action:0.006369426751592357"];
# s27 -> s16  [label="action:0.03184713375796178"];
# s27 -> s19  [label="action:0.012738853503184714"];
# s27 -> s21  [label="action:0.03184713375796178"];
# s27 -> s23  [label="action:0.012738853503184714"];
# s27 -> s24  [label="action:0.006369426751592357"];
# s27 -> s27  [label="action:0.6050955414012739"];
# s27 -> s29  [label="action:0.01910828025477707"];
# s27 -> s30  [label="action:0.044585987261146494"];
# s27 -> s31 [label="end:1.0"];
# s28 -> s0  [label="init:1.0"];
# s28 -> s1  [label="action:0.013015184381778741"];
# s28 -> s2  [label="action:0.3188720173535792"];
# s28 -> s3  [label="action:0.021691973969631236"];
# s28 -> s7  [label="action:0.004338394793926247"];
# s28 -> s8  [label="action:0.010845986984815618"];
# s28 -> s9  [label="action:0.01735357917570499"];
# s28 -> s11  [label="action:0.0021691973969631237"];
# s28 -> s12  [label="action:0.015184381778741865"];
# s28 -> s13  [label="action:0.010845986984815618"];
# s28 -> s14  [label="action:0.0021691973969631237"];
# s28 -> s15  [label="action:0.08026030368763558"];
# s28 -> s17  [label="action:0.0021691973969631237"];
# s28 -> s18  [label="action:0.004338394793926247"];
# s28 -> s19  [label="action:0.008676789587852495"];
# s28 -> s20  [label="action:0.0021691973969631237"];
# s28 -> s26  [label="action:0.0021691973969631237"];
# s28 -> s28  [label="action:0.05856832971800434"];
# s28 -> s29  [label="action:0.42516268980477223"];
# s28 -> s31 [label="end:1.0"];
# s29 -> s0  [label="init:1.0"];
# s29 -> s1  [label="action:0.019230769230769232"];
# s29 -> s2  [label="action:0.6826923076923077"];
# s29 -> s3  [label="action:0.019230769230769232"];
# s29 -> s7  [label="action:0.009615384615384616"];
# s29 -> s8  [label="action:0.019230769230769232"];
# s29 -> s9  [label="action:0.009615384615384616"];
# s29 -> s15  [label="action:0.04807692307692308"];
# s29 -> s28  [label="action:0.057692307692307696"];
# s29 -> s29  [label="action:0.1346153846153846"];
# s29 -> s31 [label="end:1.0"];
# s30 -> s0  [label="init:1.0"];
# s30 -> s1  [label="action:0.03461538461538462"];
# s30 -> s2  [label="action:0.0038461538461538464"];
# s30 -> s3  [label="action:0.0038461538461538464"];
# s30 -> s5  [label="action:0.08076923076923077"];
# s30 -> s6  [label="action:0.06923076923076923"];
# s30 -> s8  [label="action:0.019230769230769232"];
# s30 -> s9  [label="action:0.007692307692307693"];
# s30 -> s10  [label="action:0.011538461538461539"];
# s30 -> s11  [label="action:0.0038461538461538464"];
# s30 -> s12  [label="action:0.023076923076923078"];
# s30 -> s13  [label="action:0.0038461538461538464"];
# s30 -> s14  [label="action:0.0038461538461538464"];
# s30 -> s16  [label="action:0.06538461538461539"];
# s30 -> s17  [label="action:0.0038461538461538464"];
# s30 -> s19  [label="action:0.0038461538461538464"];
# s30 -> s21  [label="action:0.007692307692307693"];
# s30 -> s23  [label="action:0.011538461538461539"];
# s30 -> s25  [label="action:0.007692307692307693"];
# s30 -> s27  [label="action:0.6230769230769231"];
# s30 -> s30  [label="action:0.011538461538461539"];
# s30 -> s31 [label="end:1.0"];
# s31 -> s31 [label="init:1.0"];
# s31 -> s31  [label="action:1.0"];
# s31 -> s31  [label="end:1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }

# %%
from aalpy.utils import load_automaton_from_file, save_automaton_to_file, visualize_automaton, generate_random_dfa
from aalpy.automata import Dfa
from aalpy.SULs import AutomatonSUL
from aalpy.oracles import RandomWalkEqOracle
from aalpy.learning_algs import run_Lstar, run_KV

# load an automaton
automaton = load_automaton_from_file(f"learned_mdp_abcd_{data_part}.dot", automaton_type='mdp')

print(automaton)

# visualize the automaton
visualize_automaton(automaton, path=f"learned_mdp_abcd_{data_part}.png")
# Out:
# digraph learnedModel {
# s0 [label="init"];
# s1 [label="pull-up-account"];
# s2 [label="enter-details"];
# s3 [label="verify-identity"];
# s4 [label="make-password"];
# s5 [label="search-timing"];
# s6 [label="search-policy"];
# s7 [label="validate-purchase"];
# s8 [label="search-faq"];
# s9 [label="membership"];
# s10 [label="search-boots"];
# s11 [label="try-again"];
# s12 [label="ask-the-oracle"];
# s13 [label="update-order"];
# s14 [label="promo-code"];
# s15 [label="update-account"];
# s16 [label="search-membership"];
# s17 [label="make-purchase"];
# s18 [label="offer-refund"];
# s19 [label="notify-team"];
# s20 [label="record-reason"];
# s21 [label="search-jeans"];
# s22 [label="shipping-status"];
# s23 [label="search-shirt"];
# s24 [label="instructions"];
# s25 [label="search-jacket"];
# s26 [label="log-out-in"];
# s27 [label="select-faq"];
# s28 [label="subscription-status"];
# s29 [label="send-link"];
# s30 [label="search-pricing"];
# s31 [label="end"];
# s0 -> s0  [label="init:1.0"];
# s0 -> s1  [label="action:0.67"];
# s0 -> s2  [label="action:0.01"];
# s0 -> s3  [label="action:0.02"];
# s0 -> s4  [label="action:0.0"];
# s0 -> s5  [label="action:0.0"];
# s0 -> s6  [label="action:0.0"];
# s0 -> s7  [label="action:0.0"];
# s0 -> s8  [label="action:0.2"];
# s0 -> s9  [label="action:0.0"];
# s0 -> s10  [label="action:0.0"];
# s0 -> s11  [label="action:0.04"];
# s0 -> s12  [label="action:0.0"];
# s0 -> s13  [label="action:0.0"];
# s0 -> s14  [label="action:0.0"];
# s0 -> s15  [label="action:0.0"];
# s0 -> s16  [label="action:0.0"];
# s0 -> s17  [label="action:0.0"];
# s0 -> s18  [label="action:0.0"];
# s0 -> s19  [label="action:0.01"];
# s0 -> s20  [label="action:0.0"];
# s0 -> s21  [label="action:0.0"];
# s0 -> s22  [label="action:0.0"];
# s0 -> s23  [label="action:0.0"];
# s0 -> s24  [label="action:0.0"];
# s0 -> s25  [label="action:0.0"];
# s0 -> s26  [label="action:0.03"];
# s0 -> s27  [label="action:0.0"];
# s0 -> s28  [label="action:0.0"];
# s0 -> s29  [label="action:0.0"];
# s0 -> s30  [label="action:0.0"];
# s0 -> s31  [label="end:1.0"];
# s1 -> s0  [label="init:1.0"];
# s1 -> s1  [label="action:0.02"];
# s1 -> s2  [label="action:0.08"];
# s1 -> s3  [label="action:0.39"];
# s1 -> s4  [label="action:0.0"];
# s1 -> s7  [label="action:0.25"];
# s1 -> s8  [label="action:0.02"];
# s1 -> s9  [label="action:0.01"];
# s1 -> s11  [label="action:0.01"];
# s1 -> s12  [label="action:0.05"];
# s1 -> s13  [label="action:0.0"];
# s1 -> s14  [label="action:0.0"];
# s1 -> s15  [label="action:0.0"];
# s1 -> s17  [label="action:0.0"];
# s1 -> s18  [label="action:0.0"];
# s1 -> s19  [label="action:0.02"];
# s1 -> s20  [label="action:0.12"];
# s1 -> s22  [label="action:0.02"];
# s1 -> s24  [label="action:0.0"];
# s1 -> s26  [label="action:0.0"];
# s1 -> s28  [label="action:0.01"];
# s1 -> s29  [label="action:0.0"];
# s1 -> s31  [label="end:1.0"];
# s2 -> s0  [label="init:1.0"];
# s2 -> s1  [label="action:0.0"];
# s2 -> s2  [label="action:0.05"];
# s2 -> s3  [label="action:0.0"];
# s2 -> s4  [label="action:0.16"];
# s2 -> s7  [label="action:0.0"];
# s2 -> s8  [label="action:0.0"];
# s2 -> s9  [label="action:0.0"];
# s2 -> s11  [label="action:0.03"];
# s2 -> s12  [label="action:0.0"];
# s2 -> s13  [label="action:0.26"];
# s2 -> s14  [label="action:0.0"];
# s2 -> s15  [label="action:0.11"];
# s2 -> s17  [label="action:0.02"];
# s2 -> s18  [label="action:0.09"];
# s2 -> s19  [label="action:0.03"];
# s2 -> s20  [label="action:0.0"];
# s2 -> s22  [label="action:0.0"];
# s2 -> s24  [label="action:0.0"];
# s2 -> s26  [label="action:0.03"];
# s2 -> s28  [label="action:0.0"];
# s2 -> s29  [label="action:0.21"];
# s2 -> s31  [label="end:1.0"];
# s3 -> s0  [label="init:1.0"];
# s3 -> s1  [label="action:0.02"];
# s3 -> s2  [label="action:0.06"];
# s3 -> s3  [label="action:0.08"];
# s3 -> s4  [label="action:0.01"];
# s3 -> s7  [label="action:0.11"];
# s3 -> s8  [label="action:0.0"];
# s3 -> s9  [label="action:0.1"];
# s3 -> s11  [label="action:0.0"];
# s3 -> s12  [label="action:0.17"];
# s3 -> s13  [label="action:0.01"];
# s3 -> s14  [label="action:0.06"];
# s3 -> s15  [label="action:0.07"];
# s3 -> s17  [label="action:0.01"];
# s3 -> s18  [label="action:0.01"];
# s3 -> s19  [label="action:0.0"];
# s3 -> s20  [label="action:0.01"];
# s3 -> s22  [label="action:0.13"];
# s3 -> s24  [label="action:0.0"];
# s3 -> s28  [label="action:0.15"];
# s3 -> s29  [label="action:0.0"];
# s3 -> s31  [label="end:1.0"];
# s4 -> s0  [label="init:1.0"];
# s4 -> s2  [label="action:0.22"];
# s4 -> s4  [label="action:0.5"];
# s4 -> s8  [label="action:0.06"];
# s4 -> s17  [label="action:0.06"];
# s4 -> s28  [label="action:0.06"];
# s4 -> s29  [label="action:0.11"];
# s4 -> s31  [label="end:1.0"];
# s5 -> s0  [label="init:1.0"];
# s5 -> s1  [label="action:0.01"];
# s5 -> s2  [label="action:0.0"];
# s5 -> s5  [label="action:0.01"];
# s5 -> s6  [label="action:0.08"];
# s5 -> s8  [label="action:0.0"];
# s5 -> s11  [label="action:0.0"];
# s5 -> s12  [label="action:0.01"];
# s5 -> s14  [label="action:0.01"];
# s5 -> s16  [label="action:0.1"];
# s5 -> s17  [label="action:0.0"];
# s5 -> s20  [label="action:0.0"];
# s5 -> s21  [label="action:0.01"];
# s5 -> s23  [label="action:0.0"];
# s5 -> s27  [label="action:0.68"];
# s5 -> s28  [label="action:0.0"];
# s5 -> s30  [label="action:0.06"];
# s5 -> s31  [label="end:1.0"];
# s6 -> s0  [label="init:1.0"];
# s6 -> s1  [label="action:0.03"];
# s6 -> s2  [label="action:0.0"];
# s6 -> s3  [label="action:0.0"];
# s6 -> s5  [label="action:0.05"];
# s6 -> s6  [label="action:0.03"];
# s6 -> s8  [label="action:0.01"];
# s6 -> s9  [label="action:0.02"];
# s6 -> s10  [label="action:0.0"];
# s6 -> s11  [label="action:0.03"];
# s6 -> s12  [label="action:0.01"];
# s6 -> s15  [label="action:0.0"];
# s6 -> s16  [label="action:0.07"];
# s6 -> s20  [label="action:0.0"];
# s6 -> s21  [label="action:0.0"];
# s6 -> s23  [label="action:0.0"];
# s6 -> s24  [label="action:0.02"];
# s6 -> s26  [label="action:0.01"];
# s6 -> s27  [label="action:0.61"];
# s6 -> s28  [label="action:0.0"];
# s6 -> s30  [label="action:0.09"];
# s6 -> s31  [label="end:1.0"];
# s7 -> s0  [label="init:1.0"];
# s7 -> s1  [label="action:0.0"];
# s7 -> s2  [label="action:0.07"];
# s7 -> s3  [label="action:0.02"];
# s7 -> s4  [label="action:0.0"];
# s7 -> s7  [label="action:0.05"];
# s7 -> s8  [label="action:0.01"];
# s7 -> s9  [label="action:0.2"];
# s7 -> s12  [label="action:0.18"];
# s7 -> s13  [label="action:0.12"];
# s7 -> s14  [label="action:0.0"];
# s7 -> s15  [label="action:0.0"];
# s7 -> s17  [label="action:0.0"];
# s7 -> s18  [label="action:0.02"];
# s7 -> s19  [label="action:0.0"];
# s7 -> s20  [label="action:0.23"];
# s7 -> s22  [label="action:0.09"];
# s7 -> s28  [label="action:0.01"];
# s7 -> s29  [label="action:0.0"];
# s7 -> s31  [label="end:1.0"];
# s8 -> s0  [label="init:1.0"];
# s8 -> s1  [label="action:0.01"];
# s8 -> s2  [label="action:0.0"];
# s8 -> s3  [label="action:0.0"];
# s8 -> s5  [label="action:0.11"];
# s8 -> s6  [label="action:0.11"];
# s8 -> s7  [label="action:0.0"];
# s8 -> s8  [label="action:0.0"];
# s8 -> s9  [label="action:0.01"];
# s8 -> s10  [label="action:0.12"];
# s8 -> s11  [label="action:0.01"];
# s8 -> s12  [label="action:0.0"];
# s8 -> s14  [label="action:0.0"];
# s8 -> s16  [label="action:0.16"];
# s8 -> s19  [label="action:0.0"];
# s8 -> s20  [label="action:0.0"];
# s8 -> s21  [label="action:0.12"];
# s8 -> s23  [label="action:0.1"];
# s8 -> s24  [label="action:0.0"];
# s8 -> s25  [label="action:0.12"];
# s8 -> s26  [label="action:0.01"];
# s8 -> s27  [label="action:0.0"];
# s8 -> s28  [label="action:0.0"];
# s8 -> s30  [label="action:0.11"];
# s8 -> s31  [label="end:1.0"];
# s9 -> s0  [label="init:1.0"];
# s9 -> s1  [label="action:0.0"];
# s9 -> s2  [label="action:0.36"];
# s9 -> s3  [label="action:0.0"];
# s9 -> s6  [label="action:0.0"];
# s9 -> s7  [label="action:0.0"];
# s9 -> s8  [label="action:0.07"];
# s9 -> s9  [label="action:0.04"];
# s9 -> s11  [label="action:0.0"];
# s9 -> s12  [label="action:0.05"];
# s9 -> s13  [label="action:0.13"];
# s9 -> s14  [label="action:0.08"];
# s9 -> s15  [label="action:0.05"];
# s9 -> s16  [label="action:0.01"];
# s9 -> s17  [label="action:0.04"];
# s9 -> s18  [label="action:0.11"];
# s9 -> s19  [label="action:0.01"];
# s9 -> s20  [label="action:0.01"];
# s9 -> s21  [label="action:0.0"];
# s9 -> s22  [label="action:0.0"];
# s9 -> s24  [label="action:0.01"];
# s9 -> s28  [label="action:0.01"];
# s9 -> s29  [label="action:0.0"];
# s9 -> s31  [label="end:1.0"];
# s10 -> s0  [label="init:1.0"];
# s10 -> s1  [label="action:0.02"];
# s10 -> s6  [label="action:0.02"];
# s10 -> s8  [label="action:0.02"];
# s10 -> s10  [label="action:0.02"];
# s10 -> s11  [label="action:0.01"];
# s10 -> s16  [label="action:0.01"];
# s10 -> s17  [label="action:0.01"];
# s10 -> s18  [label="action:0.01"];
# s10 -> s20  [label="action:0.01"];
# s10 -> s23  [label="action:0.01"];
# s10 -> s25  [label="action:0.01"];
# s10 -> s26  [label="action:0.01"];
# s10 -> s27  [label="action:0.83"];
# s10 -> s29  [label="action:0.01"];
# s10 -> s30  [label="action:0.05"];
# s10 -> s31  [label="end:1.0"];
# s11 -> s0  [label="init:1.0"];
# s11 -> s1  [label="action:0.0"];
# s11 -> s2  [label="action:0.1"];
# s11 -> s5  [label="action:0.0"];
# s11 -> s8  [label="action:0.01"];
# s11 -> s9  [label="action:0.0"];
# s11 -> s11  [label="action:0.01"];
# s11 -> s12  [label="action:0.01"];
# s11 -> s14  [label="action:0.0"];
# s11 -> s16  [label="action:0.0"];
# s11 -> s17  [label="action:0.02"];
# s11 -> s19  [label="action:0.04"];
# s11 -> s21  [label="action:0.0"];
# s11 -> s22  [label="action:0.0"];
# s11 -> s24  [label="action:0.2"];
# s11 -> s26  [label="action:0.58"];
# s11 -> s27  [label="action:0.0"];
# s11 -> s31  [label="end:1.0"];
# s12 -> s0  [label="init:1.0"];
# s12 -> s1  [label="action:0.0"];
# s12 -> s2  [label="action:0.01"];
# s12 -> s3  [label="action:0.01"];
# s12 -> s7  [label="action:0.01"];
# s12 -> s8  [label="action:0.02"];
# s12 -> s9  [label="action:0.21"];
# s12 -> s11  [label="action:0.0"];
# s12 -> s12  [label="action:0.02"];
# s12 -> s13  [label="action:0.25"];
# s12 -> s14  [label="action:0.15"];
# s12 -> s15  [label="action:0.08"];
# s12 -> s17  [label="action:0.0"];
# s12 -> s18  [label="action:0.07"];
# s12 -> s19  [label="action:0.01"];
# s12 -> s20  [label="action:0.02"];
# s12 -> s22  [label="action:0.06"];
# s12 -> s26  [label="action:0.01"];
# s12 -> s28  [label="action:0.01"];
# s12 -> s29  [label="action:0.07"];
# s12 -> s31  [label="end:1.0"];
# s13 -> s0  [label="init:1.0"];
# s13 -> s1  [label="action:0.0"];
# s13 -> s2  [label="action:0.09"];
# s13 -> s3  [label="action:0.0"];
# s13 -> s4  [label="action:0.0"];
# s13 -> s8  [label="action:0.02"];
# s13 -> s9  [label="action:0.01"];
# s13 -> s13  [label="action:0.21"];
# s13 -> s14  [label="action:0.01"];
# s13 -> s15  [label="action:0.04"];
# s13 -> s17  [label="action:0.49"];
# s13 -> s18  [label="action:0.05"];
# s13 -> s19  [label="action:0.01"];
# s13 -> s20  [label="action:0.02"];
# s13 -> s22  [label="action:0.01"];
# s13 -> s24  [label="action:0.0"];
# s13 -> s26  [label="action:0.0"];
# s13 -> s28  [label="action:0.0"];
# s13 -> s29  [label="action:0.01"];
# s13 -> s31  [label="end:1.0"];
# s14 -> s0  [label="init:1.0"];
# s14 -> s2  [label="action:0.08"];
# s14 -> s3  [label="action:0.04"];
# s14 -> s7  [label="action:0.04"];
# s14 -> s9  [label="action:0.12"];
# s14 -> s12  [label="action:0.24"];
# s14 -> s13  [label="action:0.08"];
# s14 -> s14  [label="action:0.12"];
# s14 -> s15  [label="action:0.04"];
# s14 -> s17  [label="action:0.04"];
# s14 -> s18  [label="action:0.04"];
# s14 -> s20  [label="action:0.04"];
# s14 -> s29  [label="action:0.12"];
# s14 -> s31  [label="end:1.0"];
# s15 -> s0  [label="init:1.0"];
# s15 -> s1  [label="action:0.03"];
# s15 -> s2  [label="action:0.03"];
# s15 -> s3  [label="action:0.01"];
# s15 -> s7  [label="action:0.04"];
# s15 -> s8  [label="action:0.03"];
# s15 -> s13  [label="action:0.05"];
# s15 -> s15  [label="action:0.14"];
# s15 -> s17  [label="action:0.01"];
# s15 -> s18  [label="action:0.43"];
# s15 -> s19  [label="action:0.01"];
# s15 -> s20  [label="action:0.05"];
# s15 -> s28  [label="action:0.03"];
# s15 -> s29  [label="action:0.15"];
# s15 -> s31  [label="end:1.0"];
# s16 -> s0  [label="init:1.0"];
# s16 -> s1  [label="action:0.03"];
# s16 -> s2  [label="action:0.01"];
# s16 -> s3  [label="action:0.01"];
# s16 -> s5  [label="action:0.05"];
# s16 -> s6  [label="action:0.15"];
# s16 -> s8  [label="action:0.01"];
# s16 -> s9  [label="action:0.03"];
# s16 -> s10  [label="action:0.0"];
# s16 -> s11  [label="action:0.01"];
# s16 -> s12  [label="action:0.0"];
# s16 -> s13  [label="action:0.0"];
# s16 -> s16  [label="action:0.01"];
# s16 -> s18  [label="action:0.0"];
# s16 -> s19  [label="action:0.01"];
# s16 -> s20  [label="action:0.01"];
# s16 -> s22  [label="action:0.0"];
# s16 -> s24  [label="action:0.0"];
# s16 -> s27  [label="action:0.6"];
# s16 -> s28  [label="action:0.0"];
# s16 -> s29  [label="action:0.01"];
# s16 -> s30  [label="action:0.06"];
# s16 -> s31  [label="end:1.0"];
# s17 -> s0  [label="init:1.0"];
# s17 -> s2  [label="action:0.08"];
# s17 -> s3  [label="action:0.02"];
# s17 -> s7  [label="action:0.02"];
# s17 -> s8  [label="action:0.1"];
# s17 -> s9  [label="action:0.02"];
# s17 -> s11  [label="action:0.02"];
# s17 -> s13  [label="action:0.02"];
# s17 -> s14  [label="action:0.02"];
# s17 -> s15  [label="action:0.02"];
# s17 -> s17  [label="action:0.6"];
# s17 -> s18  [label="action:0.02"];
# s17 -> s19  [label="action:0.04"];
# s17 -> s20  [label="action:0.02"];
# s17 -> s26  [label="action:0.02"];
# s17 -> s31  [label="end:1.0"];
# s18 -> s0  [label="init:1.0"];
# s18 -> s1  [label="action:0.13"];
# s18 -> s2  [label="action:0.11"];
# s18 -> s3  [label="action:0.05"];
# s18 -> s7  [label="action:0.03"];
# s18 -> s8  [label="action:0.05"];
# s18 -> s9  [label="action:0.06"];
# s18 -> s13  [label="action:0.03"];
# s18 -> s15  [label="action:0.05"];
# s18 -> s18  [label="action:0.31"];
# s18 -> s19  [label="action:0.02"];
# s18 -> s20  [label="action:0.11"];
# s18 -> s22  [label="action:0.03"];
# s18 -> s29  [label="action:0.02"];
# s18 -> s31  [label="end:1.0"];
# s19 -> s0  [label="init:1.0"];
# s19 -> s1  [label="action:0.04"];
# s19 -> s2  [label="action:0.02"];
# s19 -> s3  [label="action:0.01"];
# s19 -> s8  [label="action:0.01"];
# s19 -> s11  [label="action:0.07"];
# s19 -> s14  [label="action:0.14"];
# s19 -> s15  [label="action:0.0"];
# s19 -> s17  [label="action:0.28"];
# s19 -> s19  [label="action:0.05"];
# s19 -> s20  [label="action:0.03"];
# s19 -> s22  [label="action:0.0"];
# s19 -> s24  [label="action:0.08"];
# s19 -> s26  [label="action:0.26"];
# s19 -> s31  [label="end:1.0"];
# s20 -> s0  [label="init:1.0"];
# s20 -> s1  [label="action:0.02"];
# s20 -> s2  [label="action:0.08"];
# s20 -> s3  [label="action:0.28"];
# s20 -> s7  [label="action:0.01"];
# s20 -> s8  [label="action:0.0"];
# s20 -> s9  [label="action:0.02"];
# s20 -> s12  [label="action:0.2"];
# s20 -> s13  [label="action:0.1"];
# s20 -> s14  [label="action:0.03"];
# s20 -> s15  [label="action:0.01"];
# s20 -> s17  [label="action:0.01"];
# s20 -> s18  [label="action:0.11"];
# s20 -> s19  [label="action:0.09"];
# s20 -> s20  [label="action:0.04"];
# s20 -> s22  [label="action:0.0"];
# s20 -> s26  [label="action:0.0"];
# s20 -> s31  [label="end:1.0"];
# s21 -> s0  [label="init:1.0"];
# s21 -> s1  [label="action:0.02"];
# s21 -> s5  [label="action:0.01"];
# s21 -> s6  [label="action:0.01"];
# s21 -> s8  [label="action:0.01"];
# s21 -> s9  [label="action:0.0"];
# s21 -> s10  [label="action:0.01"];
# s21 -> s21  [label="action:0.04"];
# s21 -> s23  [label="action:0.01"];
# s21 -> s24  [label="action:0.01"];
# s21 -> s25  [label="action:0.02"];
# s21 -> s26  [label="action:0.0"];
# s21 -> s27  [label="action:0.79"];
# s21 -> s30  [label="action:0.04"];
# s21 -> s31  [label="end:1.0"];
# s22 -> s0  [label="init:1.0"];
# s22 -> s1  [label="action:0.01"];
# s22 -> s2  [label="action:0.0"];
# s22 -> s3  [label="action:0.02"];
# s22 -> s7  [label="action:0.22"];
# s22 -> s8  [label="action:0.0"];
# s22 -> s9  [label="action:0.26"];
# s22 -> s11  [label="action:0.0"];
# s22 -> s12  [label="action:0.02"];
# s22 -> s13  [label="action:0.21"];
# s22 -> s15  [label="action:0.0"];
# s22 -> s17  [label="action:0.02"];
# s22 -> s18  [label="action:0.17"];
# s22 -> s19  [label="action:0.0"];
# s22 -> s20  [label="action:0.01"];
# s22 -> s22  [label="action:0.04"];
# s22 -> s28  [label="action:0.0"];
# s22 -> s31  [label="end:1.0"];
# s23 -> s0  [label="init:1.0"];
# s23 -> s1  [label="action:0.01"];
# s23 -> s3  [label="action:0.01"];
# s23 -> s5  [label="action:0.01"];
# s23 -> s10  [label="action:0.02"];
# s23 -> s11  [label="action:0.01"];
# s23 -> s21  [label="action:0.01"];
# s23 -> s23  [label="action:0.02"];
# s23 -> s25  [label="action:0.03"];
# s23 -> s27  [label="action:0.84"];
# s23 -> s30  [label="action:0.06"];
# s23 -> s31  [label="end:1.0"];
# s24 -> s0  [label="init:1.0"];
# s24 -> s1  [label="action:0.01"];
# s24 -> s2  [label="action:0.03"];
# s24 -> s3  [label="action:0.02"];
# s24 -> s6  [label="action:0.03"];
# s24 -> s8  [label="action:0.09"];
# s24 -> s9  [label="action:0.03"];
# s24 -> s11  [label="action:0.24"];
# s24 -> s12  [label="action:0.01"];
# s24 -> s17  [label="action:0.05"];
# s24 -> s19  [label="action:0.23"];
# s24 -> s20  [label="action:0.01"];
# s24 -> s24  [label="action:0.05"];
# s24 -> s26  [label="action:0.18"];
# s24 -> s29  [label="action:0.01"];
# s24 -> s30  [label="action:0.01"];
# s24 -> s31  [label="end:1.0"];
# s25 -> s0  [label="init:1.0"];
# s25 -> s1  [label="action:0.01"];
# s25 -> s5  [label="action:0.01"];
# s25 -> s8  [label="action:0.01"];
# s25 -> s10  [label="action:0.01"];
# s25 -> s11  [label="action:0.01"];
# s25 -> s16  [label="action:0.01"];
# s25 -> s19  [label="action:0.01"];
# s25 -> s21  [label="action:0.02"];
# s25 -> s23  [label="action:0.01"];
# s25 -> s24  [label="action:0.01"];
# s25 -> s25  [label="action:0.03"];
# s25 -> s27  [label="action:0.84"];
# s25 -> s30  [label="action:0.05"];
# s25 -> s31  [label="end:1.0"];
# s26 -> s0  [label="init:1.0"];
# s26 -> s1  [label="action:0.01"];
# s26 -> s2  [label="action:0.24"];
# s26 -> s8  [label="action:0.01"];
# s26 -> s10  [label="action:0.0"];
# s26 -> s11  [label="action:0.33"];
# s26 -> s17  [label="action:0.02"];
# s26 -> s18  [label="action:0.0"];
# s26 -> s19  [label="action:0.04"];
# s26 -> s20  [label="action:0.0"];
# s26 -> s22  [label="action:0.0"];
# s26 -> s24  [label="action:0.33"];
# s26 -> s26  [label="action:0.01"];
# s26 -> s31  [label="end:1.0"];
# s27 -> s0  [label="init:1.0"];
# s27 -> s1  [label="action:0.08"];
# s27 -> s2  [label="action:0.01"];
# s27 -> s5  [label="action:0.02"];
# s27 -> s6  [label="action:0.04"];
# s27 -> s8  [label="action:0.02"];
# s27 -> s9  [label="action:0.01"];
# s27 -> s10  [label="action:0.01"];
# s27 -> s11  [label="action:0.01"];
# s27 -> s12  [label="action:0.01"];
# s27 -> s14  [label="action:0.01"];
# s27 -> s15  [label="action:0.01"];
# s27 -> s16  [label="action:0.03"];
# s27 -> s19  [label="action:0.01"];
# s27 -> s21  [label="action:0.03"];
# s27 -> s23  [label="action:0.01"];
# s27 -> s24  [label="action:0.01"];
# s27 -> s27  [label="action:0.61"];
# s27 -> s29  [label="action:0.02"];
# s27 -> s30  [label="action:0.04"];
# s27 -> s31  [label="end:1.0"];
# s28 -> s0  [label="init:1.0"];
# s28 -> s1  [label="action:0.01"];
# s28 -> s2  [label="action:0.32"];
# s28 -> s3  [label="action:0.02"];
# s28 -> s7  [label="action:0.0"];
# s28 -> s8  [label="action:0.01"];
# s28 -> s9  [label="action:0.02"];
# s28 -> s11  [label="action:0.0"];
# s28 -> s12  [label="action:0.02"];
# s28 -> s13  [label="action:0.01"];
# s28 -> s14  [label="action:0.0"];
# s28 -> s15  [label="action:0.08"];
# s28 -> s17  [label="action:0.0"];
# s28 -> s18  [label="action:0.0"];
# s28 -> s19  [label="action:0.01"];
# s28 -> s20  [label="action:0.0"];
# s28 -> s26  [label="action:0.0"];
# s28 -> s28  [label="action:0.06"];
# s28 -> s29  [label="action:0.43"];
# s28 -> s31  [label="end:1.0"];
# s29 -> s0  [label="init:1.0"];
# s29 -> s1  [label="action:0.02"];
# s29 -> s2  [label="action:0.68"];
# s29 -> s3  [label="action:0.02"];
# s29 -> s7  [label="action:0.01"];
# s29 -> s8  [label="action:0.02"];
# s29 -> s9  [label="action:0.01"];
# s29 -> s15  [label="action:0.05"];
# s29 -> s28  [label="action:0.06"];
# s29 -> s29  [label="action:0.13"];
# s29 -> s31  [label="end:1.0"];
# s30 -> s0  [label="init:1.0"];
# s30 -> s1  [label="action:0.03"];
# s30 -> s2  [label="action:0.0"];
# s30 -> s3  [label="action:0.0"];
# s30 -> s5  [label="action:0.08"];
# s30 -> s6  [label="action:0.07"];
# s30 -> s8  [label="action:0.02"];
# s30 -> s9  [label="action:0.01"];
# s30 -> s10  [label="action:0.01"];
# s30 -> s11  [label="action:0.0"];
# s30 -> s12  [label="action:0.02"];
# s30 -> s13  [label="action:0.0"];
# s30 -> s14  [label="action:0.0"];
# s30 -> s16  [label="action:0.07"];
# s30 -> s17  [label="action:0.0"];
# s30 -> s19  [label="action:0.0"];
# s30 -> s21  [label="action:0.01"];
# s30 -> s23  [label="action:0.01"];
# s30 -> s25  [label="action:0.01"];
# s30 -> s27  [label="action:0.62"];
# s30 -> s30  [label="action:0.01"];
# s30 -> s31  [label="end:1.0"];
# s31 -> s31  [label="init:1.0"];
# s31 -> s31  [label="action:1.0"];
# s31 -> s31  [label="end:1.0"];
# __start0 [label="", shape=none];
# __start0 -> s0  [label=""];
# }
#
# Visualization started in the background thread.
# Visualizing 32 state automaton could take some time.
# Model saved to learned_mdp_abcd_full.pdf.
