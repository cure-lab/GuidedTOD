# %% [markdown]
# ### Pipeline should be like:
# 1. Core: could predict next action given the current context
# 2. can load the data from the benchmark
# 3. connect the data to the core module, to get the run-time action prediction list
# 4. Use CE metric to evaluate the quality of the predicted action list
# 5. if good enough, then save the dialogues as the new data for further training

# %%
import re


def parse_ast_prediction(prediction_str):
    match = re.match(r"(.*)\[(.*)]", prediction_str)
    if match:
        # action w/ value
        action_name = match.group(1).strip()
        slot_str = match.group(2)
        slot_str = slot_str.replace(";", ",")
        slots = [s.strip() for s in slot_str.split(",")]
        for i in range(len(slots)):
            if slots[i].endswith(">") and not slots[i].startswith("<"):
                # add "<" to the beginning of the slot
                slots[i] = "<" + slots[i]
            if slots[i].startswith("<") and not slots[i].endswith(">"):
                # add ">" to the end of the slot
                slots[i] = slots[i] + ">"
    else:
        action_name = "MISSING"
        slots = ["MISSING"]

    return action_name, slots


def parse_context_action(context):
    # Regular expression pattern to match actions (XX-XX, XX-XX-XX or XX-XX-XX-XX)
    action_pattern = r"\b(\w+-\w+(?:-\w+){0,2})(?=\s*\[)"

    # Find all matches in the context string
    actions = re.findall(action_pattern, context)
    return actions

# %% [markdown]
# #### directly load the model (OK)

# %%
import json

# Load model directly
from transformers import (
    AutoConfig,
    AutoModel,
    T5ForConditionalGeneration,
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    DataCollatorForSeq2Seq,
    HfArgumentParser,
    Seq2SeqTrainer,
    set_seed,
    MBartTokenizer,
    MBartTokenizerFast,
    BeamSearchScorer,
    LogitsProcessorList,
    MinLengthLogitsProcessor
)
import numpy as np
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(
    "/research/d5/gds/xywen22/project/llm_framework/AST_abcd_part/results/abcdASTWMostPActionChainAll_input_target_t5-small/",
    use_fast=False,
    # revision="main",
    # use_auth_token=None,
)
model = AutoModelForSeq2SeqLM.from_pretrained(
    "/research/d5/gds/xywen22/project/llm_framework/AST_abcd_part/results/abcdASTWMostPActionChainAll_input_target_t5-small/"
)
model.to(device)

# model.resize_token_embeddings(len(tokenizer))
# model.is_encoder_decoder = True

data = []
with open('/research/d5/gds/xywen22/project/llm_framework/AST_abcd_part/data/processed/dev_AST_abcd_wmostpaction_chain_1p.json', 'r') as file:
    for line in file:
        json_data = json.loads(line)
        data.append(json_data)

for i in range(10):
    print("input: ", data[i]['input'])
    print("target: ", data[i]['target'])

    input_context = "Predict AST: " + data[i]['input']
    encoder_input_ids = tokenizer(input_context, return_tensors="pt").input_ids
    encoder_input_ids = encoder_input_ids.to(device)

    # lets run beam search using 3 beams
    num_beams = 4
    # define decoder start token ids
    input_ids = torch.ones((num_beams, 1), device=model.device, dtype=torch.long)
    input_ids = input_ids * model.config.decoder_start_token_id

    model_kwargs = {
        "encoder_outputs": model.get_encoder()(encoder_input_ids.repeat_interleave(num_beams, dim=0), return_dict=True)
    }

    beam_scorer = BeamSearchScorer(
        batch_size=1,
        num_beams=num_beams,
        device=model.device,
        num_beam_hyps_to_keep=num_beams,
    )

    logits_processor = LogitsProcessorList(
        [
            MinLengthLogitsProcessor(5, eos_token_id=model.config.eos_token_id),
        ]
    )

    outputs = model.beam_search(
        input_ids, 
        beam_scorer, 
        logits_processor=logits_processor, 
        output_scores=True, 
        return_dict_in_generate = True,
        **model_kwargs
    )

    # print("sequence_scores: ", outputs.sequence_scores)
    # print(tokenizer.decode(outputs[0][0], skip_special_tokens=True))
    # print(tokenizer.decode(outputs[0][1], skip_special_tokens=True))
    # print(tokenizer.decode(outputs[0][2], skip_special_tokens=True))
    # print(tokenizer.decode(outputs[0][3], skip_special_tokens=True))

    # print('---------------------------------')
    # print()
    # print("outputs: ", outputs
    # print("sequence_scores: ", outputs.sequences_scores)
    scores = outputs.sequences_scores.cpu().numpy()
    # for i in range(len(scores)):
    #     scores[i] = np.exp(scores[i])
    # print("scores: ", scores)
    # # normalize the scores
    # scores = scores / np.sum(scores)
    print("scores: ", scores)

    for k in range(3):
        pred_str = tokenizer.decode(outputs.sequences[k], skip_special_tokens=True)
        print("pred str: ", pred_str)
        action_name, slots = parse_ast_prediction(pred_str)
        print(f"parsed results: {action_name}, {slots}")

    actions = parse_context_action(input_context)
    print(f"context parsed results: {actions}")
    # output = tokenizer.batch_decode(outputs[0][0], skip_special_tokens=True)
    # print(output)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# input:  Context: hello. how may i help you today? i was trying to see my history but i can't remember my username. i can definitely help you with that. what is your name and email address? david williams. <email>. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  pull-up-account [david williams]
# /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/generation/utils.py:2966: UserWarning: You don't have defined any stopping_criteria, this will likely loop forever
#   warnings.warn("You don't have defined any stopping_criteria, this will likely loop forever", UserWarning)
# scores:  [-4.8543201e-04 -2.4581455e-01 -6.3823980e-01 -6.7502719e-01]
# pred str:  pull-up-account [david williams]
# parsed results: pull-up-account, ['david williams']
# pred str:  verify-identity [david williams, n/a, n/a]
# parsed results: verify-identity, ['david williams', 'n/a', 'n/a']
# pred str:  verify-identity [david williams, n/a, n/a [none]
# parsed results: verify-identity [david williams, n/a, n/a, ['none']
# context parsed results: []
# input:  Context: hello. how may i help you today? i was trying to see my history but i can't remember my username. i can definitely help you with that. what is your name and email address? david williams. <email>. pull-up-account ['david williams'] can i also have your zip code and phone number please? <zip_code>. <phone>. thank you so much for verifying that. one moment while i pull this up. Possible Actions: [verify-identity, validate-purchase, record-reason, pull-up-account]
# target:  verify-identity [david williams, <zip_code>, <zip_code>]
# scores:  [-0.0006554  -0.16065566 -0.3312155  -0.38308027]
# pred str:  verify-identity [david williams, zip_code>, zip_code>]
# parsed results: verify-identity, ['david williams', '<zip_code>', '<zip_code>']
# pred str:  verify-identity [zip_code>, zip_code>, zip_code>]
# parsed results: verify-identity, ['<zip_code>', '<zip_code>', '<zip_code>']
# pred str:  validate-purchase [email>, email>, email>]
# parsed results: validate-purchase, ['<email>', '<email>', '<email>']
# context parsed results: ['pull-up-account']
# input:  Context: hi, how may i help you? yes i would like to double check the status of my refund. ok, what do you want to check? i would like to know the status of my refund. ok, can i have your full name or account id please? joseph banter and my account is afg5674g. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  pull-up-account [afg5674g]
# scores:  [-0.00079274 -0.21556085 -0.29223242 -0.55399054]
# pred str:  pull-up-account [joseph banter]
# parsed results: pull-up-account, ['joseph banter']
# pred str:  verify-identity [joseph banter, afg5674g, n/a]
# parsed results: verify-identity, ['joseph banter', 'afg5674g', 'n/a']
# pred str:  pull-up-account [afg5674g]
# parsed results: pull-up-account, ['afg5674g']
# context parsed results: []
# input:  Context: hi, how may i help you? yes i would like to double check the status of my refund. ok, what do you want to check? i would like to know the status of my refund. ok, can i have your full name or account id please? joseph banter and my account is afg5674g. pull-up-account ['afg5674g'] can i also have your username, email and order id please? are you there? <username>, email is <email> and order id is <order_id>. yes i was getting the info. sorry, we have a lot of disconnects lately. Possible Actions: [verify-identity, validate-purchase, record-reason, pull-up-account]
# target:  validate-purchase [<username>, <username>, <username>]
# scores:  [-0.00078002 -0.1432175  -0.24047722 -0.4569962 ]
# pred str:  validate-purchase [username>, username>, username>]
# parsed results: validate-purchase, ['<username>', '<username>', '<username>']
# pred str:  verify-identity [order_id>, order_id>, order_id>]
# parsed results: verify-identity, ['<order_id>', '<order_id>', '<order_id>']
# pred str:  verify-identity [joseph banter, order_id>, order_id>]
# parsed results: verify-identity, ['joseph banter', '<order_id>', '<order_id>']
# context parsed results: ['pull-up-account']
# input:  Context: how can i help you? yeah, this is crystal minh, my husband said that a subscription was added to our account but we didn't ask for it. sorry to hear that. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  pull-up-account [crystal minh]
# scores:  [-2.3258798e-04 -3.3682200e-01 -6.3634074e-01 -6.4098716e-01]
# pred str:  pull-up-account [crystal minh]
# parsed results: pull-up-account, ['crystal minh']
# pred str:  verify-identity [crystal minh, n/a, n/a]
# parsed results: verify-identity, ['crystal minh', 'n/a', 'n/a']
# pred str:  pull-up-account [crystalminh]
# parsed results: pull-up-account, ['crystalminh']
# context parsed results: []
# input:  Context: how can i help you? yeah, this is crystal minh, my husband said that a subscription was added to our account but we didn't ask for it. sorry to hear that. pull-up-account ['crystal minh'] did you get billed twice? or are you saying you shouldn't have a subscription at all? i didn't ask for a subscription but we are being charged $40 for it. okay, what is your account number and order id? i don't have them. do you have your billing statement? no. do you have your username and email address? cminh1982. cminh1982@email.com. Possible Actions: [verify-identity, validate-purchase, record-reason, pull-up-account]
# target:  record-reason [spouse]
# scores:  [-0.07648854 -0.07826395 -0.09312949 -0.13792674]
# pred str:  verify-identity [crystal minh, cminh1982@email.com, n/a]
# parsed results: verify-identity, ['crystal minh', 'cminh1982@email.com', 'n/a']
# pred str:  validate-purchase [cminh1982@email.com, cminh1982@email.com, n/a]
# parsed results: validate-purchase, ['cminh1982@email.com', 'cminh1982@email.com', 'n/a']
# pred str:  record-reason [spouse]
# parsed results: record-reason, ['spouse']
# context parsed results: ['pull-up-account']
# input:  Context: how can i help you? yeah, this is crystal minh, my husband said that a subscription was added to our account but we didn't ask for it. sorry to hear that. pull-up-account ['crystal minh'] did you get billed twice? or are you saying you shouldn't have a subscription at all? i didn't ask for a subscription but we are being charged $40 for it. okay, what is your account number and order id? i don't have them. do you have your billing statement? no. do you have your username and email address? cminh1982. cminh1982@email.com. record-reason ['spouse'] Possible Actions: [ask-the-oracle, verify-identity, offer-refund, enter-details]
# target:  ask-the-oracle [none]
# scores:  [-0.02924981 -0.08372498 -0.1027526  -0.1560949 ]
# pred str:  ask-the-oracle [none]
# parsed results: ask-the-oracle, ['none']
# pred str:  verify-identity [crystal minh, cminh1982@email.com, n/a]
# parsed results: verify-identity, ['crystal minh', 'cminh1982@email.com', 'n/a']
# pred str:  verify-identity [crystal minh, cminh1982@email.com, cminh1982@email.com]
# parsed results: verify-identity, ['crystal minh', 'cminh1982@email.com', 'cminh1982@email.com']
# context parsed results: ['pull-up-account', 'record-reason']
# input:  Context: how can i help you? yeah, this is crystal minh, my husband said that a subscription was added to our account but we didn't ask for it. sorry to hear that. pull-up-account ['crystal minh'] did you get billed twice? or are you saying you shouldn't have a subscription at all? i didn't ask for a subscription but we are being charged $40 for it. okay, what is your account number and order id? i don't have them. do you have your billing statement? no. do you have your username and email address? cminh1982. cminh1982@email.com. record-reason ['spouse'] ask-the-oracle ['none'] sorry about that. i see we billed you in error. Possible Actions: [search-faq, membership, update-order, promo-code, update-account, offer-refund, subscription-status]
# target:  update-order [remove service]
# scores:  [-0.08020319 -0.18141603 -0.20756458 -0.39812416]
# pred str:  ask-the-oracle [none]
# parsed results: ask-the-oracle, ['none']
# pred str:  update-account [remove service]
# parsed results: update-account, ['remove service']
# pred str:  offer-refund [40]
# parsed results: offer-refund, ['40']
# context parsed results: ['pull-up-account', 'record-reason', 'ask-the-oracle']
# input:  Context: how can i help you? yeah, this is crystal minh, my husband said that a subscription was added to our account but we didn't ask for it. sorry to hear that. pull-up-account ['crystal minh'] did you get billed twice? or are you saying you shouldn't have a subscription at all? i didn't ask for a subscription but we are being charged $40 for it. okay, what is your account number and order id? i don't have them. do you have your billing statement? no. do you have your username and email address? cminh1982. cminh1982@email.com. record-reason ['spouse'] ask-the-oracle ['none'] sorry about that. i see we billed you in error. update-order ['remove service'] how much were you charged? $40. Possible Actions: [enter-details, make-purchase]
# target:  offer-refund [40]
# scores:  [-0.00974841 -0.22203933 -0.83366627 -0.8704363 ]
# pred str:  offer-refund [40]
# parsed results: offer-refund, ['40']
# pred str:  ask-the-oracle [none]
# parsed results: ask-the-oracle, ['none']
# pred str:  offer-refund [10]
# parsed results: offer-refund, ['10']
# context parsed results: ['pull-up-account', 'record-reason', 'ask-the-oracle', 'update-order']
# input:  Context: hi! thank you for contacting acmecorp. how may i help you? i would like to cancel my shipping order. i ordered the wrong item,. ok, i can help with that. can i have your full name. rodriguez domingo. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  pull-up-account [rodriguez domingo]
# scores:  [-1.8966151e-04 -4.1477251e-01 -4.3469274e-01 -5.2250260e-01]
# pred str:  pull-up-account [rodriguez domingo]
# parsed results: pull-up-account, ['rodriguez domingo']
# pred str:  pull-up-account [rodrigo dominguez]
# parsed results: pull-up-account, ['rodrigo dominguez']
# pred str:  verify-identity [rodriguez, domingo, n/a]
# parsed results: verify-identity, ['rodriguez', 'domingo', 'n/a']
# context parsed results: []

# %%
from aalpy.utils import load_automaton_from_file
import random

# load an automaton
chained_proir = load_automaton_from_file("/research/d5/gds/xywen22/project/llm_framework/AST_abcd_part/chainPrior/mdp_guildline_half.dot", automaton_type='mc')

data_index = [random.randint(0, len(data)) for i in range(10)]

for i in data_index:
    print('=' * 100)
    print("input: ", data[i]['input'])
    print("target: ", data[i]['target'])

    input_context = "Predict AST: " + data[i]['input']
    encoder_input_ids = tokenizer(input_context, return_tensors="pt")
    encoder_input_ids = encoder_input_ids.to(device)

    # lets run beam search using 3 beams
    num_beams = 50
    # define decoder start token ids
    outputs = model.generate(**encoder_input_ids, max_new_tokens=256, return_dict_in_generate=True, output_scores=True, do_sample=False, num_beams=num_beams, num_return_sequences=num_beams,)
    transition_scores = model.compute_transition_scores(
        outputs.sequences, outputs.scores, normalize_logits=False
    )

    log_prob = transition_scores.cpu().numpy()
    # print("log_prob: ", log_prob[0])
    log_prob = np.sum(log_prob, axis=1)
    print(f'scores: {log_prob}')

    policy_model_action = []
    policy_model_slot = []
    policy_model_prob = []

    print('+' * 20, 'policy model', '+' * 20)
    for k in range(num_beams):
        pred_str = tokenizer.decode(outputs.sequences[k], skip_special_tokens=True)
        action_name, slots = parse_ast_prediction(pred_str)
        # print(f"policy model top parsed: {action_name}, {slots}; score: {log_prob[k]}")

        policy_model_action.append(action_name)
        policy_model_slot.append(slots)
        if action_name != 'MISSING':
            policy_model_prob.append(log_prob[k])
        else:
            policy_model_prob.append(-10000)

        if k == 0:
            print("policy model top pred str: ", pred_str)
            print(f"policy model top parsed: {action_name}, {slots}; score: {log_prob[k]}")


    print('+' * 20, 'chained prior', '+' * 20)
    prev_actions = parse_context_action(input_context)
    prev_actions = ['init'] + prev_actions
    print(f"context parsed: {prev_actions}")

    init_state = chained_proir.states[0]
    curr_state = init_state

    prev_actions_with_prob = [(curr_state.output, 1)]
    prev_prob = 0
    idx = 0
    while curr_state.output != prev_actions[-1] and idx <= len(prev_actions) - 1:
        print(f"curr_state.output: {curr_state.output}")
        idx += 1
        matched = False
        for prosible_state, prob in curr_state.transitions:
            # print(f"prosible_state: {prosible_state.output}, prob: {prob}")
            if prosible_state.output == prev_actions[idx]:
                # print(f"prev_actions[idx]: {prev_actions[idx]}, curr_state.output: {curr_state.output}")
                prev_actions_with_prob.append((prosible_state.output, np.log(prob)))
                prev_prob += np.log(prob)
                curr_state = prosible_state
                matched = True
        
        if matched == False:
            break
    print(f"context parsed prob: {prev_actions_with_prob}, total previous prob: {prev_prob}")
    
    chained_prior_pred = []
    chained_prior_prob = []
    for state in chained_proir.states:
        # print(f"state: {state.output}")
        if state.output == prev_actions[-1]:
            for prosible_state, prob in state.transitions:
                chained_prior_pred.append(prosible_state.output)
                chained_prior_prob.append(np.log(prob) + prev_prob)
    print(f"possible next: {chained_prior_pred}, prob: {chained_prior_prob}")

    for i, action in enumerate(policy_model_action):
        # print(f"policy model action: {action}, prob: {policy_model_prob[i]}")
        if action == 'MISSING':
            defualt_next = np.argmax(np.array(chained_prior_prob))
            policy_model_action[i] = chained_prior_pred[defualt_next]
            policy_model_prob[i] = chained_prior_prob[defualt_next] * 1000
        else:
            for j, c_action in enumerate(chained_prior_pred):
                if action == c_action:
                    # print(f"policy model prob: {policy_model_prob[i]}, chained prior prob: {chained_prior_prob[j]}")
                    policy_model_prob[i] = policy_model_prob[i] + chained_prior_prob[j] * 100
    
    for i, action in enumerate(chained_prior_pred):
        if action not in policy_model_action:
            policy_model_action.append(action)
            policy_model_slot.append(['MISSING'])
            policy_model_prob.append(chained_prior_prob[i] * 1000)

    print('+' * 20, 'chained prior + policy model', '+' * 20)
    # for i in range(len(policy_model_action)):
    #     print(f"MERGED top parsed: {policy_model_action[i]}, {policy_model_slot[i]}; score: {policy_model_prob[i]}")
    top_idx = np.argmax(np.array(policy_model_prob))
    print("MERGED top pred str: ", f"{policy_model_action[top_idx]} {policy_model_slot[top_idx]}")
    print(f"MERGED top parsed: {policy_model_action[top_idx]}, {policy_model_slot[top_idx]}; score: {policy_model_prob[top_idx]}")
    print()
# Out:
# ====================================================================================================
# input:  Context: hi, how may i help you? got a promo code from you 5 days ago. and today i'm putting it in and it isn't working. saying it's invalid. okay, can i have your full name? i'm norman bouchard. pull-up-account ['norman bouchard'] had a code for this guess t shirt. ask-the-oracle ['none'] it appears that there is no error due to the system. may i ask what your membership level is? says i'm a gold member. membership ['gold'] great, as a gold member we value you very highly. we will generate a new code for your right away. Possible Actions: [enter-details, ask-the-oracle, offer-refund, search-faq, membership]
# target:  promo-code [none]
# scores: [-758.4534  -434.4535  -681.27234 -594.493   -535.6451  -444.94394
#  -568.61646 -646.576   -480.01202 -625.2027  -657.003   -552.1121
#  -549.9955  -414.09598 -661.4824  -522.9814  -424.09296 -505.14584
#  -581.68677 -600.9825  -591.17584 -592.8374  -574.1764  -537.5526
#  -542.9673  -590.82306 -530.23737 -567.1177  -577.81824 -590.5803
#  -531.3009  -515.8505  -637.0647  -567.9852  -573.05597 -541.9039
#  -564.21454 -546.1116  -556.13776 -481.4032  -509.14133 -549.59344
#  -540.8969  -584.58405 -514.85785 -592.8795  -543.418   -473.8988
#  -485.02097 -487.60825]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  promo-code [none]
# policy model top parsed: promo-code, ['none']; score: -758.4534301757812
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'pull-up-account', 'ask-the-oracle']
# curr_state.output: init
# curr_state.transitions: [(<aalpy.automata.MarkovChain.McState object at 0x7f585b681d50>, 0.7376415094339622), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f30>, 0.03669811320754717), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ab0>, 0.011320754716981131), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681bd0>, 0.011320754716981131), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e10>, 0.1689622641509434), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681a50>, 0.012075471698113207), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6819f0>, 0.0015094339622641509), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c30>, 0.0036792452830188677), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6820b0>, 0.006320754716981132), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681990>, 0.0027358490566037736), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682050>, 0.0015094339622641509), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b70>, 0.0015094339622641509), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681db0>, 0.0018867924528301887), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f90>, 0.0002830188679245283), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ff0>, 0.00018867924528301886), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e70>, 0.0005660377358490566), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ed0>, 0.0004716981132075472), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681930>, 0.0002830188679245283), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c90>, 0.0004716981132075472), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b10>, 0.0002830188679245283), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681cf0>, 0.0002830188679245283)]
# curr_state.output: pull-up-account
# curr_state.transitions: [(<aalpy.automata.MarkovChain.McState object at 0x7f585b682050>, 0.2397356044235414), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682590>, 0.3746027710690225), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6823b0>, 0.061268590313969744), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682530>, 0.19524596415406126), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681930>, 0.03482903266810728), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682470>, 0.015253590949536036), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682410>, 0.03050718189907207), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e70>, 0.023261726198042457), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6824d0>, 0.005465870090250413), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ed0>, 0.0024151519003432057), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e10>, 0.007245455701029618), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6821d0>, 0.001652472352866404), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681a50>, 0.0013982458370408034), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b10>, 0.0006355662895640015), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b70>, 0.0019066988686920045), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682110>, 0.0008897928053896022), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681cf0>, 0.0010169060633024025), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6819f0>, 0.00025422651582560063), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681d50>, 0.0015253590949536036), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ff0>, 0.00025422651582560063), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c90>, 0.00025422651582560063), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f90>, 0.00012711325791280032), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6834f0>, 0.00025422651582560063)]
# context parsed prob: [('init', 1), ('pull-up-account', -0.3042973319756445), ('ask-the-oracle', -3.357303967941172)], total previous prob: -3.6616012999168164
# possible next: ['pull-up-account', 'promo-code', 'search-faq', 'send-link', 'membership', 'update-account', 'record-reason', 'update-order', 'membership-privileges', 'offer-refund', 'notify-team', 'shipping-status', 'validate-purchase', 'subscription-status', 'enter-details', 'verify-identity', 'log-out-in', 'n/a', 'search-membership', 'make-purchase', 'membership-privileges', 'n/a', 'update-account', 'offer-refund', 'promo-code', 'subscription-status', 'log-out-in', 'offer-refund'], prob: [-9.985960262298127, -6.671774257625602, -8.887347973630018, -5.543309005807811, -6.094139964187501, -8.887347973630018, -8.376522349864027, -6.054134629573801, -5.198468519516082, -7.460231617989871, -9.292813081738181, -5.095611134076373, -9.985960262298127, -9.580495154189963, -9.580495154189963, -10.679107442858072, -10.679107442858072, -5.891615700076027, -10.679107442858072, -10.679107442858072, -3.6616012999168164, -3.803775788697359, -6.224143917347789, -8.996732639587568, -6.8566664760912985, -9.689879820147514, -8.591267531479405, -3.6616012999168164]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  code-account ['norman bouchard']
# MERGED top parsed: code-account, ['norman bouchard']; score: -480.01202392578125
#
# ====================================================================================================
# input:  Context: hello. hello, how can i help you? i need to send something back. i bought this shirt but in the wrong color. can i get a refund. what is it that you need to send back? <name>. can i have your name? crystal minh. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  pull-up-account [crystal minh]
# scores: [ -967.2029   -781.74756  -809.83844  -874.2705   -960.9114   -918.86664
#   -886.6462  -1039.7582   -854.18085  -545.2814   -597.3451   -451.33554
#   -934.65967  -525.7945   -622.73413  -538.3909   -527.3882   -575.4864
#   -470.05298  -606.1664   -575.6336   -530.0956   -592.90375  -563.5323
#   -540.78485  -588.80695  -552.2294   -597.3137   -551.23035  -526.51294
#   -596.8977   -536.5972   -583.08734  -582.44556  -570.6957   -573.8244
#   -500.23682  -540.8709   -540.29553  -558.82117  -512.9156   -504.0259
#   -553.0248   -509.40112  -533.75244  -513.38214  -521.9757   -529.1951
#   -471.6302   -469.95865]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  pull-up-account [crystal minh]
# policy model top parsed: pull-up-account, ['crystal minh']; score: -967.202880859375
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init']
# context parsed prob: [('init', 1)], total previous prob: 0
# possible next: ['pull-up-account', 'try-again', 'log-out/in', 'notify-internal-team', 'search-faq', 'log-out-in', 'instructions', 'notify-team', 'verify-identity', 'enter-details', 'validate-purchase', 'membership', 'record-reason', 'update-account', 'update-order', 'shipping-status', 'subscription-status', 'ask-the-oracle', 'offer-refund', 'make-purchase', 'promo-code'], prob: [-0.3042973319756445, -3.305029936481712, -4.481117537318112, -4.481117537318112, -1.7780798780394467, -4.416579016180541, -6.496020557860377, -5.6050476339705115, -5.063916660709192, -5.901313450113684, -6.496020557860377, -6.496020557860377, -6.272877006546167, -8.169996991432049, -8.575462099540212, -7.476849810872103, -7.659171367666058, -8.169996991432049, -7.659171367666058, -8.169996991432049, -8.169996991432049]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  pull-up-account ['crystal minh customer is typing']
# MERGED top parsed: pull-up-account, ['crystal minh customer is typing']; score: -904.7002410100645
#
# ====================================================================================================
# input:  Context: hi, i need to cancel part of my order. okay, i'd be glad to help. can i have your name and account number? norman bouchard.  <account_id>. pull-up-account ['norman bouchard'] thank you mr. bouchard. can i have your username, email address and order number? order id: <order_id>. i don't know my username. verify-identity ['norman bouchard', '<account_id>', '<account_id>'] no problem, i was able to successfully locate your account. did the order already ship? i'm not sure. yes, i think so. shipping-status ['6416384753'] my spouse said there's no way he's wearing anything made by someone named tommy so i need to cancel that product. you still there? i understand. what is your membership level? gold. membership ['gold'] okay, which item would you like to return? the tommy jacket. okay, and how much was it? $<amount>. Possible Actions: [enter-details, ask-the-oracle, offer-refund, search-faq, membership]
# target:  offer-refund [<amount>]
# scores: [-5584.2627 -3006.869  -2605.3757 -2500.1213 -2628.9536 -2513.288
#  -2518.572  -2481.4343 -2545.8982 -2544.7183 -2406.9678 -2434.6545
#  -2598.2844 -2457.045  -2209.0552 -2657.8584 -2340.7024 -2530.934
#  -1871.6671 -2524.9468 -2494.0293 -2080.2866 -2103.8633 -2357.0564
#  -2177.997  -2214.8037 -1886.1403 -2273.065  -2194.4055 -2229.5464
#  -2386.23   -2092.6624 -2122.8418 -2143.8337 -1979.9823 -2237.042
#  -2065.1333 -2213.6467 -2084.4363 -2042.2745 -2214.69   -2034.2898
#  -2148.3264 -2102.9727 -1917.1132 -1986.5271 -1922.9987 -1899.5322
#  -1915.1041 -2003.9325]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  offer-refund [amount>]
# policy model top parsed: offer-refund, ['<amount>']; score: -5584.2626953125
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'pull-up-account', 'verify-identity', 'shipping-status']
# curr_state.output: init
# curr_state.transitions: [(<aalpy.automata.MarkovChain.McState object at 0x7f585b681d50>, 0.7376415094339622), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f30>, 0.03669811320754717), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ab0>, 0.011320754716981131), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681bd0>, 0.011320754716981131), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e10>, 0.1689622641509434), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681a50>, 0.012075471698113207), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6819f0>, 0.0015094339622641509), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c30>, 0.0036792452830188677), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6820b0>, 0.006320754716981132), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681990>, 0.0027358490566037736), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682050>, 0.0015094339622641509), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b70>, 0.0015094339622641509), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681db0>, 0.0018867924528301887), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f90>, 0.0002830188679245283), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ff0>, 0.00018867924528301886), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e70>, 0.0005660377358490566), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ed0>, 0.0004716981132075472), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681930>, 0.0002830188679245283), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c90>, 0.0004716981132075472), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b10>, 0.0002830188679245283), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681cf0>, 0.0002830188679245283)]
# curr_state.output: pull-up-account
# curr_state.transitions: [(<aalpy.automata.MarkovChain.McState object at 0x7f585b682050>, 0.2397356044235414), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682590>, 0.3746027710690225), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6823b0>, 0.061268590313969744), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682530>, 0.19524596415406126), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681930>, 0.03482903266810728), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682470>, 0.015253590949536036), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682410>, 0.03050718189907207), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e70>, 0.023261726198042457), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6824d0>, 0.005465870090250413), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ed0>, 0.0024151519003432057), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e10>, 0.007245455701029618), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6821d0>, 0.001652472352866404), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681a50>, 0.0013982458370408034), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b10>, 0.0006355662895640015), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b70>, 0.0019066988686920045), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682110>, 0.0008897928053896022), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681cf0>, 0.0010169060633024025), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6819f0>, 0.00025422651582560063), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681d50>, 0.0015253590949536036), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ff0>, 0.00025422651582560063), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c90>, 0.00025422651582560063), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f90>, 0.00012711325791280032), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6834f0>, 0.00025422651582560063)]
# curr_state.output: verify-identity
# curr_state.transitions: [(<aalpy.automata.MarkovChain.McState object at 0x7f585b681930>, 0.18976011457214464), (<aalpy.automata.MarkovChain.McState object at 0x7f585b683370>, 0.2681704260651629), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682410>, 0.04296455424274973), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6833d0>, 0.07876834944504117), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ed0>, 0.18689581095596133), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6831f0>, 0.04296455424274973), (<aalpy.automata.MarkovChain.McState object at 0x7f585b683310>, 0.08592910848549946), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6820b0>, 0.012531328320802004), (<aalpy.automata.MarkovChain.McState object at 0x7f585b683250>, 0.024704618689581095), (<aalpy.automata.MarkovChain.McState object at 0x7f585b6832b0>, 0.04296455424274973), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f90>, 0.003938417472252059), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681ff0>, 0.00322234156820623), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681db0>, 0.006802721088435374), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681e10>, 0.0021482277121374865), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681f30>, 0.00035803795202291446), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681cf0>, 0.00035803795202291446), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c90>, 0.002506265664160401), (<aalpy.automata.MarkovChain.McState object at 0x7f585b682110>, 0.0021482277121374865), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681b10>, 0.0021482277121374865), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681c30>, 0.00035803795202291446), (<aalpy.automata.MarkovChain.McState object at 0x7f585b681d50>, 0.00035803795202291446)]
# context parsed prob: [('init', 1), ('pull-up-account', -0.3042973319756445), ('verify-identity', -0.9818890915915477), ('shipping-status', -1.3161325824279573)], total previous prob: -2.6023190059951498
# possible next: ['pull-up-account', 'validate-purchase', 'verify-identity', 'search-faq', 'ask-the-oracle', 'shipping-status', 'subscription-status', 'membership', 'enter-details', 'offer-refund', 'record-reason', 'update-order', 'try-again', 'make-purchase', 'update-order', 'offer-refund', 'membership', 'verify-identity', 'enter-details', 'shipping-status', 'record-reason', 'ask-the-oracle', 'update-order', 'membership-privileges', 'membership', 'validate-purchase', 'offer-refund', 'make-purchase', 'update-account', 'shipping-status', 'verify-identity'], prob: [-7.650035974995937, -3.5446415765872517, -8.055501083104101, -8.748648263664048, -7.650035974995937, -6.956888794435992, -8.748648263664048, -7.3623539025441564, -8.748648263664048, -3.8658463410776758, -7.650035974995937, -3.9123663567125693, -8.748648263664048, -8.055501083104101, -2.8483283820463625, -4.342253407358619, -7.838760968825099, -6.740148680156989, -7.838760968825099, -7.838760968825099, -7.838760968825099, -7.838760968825099, -4.186962259816034, -3.0036087426928337, -4.85990673305846, -8.484247666034825, -7.567956934160669, -7.567956934160669, -9.177394846594769, -9.177394846594769, -9.177394846594769]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  membership-privileges ['MISSING']
# MERGED top parsed: membership-privileges, ['MISSING']; score: -3003.608742692834
#
# ====================================================================================================
# input:  Context: hello. how can i help you? hi, i placed an order to buy a shirt but i was charged twice. i want my money returned. i will be glad to help you with that. could i have your full name or account id? name: chloe zhang. account id: <account_id>. pull-up-account ['chloe zhang'] could i have your user name, email, and order id. the order id is <order_id>. product: shirt amount: $<amount>. validate-purchase ['<order_id>', '<order_id>', '<order_id>'] ok, how would you like your refund. gift card, added to your account, paper check, or refund to credit card? i would prefer a refund to my credit card. hello. are you there? yes. it will just be a minute. Possible Actions: [record-reason, shipping-status, membership, update-order]
# target:  enter-details [<account_id>]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 21
#      19 num_beams = 50
#      20 # define decoder start token ids
# ---> 21 outputs = model.generate(**encoder_input_ids, max_new_tokens=256, return_dict_in_generate=True, output_scores=True, do_sample=False, num_beams=num_beams, num_return_sequences=num_beams,)
#      22 transition_scores = model.compute_transition_scores(
#      23     outputs.sequences, outputs.scores, normalize_logits=False
#      24 )
#      26 log_prob = transition_scores.cpu().numpy()
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/generation/utils.py:1609, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1602     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1603         input_ids=input_ids,
#    1604         expand_size=generation_config.num_beams,
#    1605         is_encoder_decoder=self.config.is_encoder_decoder,
#    1606         **model_kwargs,
#    1607     )
#    1608     # 13. run beam search
# -> 1609     result = self._beam_search(
#    1610         input_ids,
#    1611         beam_scorer,
#    1612         logits_processor=prepared_logits_processor,
#    1613         stopping_criteria=prepared_stopping_criteria,
#    1614         pad_token_id=generation_config.pad_token_id,
#    1615         eos_token_id=generation_config.eos_token_id,
#    1616         output_scores=generation_config.output_scores,
#    1617         output_logits=generation_config.output_logits,
#    1618         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1619         synced_gpus=synced_gpus,
#    1620         sequential=generation_config.low_memory,
#    1621         **model_kwargs,
#    1622     )
#    1624 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1625     # 11. prepare logits warper
#    1626     logits_warper = self._get_logits_warper(generation_config)
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/generation/utils.py:3064, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, sequential, **model_kwargs)
#    3061     outputs = stack_model_outputs(outputs_per_sub_batch)
#    3063 else:  # Unchanged original behavior
# -> 3064     outputs = self(
#    3065         **model_inputs,
#    3066         return_dict=True,
#    3067         output_attentions=output_attentions,
#    3068         output_hidden_states=output_hidden_states,
#    3069     )
#    3071 if synced_gpus and this_peer_finished:
#    3072     cur_len = cur_len + 1
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1748, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1745         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1747 # Decode
# -> 1748 decoder_outputs = self.decoder(
#    1749     input_ids=decoder_input_ids,
#    1750     attention_mask=decoder_attention_mask,
#    1751     inputs_embeds=decoder_inputs_embeds,
#    1752     past_key_values=past_key_values,
#    1753     encoder_hidden_states=hidden_states,
#    1754     encoder_attention_mask=attention_mask,
#    1755     head_mask=decoder_head_mask,
#    1756     cross_attn_head_mask=cross_attn_head_mask,
#    1757     use_cache=use_cache,
#    1758     output_attentions=output_attentions,
#    1759     output_hidden_states=output_hidden_states,
#    1760     return_dict=return_dict,
#    1761 )
#    1763 sequence_output = decoder_outputs[0]
#    1765 # Set device for model parallelism
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1041, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1037     attention_mask = torch.ones(batch_size, mask_seq_length, device=inputs_embeds.device)
#    1039 # We can provide a self-attention mask of dimensions [batch_size, from_seq_length, to_seq_length]
#    1040 # ourselves in which case we just need to make it broadcastable to all heads.
# -> 1041 extended_attention_mask = self.get_extended_attention_mask(attention_mask, input_shape)
#    1043 # If a 2D or 3D attention mask is provided for the cross-attention
#    1044 # we need to make broadcastable to [batch_size, num_heads, seq_length, seq_length]
#    1045 if self.is_decoder and encoder_hidden_states is not None:
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/modeling_utils.py:974, in ModuleUtilsMixin.get_extended_attention_mask(self, attention_mask, input_shape, device, dtype)
#     971 if dtype is None:
#     972     dtype = self.dtype
# --> 974 if not (attention_mask.dim() == 2 and self.config.is_decoder):
#     975     # show warning only if it won't be shown in `create_extended_attention_mask_for_decoder`
#     976     if device is not None:
#     977         warnings.warn(
#     978             "The `device` argument is deprecated and will be removed in v5 of Transformers.", FutureWarning
#     979         )
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/configuration_utils.py:260, in PretrainedConfig.__getattribute__(self, key)
#     257         key = super().__getattribute__("attribute_map")[key]
#     258     super().__setattr__(key, value)
# --> 260 def __getattribute__(self, key):
#     261     if key != "attribute_map" and key in super().__getattribute__("attribute_map"):
#     262         key = super().__getattribute__("attribute_map")[key]
#
# KeyboardInterrupt:

# %% [markdown]
# #### V2:

# %%
from aalpy.utils import load_automaton_from_file
import random

# load an automaton
chained_proir = load_automaton_from_file("/research/d5/gds/xywen22/project/llm_framework/AST_abcd_part/chainPrior/mdp_guildline_half.dot", automaton_type='mc')

data_index = [random.randint(0, len(data)) for i in range(10)]

for i in data_index:
    print('=' * 100)
    print("input: ", data[i]['input'])
    print("target: ", data[i]['target'])

    input_context = "Predict AST: " + data[i]['input']
    encoder_input_ids = tokenizer(input_context, return_tensors="pt")
    encoder_input_ids = encoder_input_ids.to(device)

    # lets run beam search using 3 beams
    num_beams = 50
    # define decoder start token ids
    outputs = model.generate(**encoder_input_ids, max_new_tokens=256, return_dict_in_generate=True, output_scores=True, do_sample=False, num_beams=num_beams, num_return_sequences=num_beams,)
    transition_scores = model.compute_transition_scores(
        outputs.sequences, outputs.scores, normalize_logits=False
    )

    # log_prob = transition_scores.cpu().numpy()
    # print("log_prob: ", log_prob[0])
    # log_prob = np.sum(log_prob, axis=1)

    output_length = np.sum(transition_scores.cpu().numpy() < 0, axis=1)
    length_penalty = model.generation_config.length_penalty
    reconstructed_scores = transition_scores.sum(axis=1).cpu().numpy() / (output_length ** length_penalty)
    log_prob = reconstructed_scores

    print(f'scores: {log_prob}')

    policy_model_action = []
    policy_model_slot = []
    policy_model_prob = []
    policy_max_idx = np.argmax(log_prob)

    print('+' * 20, 'policy model', '+' * 20)
    for k in range(num_beams):
        pred_str = tokenizer.decode(outputs.sequences[k], skip_special_tokens=True)
        action_name, slots = parse_ast_prediction(pred_str)
        # print(f"policy model top parsed: {action_name}, {slots}; score: {log_prob[k]}")

        policy_model_action.append(action_name)
        policy_model_slot.append(slots)
        if action_name != 'MISSING':
            policy_model_prob.append(log_prob[k])
        else:
            policy_model_prob.append(-10000)

        if k == 0:
            print("policy model top pred str: ", pred_str)
            print(f"policy model top parsed: {action_name}, {slots}; score: {log_prob[k]}")


    print('+' * 20, 'chained prior', '+' * 20)
    prev_actions = parse_context_action(input_context)
    prev_actions = ['init'] + prev_actions
    print(f"context parsed: {prev_actions}")

    init_state = chained_proir.states[0]
    curr_state = init_state

    prev_actions_with_prob = [(curr_state.output, 1)]
    prev_prob = 0
    idx = 0
    while curr_state.output != prev_actions[-1] and idx <= len(prev_actions) - 1:
        print(f"curr_state.output: {curr_state.output}")
        idx += 1
        matched = False
        for prosible_state, prob in curr_state.transitions:
            # print(f"prosible_state: {prosible_state.output}, prob: {prob}")
            if prosible_state.output == prev_actions[idx]:
                # print(f"prev_actions[idx]: {prev_actions[idx]}, curr_state.output: {curr_state.output}")
                prev_actions_with_prob.append((prosible_state.output, np.log(prob)))
                prev_prob += np.log(prob)
                curr_state = prosible_state
                matched = True
        
        if matched == False:
            break
    print(f"context parsed prob: {prev_actions_with_prob}, total previous prob: {prev_prob}")
    
    chained_prior_pred = []
    chained_prior_prob = []
    for state in chained_proir.states:
        # print(f"state: {state.output}")
        if state.output == prev_actions[-1]:
            for prosible_state, prob in state.transitions:
                chained_prior_pred.append(prosible_state.output)
                chained_prior_prob.append(np.log(prob) + prev_prob)
    print(f"possible next: {chained_prior_pred}, prob: {chained_prior_prob}")

    for i, action in enumerate(policy_model_action):
        # print(f"policy model action: {action}, prob: {policy_model_prob[i]}")
        if action == 'MISSING':
            defualt_next = np.argmax(np.array(chained_prior_prob))
            policy_model_action[i] = chained_prior_pred[defualt_next]
            policy_model_prob[i] = chained_prior_prob[defualt_next] * 1000
        else:
            for j, c_action in enumerate(chained_prior_pred):
                if action == c_action:
                    # print(f"policy model prob: {policy_model_prob[i]}, chained prior prob: {chained_prior_prob[j]}")
                    policy_model_prob[i] = policy_model_prob[i] + chained_prior_prob[j] * 100
    
    for i, action in enumerate(chained_prior_pred):
        if action not in policy_model_action:
            policy_model_action.append(action)
            policy_model_slot.append(['MISSING'])
            policy_model_prob.append(chained_prior_prob[i] * 1000)

    print('+' * 20, 'chained prior + policy model', '+' * 20)
    # for i in range(len(policy_model_action)):
    #     print(f"MERGED top parsed: {policy_model_action[i]}, {policy_model_slot[i]}; score: {policy_model_prob[i]}")
    top_idx = np.argmax(np.array(policy_model_prob))
    print("MERGED top pred str: ", f"{policy_model_action[top_idx]} {policy_model_slot[top_idx]}")
    print(f"MERGED top parsed: {policy_model_action[top_idx]}, {policy_model_slot[top_idx]}; score: {policy_model_prob[top_idx]}")
    print()
# Out:
# ====================================================================================================
# input:  Context: thank you for contacting acmebrands! how can i help you today? i'm wondering about a weird fee that got added on to my order. that i'm also checking on. wasn't disclosed when i bought it this extra bit. i can take a look at that for you. could you provide me with your name and account id? rodriguez domingo. <account_id>. pull-up-account ['rodriguez domingo'] i've pulled up your account, mr. domingo. which order id was this for? <order_id>. a michael kors shirt. Possible Actions: [verify-identity, validate-purchase, record-reason, pull-up-account]
# target:  verify-identity [rodriguez domingo, <account_id>, <account_id>]
# /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/generation/utils.py:1197: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# scores: [-31.46646322 -36.88648546 -30.28423517 -33.19927572 -29.0894498
#  -31.26869846 -30.45401476 -30.84985352 -32.54336825 -33.34528266
#  -29.67690158 -30.17221347 -29.24696181 -31.44116821 -28.65219998
#  -29.24461263 -29.81454536 -30.13176541 -31.69626194 -28.0696039
#  -28.15845917 -28.79051883 -27.61348199 -29.53698176 -29.33618707
#  -29.26768663 -26.15303819 -31.44916992 -28.70319824 -24.67834195
#  -29.25456814 -26.88825989 -28.76027018 -29.3990153  -25.31437683
#  -28.94166528 -25.58459778 -28.70853407 -26.20375784 -28.50030092
#  -26.00545432 -26.13295201 -22.38342014 -24.38519734 -23.48244324
#  -26.06386497 -23.81065704 -24.30553367 -24.958648   -23.45784505]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  verify-identity [rodriguez domingo, account_id>, account_id>]
# policy model top parsed: verify-identity, ['rodriguez domingo', '<account_id>', '<account_id>']; score: -31.466463216145833
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'pull-up-account']
# curr_state.output: init
# context parsed prob: [('init', 1), ('pull-up-account', -0.3042973319756445)], total previous prob: -0.3042973319756445
# possible next: ['validate-purchase', 'verify-identity', 'enter-details', 'record-reason', 'ask-the-oracle', 'notify-internal-team', 'n/a', 'shipping-status', 'notify-team', 'subscription-status', 'search-faq', 'try-again', 'log-out-in', 'make-purchase', 'membership', 'make-password', 'promo-code', 'instructions', 'pull-up-account', 'update-order', 'offer-refund', 'update-account', 'select-faq', 'validate-purchase', 'ask-the-oracle', 'verify-identity', 'pull-up-account', 'search-shirt', 'search-boots'], prob: [-1.7325159431114843, -1.2861864235671923, -3.0967852922542867, -1.9377924925972696, -3.6616012999168164, -4.487237663522841, -3.7940904829628956, -4.065243253463466, -5.5135292906113245, -6.330290427138446, -5.231678138470336, -6.70978004884335, -6.876834133506516, -7.665291493870786, -6.566679205202677, -7.328819257249573, -7.19528786462505, -8.581582225744942, -6.7898227565168865, -8.581582225744942, -8.581582225744942, -9.274729406304887, -8.581582225744942, -2.501521909311864, -1.5852311774377088, -1.1152275481919733, -3.194669089871809, -3.194669089871809, -3.194669089871809]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  verify-identity [rodriguez domingo, account_id>, account_id>] ['michael kors shirt']
# MERGED top parsed: verify-identity [rodriguez domingo, account_id>, account_id>], ['michael kors shirt']; score: -22.383420138888887
#
# ====================================================================================================
# input:  Context: hi, how can i help you? hi!   i need ot remove an item from my last order please. may i have your full name or account id? sure, its <account_id>. pull-up-account ['<account_id>'] what is the shipping status of the order? umm, i'll check. it says in transit. shipping-status ['in transit'] may i have your username, e-mail address, and the order id? the order id is <order_id>. i don't seem to remember my email address or id for this account. oh wait, its david@mail.com. and david123 for my username. validate-purchase ['<order_id>', '<order_id>', '<order_id>'] thank you. what is the item you want removed? update-order ['change order'] the second item, the boots from calvin klein. Possible Actions: [enter-details, make-purchase]
# target:  update-order [calvin klein boots]
# scores: [-33.46512567 -33.80237979 -38.21507626 -32.25501709 -29.47306024
#  -35.20842053 -31.41734677 -32.62928409 -31.69090634 -34.86038063
#  -29.30603609 -30.98375244 -32.14533924 -33.55916748 -35.96363758
#  -28.26720029 -36.1401716  -33.52137451 -32.88144066 -33.66947021
#  -32.50054641 -29.85334415 -28.54301816 -31.01428223 -31.36869303
#  -23.59819539 -35.46568952 -26.29634705 -31.52934338 -26.2386184
#  -26.33498419 -33.3522644  -25.21149292 -22.11806815 -29.48349435
#  -25.58392043 -26.87133484 -21.30248733 -23.60933722 -31.75585066
#  -22.79705811 -20.93986293 -27.89141555 -26.51417178 -29.42119489
#  -25.99893334 -24.76753453 -22.11031814 -24.25077602 -31.3821789 ]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  make-purchase [boots from calvin klein]
# policy model top parsed: make-purchase, ['boots from calvin klein']; score: -33.465125674293155
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'pull-up-account', 'shipping-status', 'validate-purchase', 'update-order']
# curr_state.output: init
# curr_state.output: pull-up-account
# curr_state.output: shipping-status
# curr_state.output: validate-purchase
# context parsed prob: [('init', 1), ('pull-up-account', -0.3042973319756445), ('shipping-status', -3.7609459214878216), ('validate-purchase', -0.9423225705921019), ('update-order', -2.232298560265874)], total previous prob: -7.239864384321442
# possible next: ['enter-details', 'shipping-status', 'pull-up-account', 'make-purchase', 'update-order', 'record-reason', 'update-account', 'offer-refund', 'notify-team', 'search-faq', 'promo-code', 'send-link'], prob: [-10.607160214307916, -12.398919683535972, -13.092066864095916, -7.888060177019121, -10.453009534480657, -11.993454575427807, -11.300307394867861, -8.2798825087235, -13.092066864095916, -12.398919683535972, -13.092066864095916, -13.092066864095916]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  select-faq ['boots calvin klein']
# MERGED top parsed: select-faq, ['boots calvin klein']; score: -23.598195393880207
#
# ====================================================================================================
# input:  Context: hi, how can i help you today? i bought an item and want to return it, i bought the wrong size. how do i return it? okay, can i have your full name please? joseph banter. pull-up-account ['joseph banter'] thank you joseph. can i also have your account id and your order id as well? order id: <order_id>. can i have your username instead of the account id? account id is covid192020. username: <username>. sorry about that, my mistake. no problem. can i have your email address as well? <email>. validate-purchase ['<username>', '<username>', '<username>'] i appreciate that information. could i please have your membership level? no problem. bronze. what is the date of your order? 2019-11-29. do you have the receipt? yes i do. membership ['bronze'] okay, since you have the receipt, you can return the item. perfect. thank you. i will need your address so i can send over a shipping label that you can print. my address is 123456 covid lane, unit 19. china, ontario. zip code? postal code is 90222. thank you. zip code. 90222. enter-details ['<username>'] how would you like to return your item? you can send it in by mail, in store, or at a drop-off center. i will mail it. great. Possible Actions: [enter-details, update-order, offer-refund, ask-the-oracle, update-account, notify-team]
# target:  update-order [by mail]
# scores: [-38.86802979 -38.34472168 -36.22204102 -28.47229456 -24.80915889
#  -37.75577017 -29.61766222 -33.95573308 -19.43270639 -19.62656813
#  -30.30110225 -25.58443275 -24.75119141 -22.85589826 -30.8090323
#  -21.96919759 -19.96184625 -37.0047404  -37.04466834 -37.12762216
#  -27.04920138 -30.38731971 -25.15672924 -16.9986188  -26.23407921
#  -29.10747387 -24.55288809 -26.86884675 -22.60878273 -34.24696181
#  -29.14923096 -27.63717538 -25.1787245  -23.09596605 -21.9445613
#  -23.95675424 -20.22081111 -20.77416088 -26.46928993 -23.8038963
#  -22.15750357 -26.98288903 -23.15757921 -21.83712534 -21.84028682
#  -25.93875235 -20.04180456 -24.38119272 -26.23391958 -18.52196022]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  update-order [by mail]
# policy model top parsed: update-order, ['by mail']; score: -38.86802978515625
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'pull-up-account', 'validate-purchase', 'enter-details']
# curr_state.output: init
# curr_state.output: pull-up-account
# curr_state.output: validate-purchase
# context parsed prob: [('init', 1), ('pull-up-account', -0.3042973319756445), ('validate-purchase', -1.4282186111358397), ('enter-details', -3.570018251237207)], total previous prob: -5.302534194348691
# possible next: ['log-out-in', 'try-again', 'send-link', 'make-password', 'make-purchase', 'validate-purchase', 'update-account', 'notify-team', 'offer-refund', 'update-order', 'enter-details', 'record-reason', 'shipping-status', 'ask-the-oracle', 'membership', 'n/a', 'send-link', 'make-password', 'enter-details', 'record-reason', 'verify-identity', 'update-order', 'log-out-in', 'notify-team', 'update-account', 'update-order', 'offer-refund', 'make-purchase', 'membership', 'record-reason', 'enter-details', 'validate-purchase', 'notify-team', 'send-link', 'shipping-status', 'update-account', 'make-password', 'update-order', 'notify-team', 'send-link', 'enter-details', 'ask-the-oracle', 'make-purchase', 'search-faq', 'notify-team', 'update-order', 'offer-refund', 'update-order'], prob: [-8.40487620296094, -8.45616949734849, -7.904100915048451, -9.454698327459617, -10.014314115395042, -11.400608476514932, -7.737046830385285, -9.791170564080831, -6.288620688158389, -6.5027686765640205, -8.91570182672693, -11.400608476514932, -11.400608476514932, -11.400608476514932, -10.707461295954985, -6.672021437152201, -5.938052262072, -7.028696381090933, -8.974606530146247, -11.459513179934246, -11.459513179934246, -11.459513179934246, -11.459513179934246, -11.459513179934246, -11.459513179934246, -5.849077900716761, -6.637535261081032, -9.34558546218324, -9.34558546218324, -8.652438281623297, -9.34558546218324, -9.34558546218324, -9.34558546218324, -9.34558546218324, -9.34558546218324, -6.343988069176852, -6.1208445178626425, -8.828894718964852, -7.730282430296743, -8.828894718964852, -8.423429610856688, -9.522041899524798, -5.30654221574623, -10.823995112210937, -5.496690208789649, -7.442600357844962, -8.135747538404907, -5.302534194348691]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  update-account [delivery ['by mail']
# MERGED top parsed: update-account [delivery, ['by mail']; score: -34.24696180555556
#
# ====================================================================================================
# input:  Context: hello, how can i help you? so according to my bank statement i was charged the annual fee of 99$ twice last night! pretty sur eyou guys double charged me. i am so sorry about that. can i have your name? david williams. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  pull-up-account [david williams]
# scores: [-31.89632442 -24.6621199  -24.49308829 -26.6269405  -21.14134652
#  -22.0517055  -21.83983954 -19.0141328  -22.76349929 -19.13962108
#  -20.97804839 -20.11158098 -22.01426749 -20.08688249 -21.32227825
#  -20.0730654  -20.5315678  -19.90393938 -18.93417794 -17.44153704
#  -19.29981311 -17.87261331 -18.3110417  -19.59950835 -19.29611943
#  -18.35408674 -17.37080819 -17.61493762 -19.25722109 -15.0213139
#  -19.05398454 -20.82410089 -17.53531788 -17.91748889 -15.35203815
#  -17.55720257 -16.49195644 -16.60388184 -15.88855296 -16.38597896
#  -18.97215534 -16.17518142 -16.87334048 -17.04949425 -17.04388849
#  -17.42370185 -18.0777188  -14.80241868 -15.28520255 -14.15847778]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  pull-up-account [david williams]
# policy model top parsed: pull-up-account, ['david williams']; score: -31.896324420797413
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init']
# context parsed prob: [('init', 1)], total previous prob: 0
# possible next: ['pull-up-account', 'try-again', 'log-out/in', 'notify-internal-team', 'search-faq', 'log-out-in', 'instructions', 'notify-team', 'verify-identity', 'enter-details', 'validate-purchase', 'membership', 'record-reason', 'update-account', 'update-order', 'shipping-status', 'subscription-status', 'ask-the-oracle', 'offer-refund', 'make-purchase', 'promo-code'], prob: [-0.3042973319756445, -3.305029936481712, -4.481117537318112, -4.481117537318112, -1.7780798780394467, -4.416579016180541, -6.496020557860377, -5.6050476339705115, -5.063916660709192, -5.901313450113684, -6.496020557860377, -6.496020557860377, -6.272877006546167, -8.169996991432049, -8.575462099540212, -7.476849810872103, -7.659171367666058, -8.169996991432049, -7.659171367666058, -8.169996991432049, -8.169996991432049]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  pull-up-account ['david williams customer is typing']
# MERGED top parsed: pull-up-account, ['david williams customer is typing']; score: -57.05667369460109
#
# ====================================================================================================
# input:  Context: hello. i keep searching for items, but unrelated items keep popping up. it seems the search button has an issue. let's try to fix it. okay. great. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  log-out-in [none]
# scores: [-36.13905736 -36.0570204  -33.30640612 -31.21321186 -28.11364407
#  -26.65266418 -27.32873214 -37.04370117 -23.84993829 -27.62167867
#  -28.13008626 -26.65884721 -23.64102681 -33.0760871  -31.42721378
#  -28.99931255 -28.55786454 -22.58512637 -24.41124301 -35.00197882
#  -27.82587955 -24.11415609 -27.18408203 -26.10008481 -34.16168855
#  -27.52921335 -26.9139133  -24.44341077 -25.38946533 -28.77819182
#  -24.0688332  -28.41297029 -25.22066136 -28.83704631 -27.34352513
#  -26.99628649 -28.35843699 -26.1891351  -28.34773656 -26.18477885
#  -24.73378714 -28.54084216 -27.59268358 -27.41439016 -26.57531256
#  -30.39153375 -28.00748484 -27.44090512 -22.77490877 -23.18391499]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  log-out-in [none]
# policy model top parsed: log-out-in, ['none']; score: -36.13905736019737
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init']
# context parsed prob: [('init', 1)], total previous prob: 0
# possible next: ['pull-up-account', 'try-again', 'log-out/in', 'notify-internal-team', 'search-faq', 'log-out-in', 'instructions', 'notify-team', 'verify-identity', 'enter-details', 'validate-purchase', 'membership', 'record-reason', 'update-account', 'update-order', 'shipping-status', 'subscription-status', 'ask-the-oracle', 'offer-refund', 'make-purchase', 'promo-code'], prob: [-0.3042973319756445, -3.305029936481712, -4.481117537318112, -4.481117537318112, -1.7780798780394467, -4.416579016180541, -6.496020557860377, -5.6050476339705115, -5.063916660709192, -5.901313450113684, -6.496020557860377, -6.496020557860377, -6.272877006546167, -8.169996991432049, -8.575462099540212, -7.476849810872103, -7.659171367666058, -8.169996991432049, -7.659171367666058, -8.169996991432049, -8.169996991432049]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  fix-up-account ['joseph banter']
# MERGED top parsed: fix-up-account, ['joseph banter']; score: -22.585126374897204
#
# ====================================================================================================
# input:  Context: hello. hi.  my name is alessandro phoenix.  my order id is <order_id>.  i would like to return these tommy hilfiger boots for $<amount> and add this refund onto my existing refund of $100 if possible? okay. pull-up-account ['alessandro phoenix'] i need to confirm that your purchase is valid. give me your username, email and order id. sure.  my username is <username>, my email is <email>. i gave you the order id above. validate-purchase ['<username>', '<username>', '<username>'] validated. Possible Actions: [record-reason, shipping-status, membership, update-order]
# target:  record-reason [tommy hilfger boots]
# scores: [-40.12108101 -38.46554191 -36.22576427 -16.2205757  -15.40639134
#  -13.53826155 -13.56238757 -14.87548935 -13.26546866 -13.5243798
#  -16.24430553 -14.10859975 -14.8149564  -15.39938646 -16.37539298
#  -15.23555073 -15.80528179 -15.92587013 -13.90124726 -15.18621077
#  -14.63752291 -14.36444841 -15.55414782 -14.351207   -15.77683619
#  -14.46544982 -17.14085629 -15.50381095 -15.28417862 -14.99590957
#  -15.71340483 -15.13817824 -15.59994989 -14.05957138 -15.59809313
#  -15.87341094 -14.90773412 -14.6633954  -13.49526792 -15.07219281
#  -15.01596444 -14.43981184 -13.66392008 -14.19505016 -13.14211661
#  -12.55925015 -13.12659334 -13.85237416 -14.53776898 -14.13130054]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  record-reason [tommy hilfiger boots]
# policy model top parsed: record-reason, ['tommy hilfiger boots']; score: -40.12108101222826
# Token indices sequence length is longer than the specified maximum sequence length for this model (546 > 512). Running this sequence through the model will result in indexing errors
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'pull-up-account', 'validate-purchase']
# curr_state.output: init
# curr_state.output: pull-up-account
# context parsed prob: [('init', 1), ('pull-up-account', -0.3042973319756445), ('validate-purchase', -1.4282186111358397)], total previous prob: -1.7325159431114843
# possible next: ['record-reason', 'ask-the-oracle', 'pull-up-account', 'make-password', 'verify-identity', 'membership', 'offer-refund', 'n/a', 'membership-privileges', 'shipping-status', 'enter-details', 'subscription-status', 'validate-purchase', 'update-order', 'search-faq', 'promo-code', 'notify-team', 'make-purchase', 'try-again', 'ask-the-oracle', 'update-order', 'record-reason', 'enter-details', 'validate-purchase', 'notify-team', 'shipping-status', 'membership'], prob: [-2.8527188643719614, -4.10548183286733, -8.264364916227002, -9.36297720489511, -6.798027847433574, -4.269227004088348, -6.41853822572867, -4.575485462113065, -3.476873173444955, -4.121230189835469, -5.302534194348691, -7.976682843775221, -5.836616680278949, -3.964814503377358, -7.753539292461011, -9.36297720489511, -8.669830024335166, -8.669830024335166, -9.36297720489511, -1.866047335736007, -5.721499989675759, -4.622887701007649, -6.00918206212754, -6.414647170235704, -7.10779435079565, -5.721499989675759, -7.10779435079565]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  verify-identity ['alessandro phoenix', '<order_id>', '<order_id>']
# MERGED top parsed: verify-identity, ['alessandro phoenix', '<order_id>', '<order_id>']; score: -716.0285490096618
#
# ====================================================================================================
# input:  Context: hello, how may i assist you today? hello i purchased this jacket for my wife but it turns out she's a little to hefty to fit in it so i'd like to return it. chat will end soon due to inactivity. *too. may i have your full name, order id, and email address? sanya afzal. email is "<email>". the order id is <order_id>. may i have your username? that would be <username>. i am sorry, i h=am having trouble pulling up your account details. what is the purchase date and membership level? that's okay is there any other info i could provide to help? just a moment. purchase date is 2019-12-20. my membership level is gold. you get unlimited returns as a gold member. what is your address please? that's good to hear! <street_address>  san lima, ny <zip_code>. return options include mail, in store, or ups drop-off. the address is 448 fairview drive. i assume this is the store address? yes. understood i will drop it off shortly. thank you for your help. anything else i can help you with? nope that's everything thanks again! have a great day! validate-purchase ['<username>', '<username>', '<username>'] membership ['bronze'] pull-up-account ['joyce wu'] validate-purchase ['<username>', '<username>', '<username>'] pull-up-account ['david williams'] verify-identity ['sanya afzal', '<order_id>', '<order_id>'] membership ['gold'] validate-purchase ['<username>', '<username>', '<username>'] membership ['silver'] enter-details ['<username>'] record-reason ['guess jeans'] Possible Actions: [ask-the-oracle, verify-identity, offer-refund, enter-details]
# target:  update-order [by mail]
# scores: [-42.3119565  -41.97819592 -43.16341344 -38.52782331 -26.46222796
#  -39.26705114 -38.2989967  -38.88483829 -38.62831079 -39.16565523
#  -34.9306815  -37.2203747  -39.2477853  -37.252626   -35.0545538
#  -36.23497373 -32.24910482 -35.92625209 -37.05526297 -33.55213274
#  -38.94868397 -36.26523554 -35.5674235  -35.61207799 -23.10762678
#  -36.38516962 -33.30128697 -20.14299375 -34.66388982 -31.74580793
#  -22.87486485 -34.55398485 -29.55844262 -23.00375512 -35.62500291
#  -24.11276536 -21.82234006 -36.75063942 -22.71405175 -31.83778018
#  -35.91139439 -24.63586716 -18.60166858 -26.5856643  -23.1986084
#  -31.81354206 -20.36659313 -18.1956293  -22.34869239 -28.29415458]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  enter-details [username>]
# policy model top parsed: enter-details, ['<username>']; score: -42.311956496465776
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'validate-purchase', 'pull-up-account', 'validate-purchase', 'pull-up-account', 'verify-identity', 'validate-purchase', 'enter-details', 'record-reason']
# curr_state.output: init
# curr_state.output: validate-purchase
# curr_state.output: pull-up-account
# curr_state.output: validate-purchase
# curr_state.output: pull-up-account
# curr_state.output: verify-identity
# curr_state.output: validate-purchase
# curr_state.output: enter-details
# context parsed prob: [('init', 1), ('validate-purchase', -6.496020557860377), ('pull-up-account', -6.531848973115517), ('validate-purchase', -1.4282186111358397), ('pull-up-account', -6.531848973115517), ('verify-identity', -0.9818890915915477), ('validate-purchase', -2.541244019592815), ('enter-details', -4.276666119016055), ('record-reason', -6.09807428216624)], total previous prob: -34.88581062759391
# possible next: ['notify-team', 'pull-up-account', 'verify-identity', 'search-faq', 'record-reason', 'promo-code', 'ask-the-oracle', 'offer-refund', 'enter-details', 'membership-privileges', 'n/a', 'update-order', 'membership', 'make-purchase', 'shipping-status', 'validate-purchase', 'update-account', 'search-timing', 'ask-the-oracle', 'verify-identity', 'notify-internal-team', 'notify-team', 'promo-code', 'validate-purchase', 'record-reason', 'update-account', 'enter-details', 'search-faq'], prob: [-40.79931363323218, -39.00755416400413, -39.094565540993756, -40.393848525124014, -38.92751145633059, -38.92751145633059, -39.883022901358025, -36.266714140078925, -36.36849683438887, -36.70496907101008, -36.70496907101008, -37.43201780324571, -38.853403484176866, -40.106166452672234, -41.49246081379213, -40.79931363323218, -39.54655066473681, -41.49246081379213, -36.065117302029655, -35.45590457295486, -37.434604544833164, -38.37194868590515, -40.142654745935374, -40.83580192649532, -39.919511194621165, -41.1234839989471, -41.52894910705526, -42.22209628761521]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  lock-up-account ['sanya afzal']
# MERGED top parsed: lock-up-account, ['sanya afzal']; score: -31.74580792682927
#
# ====================================================================================================
# input:  Context: welcome to acmebrands. how may i help? hello, i was wondering what types of membership levels there are in your company. ok. i can help. one moment. search-faq ['none'] Possible Actions: [search-pricing, search-membership, search-policy, search-shirt, search-jacket]
# target:  search-membership [none]
# scores: [-40.90998921 -17.55166653 -16.62436745 -17.8383322  -16.62239513
#  -17.45043618 -17.66528212 -17.43229167 -17.04926287 -17.80444336
#  -18.01578635 -17.21551192 -16.80112176 -17.04797257 -16.79173724
#  -16.75591457 -17.23162628 -17.43485514 -16.52515513 -16.96946422
#  -17.17834258 -16.99077573 -17.06233296 -17.01567685 -17.08603256
#  -17.1680073  -17.3331513  -17.48311608 -16.94797045 -16.98037959
#  -17.12650553 -16.92749023 -16.74840666 -16.86309443 -17.28966967
#  -17.15675845 -18.27693042 -17.16396613 -16.81942588 -16.79552687
#  -16.1691376  -16.51791328 -16.78928844 -17.20306775 -16.65295304
#  -16.94571083 -17.08282205 -17.38022975 -16.99585068 -16.87007971]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  search-membership [none]
# policy model top parsed: search-membership, ['none']; score: -40.90998920641447
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'search-faq']
# curr_state.output: init
# context parsed prob: [('init', 1), ('search-faq', -1.7780798780394467)], total previous prob: -1.7780798780394467
# possible next: ['boots', 'shirt', 'jeans', 'jacket', 'pricing', 'membership', 'timing', 'policy', 'search-timing', 'search-shirt', 'search-membership', 'search-boots', 'search-jacket', 'search-policy', 'search-pricing', 'search-jeans', 'log-out-in', 'try-again', 'pull-up-account', 'notify-team', 'instructions', 'promo-code', 'verify-identity', 'ask-the-oracle', 'search-membership', 'search-policy', 'search-pricing'], prob: [-4.532271235139512, -4.532271235139512, -4.532271235139512, -4.532271235139512, -4.532271235139512, -4.48348107097008, -4.532271235139512, -4.532271235139512, -4.610232776609224, -4.745051999418175, -4.3361563562132215, -4.491449240619256, -4.601264106626463, -4.745051999418175, -4.714592791933466, -4.628415095692414, -7.933468616801667, -7.373852828866244, -7.528003508693502, -9.319762977921558, -9.319762977921558, -9.319762977921558, -9.319762977921558, -9.319762977921558, -1.9787505735015978, -3.7705100427296525, -4.8691223313977625]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  search-membership ['none']
# MERGED top parsed: search-membership, ['none']; score: -647.6598305717308
#
# ====================================================================================================
# input:  Context: how can i help you? hi, i have a gold membership and am wondering how to cancel it? search-faq ['none'] search-membership ['none'] Possible Actions: [search-policy, select-faq]
# target:  search-policy [none]
# scores: [-34.81060181 -28.58557739 -33.71173401 -32.73426514 -35.71833191
#  -34.23365614 -35.79068909 -32.05041504 -27.38379822 -23.34532406
#  -26.23800354 -34.19407959 -25.14404297 -30.74451326 -29.44269409
#  -26.44842851 -25.08396454 -30.2880127  -24.27757665 -35.51921644
#  -28.61462081 -27.73591694 -23.75360107 -24.5540386  -23.64781189
#  -33.36900892 -23.77454529 -31.63788452 -27.50210732 -25.68354797
#  -29.60163574 -29.52896729 -25.10648651 -27.11295776 -29.91828003
#  -30.18688965 -28.81609786 -29.12117727 -25.60432193 -27.71963501
#  -25.15871124 -25.55825806 -23.24118805 -23.87108459 -22.79807129
#  -30.21537058 -20.34302979 -23.32633514 -25.96419164 -21.327948  ]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# policy model top pred str:  search-policy [none]
# policy model top parsed: search-policy, ['none']; score: -34.810601806640626
# ++++++++++++++++++++ chained prior ++++++++++++++++++++
# context parsed: ['init', 'search-faq', 'search-membership']
# curr_state.output: init
# curr_state.output: search-faq
# context parsed prob: [('init', 1), ('search-faq', -1.7780798780394467), ('search-membership', -2.5580764781737746)], total previous prob: -4.3361563562132215
# possible next: ['select-faq', 'search-policy', 'search-timing', 'verify-identity', 'pull-up-account', 'search-pricing', 'send-link', 'search-boots', 'record-reason', 'membership', 'notify-team', 'try-again', 'update-order', 'enter-details', 'shipping-status'], prob: [-4.799890372445361, -6.186184733565252, -7.45915040937814, -8.711913377873508, -8.711913377873508, -7.007165285635082, -9.405060558433453, -9.405060558433453, -9.405060558433453, -8.018766197313562, -9.405060558433453, -9.405060558433453, -9.405060558433453, -9.405060558433453, -9.405060558433453]
# ++++++++++++++++++++ chained prior + policy model ++++++++++++++++++++
# MERGED top pred str:  pick-up-account ['normanb1']
# MERGED top parsed: pick-up-account, ['normanb1']; score: -21.327947998046874
#
# ====================================================================================================
# input:  Context: hello, how may i help you? i have a shipping question - does my account include free shipping? free shipping from out of country that is. let's see what we can find out. Possible Actions: [pull-up-account, enter-details, verify-identity, make-password, search-timing, search-policy, validate-purchase, search-faq, membership, search-boots, try-again, ask-the-oracle, update-order, promo-code, update-account, search-membership, make-purchase, offer-refund, notify-team, record-reason, search-jeans, shipping-status, search-shirt, instructions, search-jacket, log-out-in, select-faq, subscription-status, send-link, search-pricing]
# target:  search-faq [none]
# scores: [-45.64909137 -11.36906032 -13.45438853 -17.9775048  -17.62368801
#  -18.39860454 -17.84909539 -14.00977419 -16.11457477 -13.75862095
#  -13.51257217 -13.38360274 -14.50948079 -12.6987219  -12.79031747
#  -12.02550306 -10.52233673 -10.12134324 -10.77315374  -9.95922852
#   -9.77814042  -9.64693946 -10.16796875  -7.99349922  -9.95837402
#   -9.48236834  -8.93680345 -10.20781769  -9.06712475  -9.65178051
#   -8.60157222  -8.76878758  -9.55515651  -9.18427692  -9.57788514
#   -8.86278601  -9.16043496  -9.83770752 -10.3611272  -10.40345202
#  -10.62398703 -10.35756429 -10.19666277 -11.18110737  -8.71628159
#   -9.71827671  -8.39898093  -8.95795213  -8.3762812   -9.80953819]
# ++++++++++++++++++++ policy model ++++++++++++++++++++
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 44
#      42 print('+' * 20, 'policy model', '+' * 20)
#      43 for k in range(num_beams):
# ---> 44     pred_str = tokenizer.decode(outputs.sequences[k], skip_special_tokens=True)
#      45     action_name, slots = parse_ast_prediction(pred_str)
#      46     # print(f"policy model top parsed: {action_name}, {slots}; score: {log_prob[k]}")
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3825, in PreTrainedTokenizerBase.decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, **kwargs)
#    3822 # Convert inputs to python lists
#    3823 token_ids = to_py_obj(token_ids)
# -> 3825 return self._decode(
#    3826     token_ids=token_ids,
#    3827     skip_special_tokens=skip_special_tokens,
#    3828     clean_up_tokenization_spaces=clean_up_tokenization_spaces,
#    3829     **kwargs,
#    3830 )
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/tokenization_utils.py:1001, in PreTrainedTokenizer._decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, spaces_between_special_tokens, **kwargs)
#     991 def _decode(
#     992     self,
#     993     token_ids: List[int],
#    (...)
#     997     **kwargs,
#     998 ) -> str:
#     999     self._decode_use_source_tokenizer = kwargs.pop("use_source_tokenizer", False)
# -> 1001     filtered_tokens = self.convert_ids_to_tokens(token_ids, skip_special_tokens=skip_special_tokens)
#    1002     legacy_added_tokens = set(self._added_tokens_encoder.keys()) - set(self.all_special_tokens) | {
#    1003         token for token in self.additional_special_tokens if self.convert_tokens_to_ids(token) >= self.vocab_size
#    1004     }
#    1005     # To avoid mixing byte-level and unicode for byte-level BPT
#    1006     # we need to build string separately for added tokens and byte-level tokens
#    1007     # cf. https://github.com/huggingface/transformers/issues/1133
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/tokenization_utils.py:977, in PreTrainedTokenizer.convert_ids_to_tokens(self, ids, skip_special_tokens)
#     975 for index in ids:
#     976     index = int(index)
# --> 977     if skip_special_tokens and index in self.all_special_ids:
#     978         continue
#     979     if index in self._added_tokens_decoder:
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1361, in SpecialTokensMixin.all_special_ids(self)
#    1357 """
#    1358 `List[int]`: List the ids of the special tokens(`'<unk>'`, `'<cls>'`, etc.) mapped to class attributes.
#    1359 """
#    1360 all_toks = self.all_special_tokens
# -> 1361 all_ids = self.convert_tokens_to_ids(all_toks)
#    1362 return all_ids
#
# File /research/d5/gds/xywen22/anaconda3/envs/chainPrior/lib/python3.10/site-packages/transformers/tokenization_utils.py:649, in PreTrainedTokenizer.convert_tokens_to_ids(self, tokens)
#     647 ids = []
#     648 for token in tokens:
# --> 649     ids.append(self._convert_token_to_id_with_added_voc(token))
#     650 return ids
#
# KeyboardInterrupt:

# %%
from aalpy.utils import load_automaton_from_file

# load an automaton
chained_proir = load_automaton_from_file('/research/d1/gds/jyzhong/computation_models/mdp_guildline_half.dot', automaton_type='mc')

preds = []
labels = []


for i in tqdm(range(len(data))):
    # print('=' * 100)
    # print("input: ", data[i]['input'])
    # print("target: ", data[i]['target'])

    input_context = "Predict AST: " + data[i]['input']
    encoder_input_ids = tokenizer(input_context, return_tensors="pt")
    encoder_input_ids = encoder_input_ids.to(device)

    # lets run beam search using 3 beams
    num_beams = 20
    # define decoder start token ids
    outputs = model.generate(**encoder_input_ids, max_new_tokens=100, return_dict_in_generate=True, output_scores=True, do_sample=False, num_beams=num_beams, num_return_sequences=num_beams,)
    # print(outputs.scores)
    try:
        transition_scores = model.compute_transition_scores(
            outputs.sequences, outputs.scores, normalize_logits=False
        )
        output_length = np.sum(transition_scores.cpu().numpy() < 0, axis=1)
        length_penalty = model.generation_config.length_penalty
        reconstructed_scores = transition_scores.sum(axis=1).cpu().numpy() / (output_length**length_penalty)
    except:
        reconstructed_scores = np.zeros(num_beams)
        print(f"cannot compute {i}, set prob to 0")

    log_prob = reconstructed_scores
    # log_prob = np.sum(log_prob, axis=1)
    # log_prob = normalize_log_probs(log_prob)
    # print(f'scores: {log_prob}')

    policy_model_action = []
    policy_model_slot = []
    policy_model_prob = []
    policy_max_idx = np.argmax(log_prob)

    # print('+' * 20, 'policy model', '+' * 20)
    for k in range(num_beams):
        pred_str = tokenizer.decode(outputs.sequences[k], skip_special_tokens=True)
        action_name, slots = parse_ast_prediction(pred_str)

        policy_model_action.append(action_name)
        policy_model_slot.append(slots)
        if action_name != 'MISSING':
            policy_model_prob.appe
